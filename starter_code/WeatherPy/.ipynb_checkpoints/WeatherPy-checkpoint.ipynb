# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# #Observations
# ---------------------
#
# * 1) We can see from our regression analysis that there are strong correlations between latitude and temperature.
# ------------------------------------------------------------------------------------------------------------------------------
# * 2) We can see from the regression analysis that there is correlation between latitude and the other relationships, but they have weak correlation. While latitude might have some impact, there are several other geographical factors that might have a greater impact.
# ------------------------------------------------------------------------------------------------------------------------------
# * 3) The number of cities greatly favored the Northern Hemisphere data. This was due to randomly generating the latitude coordinates at the beginning of the code. I feel like we got a more accurate sample of Northern Hemisphere weather data when compared to Southern Hemisphere data. We could run the code a few more times or at greater quantity to see how the data might have changed.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import requests
import json
from api_keys import weather_api_key
from citipy import citipy
import random
import decimal
import time

# %% [markdown]
# ## Generate Cities List

# %%
#set up latitude and longitude lists
latitude_list = []
longitude_list = []

# Generate 5000 random latitude and logitude values and add them to there respective list
for x in range(0, 5000):
    latitude = float(decimal.Decimal(random.randrange(-9000, 9000))/100)
    longitude = float(decimal.Decimal(random.randrange(-18000, 18000))/100)
    latitude_list.append(latitude)
    longitude_list.append(longitude)

# Set up the Weather DF
weather_df = pd.DataFrame({"Latitude": latitude_list, "Longitude": longitude_list})

# set up list to hold city names and what there country there from
city_list = []
country_list = []

# goes through each value of Latitude and Longitude in the Weather DF and uses the value as inputs to determin there city and country
for a in range(0, len(weather_df["Latitude"])):
    lat_value = weather_df.iloc[a]["Latitude"]
    long_value = weather_df.iloc[a]["Longitude"]    
    city_cord = citipy.nearest_city(lat_value, long_value)
    city_name = city_cord.city_name
    city_list.append(city_name)
    country = city_cord.country_code
    country_list.append(country)

    
# adds the city and country lists into our weather data frame, and then a touch of formatting   
weather_df["City"] = city_list
weather_df["Country"] = country_list
weather_df["City"] = weather_df["City"].str.title()
weather_df["Country"] = weather_df["Country"].str.upper()


#drop duplicates duplicates
weather_df = weather_df.drop_duplicates(subset=["City", "Country"], keep="first")
weather_df = weather_df.reset_index(drop=True)

print("Total number of unique cities in weather dataframe is: " + str(len(weather_df.index)))
# Out:
# Total number of unique cities in weather dataframe is: 1400

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set up list for variables we want
temperature_list = [] 
humidity_list = []
cloudiness_list = []
wind_speed_list = []
date_list = []
latitude_list_v2 = []
longitude_list_v2 = []
city_list_v2 = []
country_list_v2 = []

# Base URL before adding variable componets
url = "http://api.openweathermap.org/data/2.5/weather?"

    

for target in range(0, len(weather_df.index)):
    
    # Select city on weather DF, and formate for proper url code in event city has spaces in name
    display_city = weather_df.iloc[target]["City"]
    display_country = weather_df.iloc[target]["Country"]
    target_city = weather_df.iloc[target]["City"]
    target_city = target_city.replace(" ","+")
    
    # Build query URL
    query_url = f"{url}appid={weather_api_key}&q={target_city}&units=imperial"
    
    # Use URL to make a request of information, bring back in the json format, and print URL
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    print(f"Currently on {(target + 1)} out of {(len(weather_df.index))} |::| City: {display_city}, {display_country}")

    
    # This will collect and store desired information, but if there is an error it will print a line and move on to next
    try:
        cities_temp = weather_json["main"]["temp"]
        temperature_list.append(cities_temp)
        
        cities_humid = weather_json["main"]["humidity"]
        humidity_list.append(cities_humid)
        
        cities_cloud = weather_json["clouds"]["all"]
        cloudiness_list.append(cities_cloud)
        
        cities_wind = weather_json["wind"]["speed"]
        wind_speed_list.append(cities_wind)
        
        cities_date = weather_json["dt"]
        date_list.append(cities_date)
        
        cities_lat_update = weather_json["coord"]["lat"]
        latitude_list_v2.append(cities_lat_update)
        
        cities_long_update = weather_json["coord"]["lon"]
        longitude_list_v2.append(cities_long_update)
        
        cities_city_update = weather_json["name"]
        city_list_v2.append(cities_city_update)
        
        cities_con_update = weather_json["sys"]["country"]       
        country_list_v2.append(cities_con_update)
        
    except:
        print("I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.")
        
        # Usuccessful API request will result in a blank value in list that will throw off list alignment
        # We will but in a dummy value in its place to clean out later
        temperature_list.append("Error")
        humidity_list.append("Error")
        cloudiness_list.append("Error")
        wind_speed_list.append("Error")
        date_list.append("Error")
        latitude_list_v2.append("Error")
        longitude_list_v2.append("Error")
        city_list_v2.append("Error")
        country_list_v2.append("Error")
        
        
    print()
    
    # Add a sleep timer to prevent my API requests from going over 60 per min and causing a 1 hour lock out.
    time.sleep(1) # in seconds
# Out:
# Currently on 1 out of 1400 |::| City: Illoqqortoormiut, GL
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 2 out of 1400 |::| City: Irbeyskoye, RU
#
# Currently on 3 out of 1400 |::| City: Saint-Philippe, RE
#
# Currently on 4 out of 1400 |::| City: Hobart, AU
#
# Currently on 5 out of 1400 |::| City: Hermanus, ZA
#
# Currently on 6 out of 1400 |::| City: Bredasdorp, ZA
#
# Currently on 7 out of 1400 |::| City: Castro, CL
#
# Currently on 8 out of 1400 |::| City: Ushuaia, AR
#
# Currently on 9 out of 1400 |::| City: Haikou, CN
#
# Currently on 10 out of 1400 |::| City: Yellowknife, CA
#
# Currently on 11 out of 1400 |::| City: Tramandai, BR
#
# Currently on 12 out of 1400 |::| City: Awjilah, LY
#
# Currently on 13 out of 1400 |::| City: Paamiut, GL
#
# Currently on 14 out of 1400 |::| City: Saskylakh, RU
#
# Currently on 15 out of 1400 |::| City: Mataura, PF
#
# Currently on 16 out of 1400 |::| City: Tabiauea, KI
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 17 out of 1400 |::| City: Qaanaaq, GL
#
# Currently on 18 out of 1400 |::| City: Norman Wells, CA
#
# Currently on 19 out of 1400 |::| City: Atuona, PF
#
# Currently on 20 out of 1400 |::| City: Taolanaro, MG
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 21 out of 1400 |::| City: Klaksvik, FO
#
# Currently on 22 out of 1400 |::| City: Janauba, BR
#
# Currently on 23 out of 1400 |::| City: Sitka, US
#
# Currently on 24 out of 1400 |::| City: Tasiilaq, GL
#
# Currently on 25 out of 1400 |::| City: Arlit, NE
#
# Currently on 26 out of 1400 |::| City: Jamestown, SH
#
# Currently on 27 out of 1400 |::| City: Kindu, CD
#
# Currently on 28 out of 1400 |::| City: Mahebourg, MU
#
# Currently on 29 out of 1400 |::| City: Otane, NZ
#
# Currently on 30 out of 1400 |::| City: Nikolskoye, RU
#
# Currently on 31 out of 1400 |::| City: Sinnamary, GF
#
# Currently on 32 out of 1400 |::| City: Amuntai, ID
#
# Currently on 33 out of 1400 |::| City: Rebrikha, RU
#
# Currently on 34 out of 1400 |::| City: Trinidad, US
#
# Currently on 35 out of 1400 |::| City: Ayan, RU
#
# Currently on 36 out of 1400 |::| City: Gannan, CN
#
# Currently on 37 out of 1400 |::| City: Bolungarvik, IS
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 38 out of 1400 |::| City: Asfi, MA
#
# Currently on 39 out of 1400 |::| City: Vardo, NO
#
# Currently on 40 out of 1400 |::| City: Hithadhoo, MV
#
# Currently on 41 out of 1400 |::| City: Busselton, AU
#
# Currently on 42 out of 1400 |::| City: Ailigandi, PA
#
# Currently on 43 out of 1400 |::| City: Saleaula, WS
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 44 out of 1400 |::| City: Aquiraz, BR
#
# Currently on 45 out of 1400 |::| City: Socorro, US
#
# Currently on 46 out of 1400 |::| City: Puerto Ayora, EC
#
# Currently on 47 out of 1400 |::| City: Porto Novo, CV
#
# Currently on 48 out of 1400 |::| City: Bairiki, KI
#
# Currently on 49 out of 1400 |::| City: Tommot, RU
#
# Currently on 50 out of 1400 |::| City: Upernavik, GL
#
# Currently on 51 out of 1400 |::| City: Kishi, NG
#
# Currently on 52 out of 1400 |::| City: Kurumkan, RU
#
# Currently on 53 out of 1400 |::| City: Albany, AU
#
# Currently on 54 out of 1400 |::| City: Omsukchan, RU
#
# Currently on 55 out of 1400 |::| City: Nanortalik, GL
#
# Currently on 56 out of 1400 |::| City: Berbera, SO
#
# Currently on 57 out of 1400 |::| City: Manicore, BR
#
# Currently on 58 out of 1400 |::| City: Barrow, US
#
# Currently on 59 out of 1400 |::| City: Rikitea, PF
#
# Currently on 60 out of 1400 |::| City: Sentyabrskiy, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 61 out of 1400 |::| City: Bambous Virieux, MU
#
# Currently on 62 out of 1400 |::| City: Vaini, TO
#
# Currently on 63 out of 1400 |::| City: Kapaa, US
#
# Currently on 64 out of 1400 |::| City: Skaerbaek, DK
#
# Currently on 65 out of 1400 |::| City: Komsomolskiy, RU
#
# Currently on 66 out of 1400 |::| City: Butaritari, KI
#
# Currently on 67 out of 1400 |::| City: Saldanha, ZA
#
# Currently on 68 out of 1400 |::| City: Winston, US
#
# Currently on 69 out of 1400 |::| City: Guiratinga, BR
#
# Currently on 70 out of 1400 |::| City: Labuhan, ID
#
# Currently on 71 out of 1400 |::| City: Ponta Do Sol, CV
#
# Currently on 72 out of 1400 |::| City: Fairbanks, US
#
# Currently on 73 out of 1400 |::| City: Mayo, CA
#
# Currently on 74 out of 1400 |::| City: Tsiroanomandidy, MG
#
# Currently on 75 out of 1400 |::| City: Kruisfontein, ZA
#
# Currently on 76 out of 1400 |::| City: Chapais, CA
#
# Currently on 77 out of 1400 |::| City: Olafsvik, IS
#
# Currently on 78 out of 1400 |::| City: Baykit, RU
#
# Currently on 79 out of 1400 |::| City: Saint-Augustin, CA
#
# Currently on 80 out of 1400 |::| City: Kodiak, US
#
# Currently on 81 out of 1400 |::| City: Hasaki, JP
#
# Currently on 82 out of 1400 |::| City: Avarua, CK
#
# Currently on 83 out of 1400 |::| City: Grand River South East, MU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 84 out of 1400 |::| City: Bilma, NE
#
# Currently on 85 out of 1400 |::| City: Kieta, PG
#
# Currently on 86 out of 1400 |::| City: New Norfolk, AU
#
# Currently on 87 out of 1400 |::| City: Huarmey, PE
#
# Currently on 88 out of 1400 |::| City: Saint-Louis, SN
#
# Currently on 89 out of 1400 |::| City: Polyarnyy, RU
#
# Currently on 90 out of 1400 |::| City: Juneau, US
#
# Currently on 91 out of 1400 |::| City: Broken Hill, AU
#
# Currently on 92 out of 1400 |::| City: Vanavara, RU
#
# Currently on 93 out of 1400 |::| City: Gushikawa, JP
#
# Currently on 94 out of 1400 |::| City: Sioux Lookout, CA
#
# Currently on 95 out of 1400 |::| City: Constitucion, MX
#
# Currently on 96 out of 1400 |::| City: Dikson, RU
#
# Currently on 97 out of 1400 |::| City: Longyearbyen, SJ
#
# Currently on 98 out of 1400 |::| City: Marks, RU
#
# Currently on 99 out of 1400 |::| City: Bathsheba, BB
#
# Currently on 100 out of 1400 |::| City: Port Lincoln, AU
#
# Currently on 101 out of 1400 |::| City: Udachnyy, RU
#
# Currently on 102 out of 1400 |::| City: Hailar, CN
#
# Currently on 103 out of 1400 |::| City: Talas, KG
#
# Currently on 104 out of 1400 |::| City: Riviere-Au-Renard, CA
#
# Currently on 105 out of 1400 |::| City: Luanda, AO
#
# Currently on 106 out of 1400 |::| City: Ribeira Grande, PT
#
# Currently on 107 out of 1400 |::| City: Vaovai, WS
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 108 out of 1400 |::| City: Chuy, UY
#
# Currently on 109 out of 1400 |::| City: Hilo, US
#
# Currently on 110 out of 1400 |::| City: Port Hedland, AU
#
# Currently on 111 out of 1400 |::| City: Maceio, BR
#
# Currently on 112 out of 1400 |::| City: Sistranda, NO
#
# Currently on 113 out of 1400 |::| City: Esperance, AU
#
# Currently on 114 out of 1400 |::| City: Makakilo City, US
#
# Currently on 115 out of 1400 |::| City: Rodez, FR
#
# Currently on 116 out of 1400 |::| City: Samusu, WS
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 117 out of 1400 |::| City: Krasnoselkup, RU
#
# Currently on 118 out of 1400 |::| City: Provideniya, RU
#
# Currently on 119 out of 1400 |::| City: Haibowan, CN
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 120 out of 1400 |::| City: Soanierana Ivongo, MG
#
# Currently on 121 out of 1400 |::| City: Tocopilla, CL
#
# Currently on 122 out of 1400 |::| City: Abha, SA
#
# Currently on 123 out of 1400 |::| City: Norden, DE
#
# Currently on 124 out of 1400 |::| City: Salalah, OM
#
# Currently on 125 out of 1400 |::| City: Bluff, NZ
#
# Currently on 126 out of 1400 |::| City: Rawannawi, KI
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 127 out of 1400 |::| City: Tessalit, ML
#
# Currently on 128 out of 1400 |::| City: Jedrzejow, PL
#
# Currently on 129 out of 1400 |::| City: Ambositra, MG
#
# Currently on 130 out of 1400 |::| City: Rawson, AR
#
# Currently on 131 out of 1400 |::| City: Vestmannaeyjar, IS
#
# Currently on 132 out of 1400 |::| City: Liepaja, LV
#
# Currently on 133 out of 1400 |::| City: Arraial Do Cabo, BR
#
# Currently on 134 out of 1400 |::| City: Westerland, DE
# Currently on 135 out of 1400 |::| City: Margate, ZA
#
# Currently on 136 out of 1400 |::| City: Gorno-Altaysk, RU
#
# Currently on 137 out of 1400 |::| City: Stornoway, GB
#
# Currently on 138 out of 1400 |::| City: Tsihombe, MG
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 139 out of 1400 |::| City: San Rafael, AR
#
# Currently on 140 out of 1400 |::| City: Havre-Saint-Pierre, CA
#
# Currently on 141 out of 1400 |::| City: Punta Arenas, CL
#
# Currently on 142 out of 1400 |::| City: Vila Franca Do Campo, PT
#
# Currently on 143 out of 1400 |::| City: Caravelas, BR
#
# Currently on 144 out of 1400 |::| City: Thompson, CA
#
# Currently on 145 out of 1400 |::| City: Solikamsk, RU
#
# Currently on 146 out of 1400 |::| City: Carnarvon, AU
#
# Currently on 147 out of 1400 |::| City: Vizinga, RU
#
# Currently on 148 out of 1400 |::| City: Zhanaozen, KZ
#
# Currently on 149 out of 1400 |::| City: Klyuchi, RU
#
# Currently on 150 out of 1400 |::| City: Kalamata, GR
#
# Currently on 151 out of 1400 |::| City: Fort Nelson, CA
#
# Currently on 152 out of 1400 |::| City: Amderma, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 153 out of 1400 |::| City: Viligili, MV
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 154 out of 1400 |::| City: Belaya Gora, RU
#
# Currently on 155 out of 1400 |::| City: Aflu, DZ
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 156 out of 1400 |::| City: Edd, ER
#
# Currently on 157 out of 1400 |::| City: Tuktoyaktuk, CA
#
# Currently on 158 out of 1400 |::| City: Cherskiy, RU
#
# Currently on 159 out of 1400 |::| City: Cabedelo, BR
#
# Currently on 160 out of 1400 |::| City: Richards Bay, ZA
#
# Currently on 161 out of 1400 |::| City: Balabac, PH
#
# Currently on 162 out of 1400 |::| City: Marystown, CA
#
# Currently on 163 out of 1400 |::| City: Isangel, VU
#
# Currently on 164 out of 1400 |::| City: Warqla, DZ
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 165 out of 1400 |::| City: San Patricio, MX
#
# Currently on 166 out of 1400 |::| City: Cape Town, ZA
#
# Currently on 167 out of 1400 |::| City: Neiafu, TO
#
# Currently on 168 out of 1400 |::| City: Louisbourg, CA
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 169 out of 1400 |::| City: Georgetown, SH
#
# Currently on 170 out of 1400 |::| City: Bacolod, PH
#
# Currently on 171 out of 1400 |::| City: Severo-Kurilsk, RU
#
# Currently on 172 out of 1400 |::| City: Nemuro, JP
#
# Currently on 173 out of 1400 |::| City: Oussouye, SN
#
# Currently on 174 out of 1400 |::| City: Ancud, CL
#
# Currently on 175 out of 1400 |::| City: La Ronge, CA
#
# Currently on 176 out of 1400 |::| City: Palauig, PH
#
# Currently on 177 out of 1400 |::| City: Namie, JP
#
# Currently on 178 out of 1400 |::| City: Lompoc, US
#
# Currently on 179 out of 1400 |::| City: Lakes Entrance, AU
#
# Currently on 180 out of 1400 |::| City: Quelimane, MZ
#
# Currently on 181 out of 1400 |::| City: Ilulissat, GL
#
# Currently on 182 out of 1400 |::| City: Tabialan, PH
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 183 out of 1400 |::| City: Port Elizabeth, ZA
#
# Currently on 184 out of 1400 |::| City: Bacuit, PH
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 185 out of 1400 |::| City: La Peca, PE
#
# Currently on 186 out of 1400 |::| City: Skovorodino, RU
#
# Currently on 187 out of 1400 |::| City: Beaupre, CA
#
# Currently on 188 out of 1400 |::| City: Maymanak, UZ
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 189 out of 1400 |::| City: Mahanoro, MG
#
# Currently on 190 out of 1400 |::| City: Sahrak, AF
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 191 out of 1400 |::| City: Grindavik, IS
#
# Currently on 192 out of 1400 |::| City: Kuche, CN
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 193 out of 1400 |::| City: Heihe, CN
#
# Currently on 194 out of 1400 |::| City: Savannah Bight, HN
#
# Currently on 195 out of 1400 |::| City: Perbaungan, ID
#
# Currently on 196 out of 1400 |::| City: Lawton, US
#
# Currently on 197 out of 1400 |::| City: Rocha, UY
#
# Currently on 198 out of 1400 |::| City: Mar Del Plata, AR
#
# Currently on 199 out of 1400 |::| City: Chokurdakh, RU
#
# Currently on 200 out of 1400 |::| City: Emerald, AU
#
# Currently on 201 out of 1400 |::| City: Srednekolymsk, RU
#
# Currently on 202 out of 1400 |::| City: Ajaccio, FR
#
# Currently on 203 out of 1400 |::| City: Korcula, HR
#
# Currently on 204 out of 1400 |::| City: East London, ZA
#
# Currently on 205 out of 1400 |::| City: Eyl, SO
#
# Currently on 206 out of 1400 |::| City: Utiroa, KI
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 207 out of 1400 |::| City: Bahir Dar, ET
#
# Currently on 208 out of 1400 |::| City: Kalmunai, LK
#
# Currently on 209 out of 1400 |::| City: Kaitangata, NZ
#
# Currently on 210 out of 1400 |::| City: Simpang, ID
#
# Currently on 211 out of 1400 |::| City: Vaitupu, WF
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 212 out of 1400 |::| City: Dalton, US
#
# Currently on 213 out of 1400 |::| City: Mpigi, UG
#
# Currently on 214 out of 1400 |::| City: Tomatlan, MX
#
# Currently on 215 out of 1400 |::| City: Krasnovishersk, RU
#
# Currently on 216 out of 1400 |::| City: Port Blair, IN
#
# Currently on 217 out of 1400 |::| City: Bethel, US
#
# Currently on 218 out of 1400 |::| City: Vancouver, CA
#
# Currently on 219 out of 1400 |::| City: Guabito, PA
#
# Currently on 220 out of 1400 |::| City: Belushya Guba, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 221 out of 1400 |::| City: Baruun-Urt, MN
#
# Currently on 222 out of 1400 |::| City: Buin, PG
#
# Currently on 223 out of 1400 |::| City: Kununurra, AU
#
# Currently on 224 out of 1400 |::| City: Burica, PA
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 225 out of 1400 |::| City: Yashalta, RU
#
# Currently on 226 out of 1400 |::| City: Yanam, IN
#
# Currently on 227 out of 1400 |::| City: Bayir, JO
#
# Currently on 228 out of 1400 |::| City: Senno, BY
#
# Currently on 229 out of 1400 |::| City: Zyryanka, RU
#
# Currently on 230 out of 1400 |::| City: Iralaya, HN
#
# Currently on 231 out of 1400 |::| City: Oktyabrskiy, RU
#
# Currently on 232 out of 1400 |::| City: Odienne, CI
#
# Currently on 233 out of 1400 |::| City: Palmer, US
#
# Currently on 234 out of 1400 |::| City: Taoudenni, ML
#
# Currently on 235 out of 1400 |::| City: Coquimbo, CL
#
# Currently on 236 out of 1400 |::| City: Barentsburg, SJ
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 237 out of 1400 |::| City: Zakamensk, RU
#
# Currently on 238 out of 1400 |::| City: Petrykivka, UA
#
# Currently on 239 out of 1400 |::| City: Markala, ML
#
# Currently on 240 out of 1400 |::| City: Egyek, HU
#
# Currently on 241 out of 1400 |::| City: Pisco, PE
#
# Currently on 242 out of 1400 |::| City: Naze, JP
#
# Currently on 243 out of 1400 |::| City: Hofn, IS
#
# Currently on 244 out of 1400 |::| City: Ughelli, NG
#
# Currently on 245 out of 1400 |::| City: Pevek, RU
#
# Currently on 246 out of 1400 |::| City: Dyshne-Vedeno, RU
#
# Currently on 247 out of 1400 |::| City: Port Alfred, ZA
#
# Currently on 248 out of 1400 |::| City: Miles City, US
#
# Currently on 249 out of 1400 |::| City: Valdivia, CL
#
# Currently on 250 out of 1400 |::| City: Schmallenberg, DE
#
# Currently on 251 out of 1400 |::| City: Enterprise, US
#
# Currently on 252 out of 1400 |::| City: Solnechnyy, RU
#
# Currently on 253 out of 1400 |::| City: Valparaiso, CL
#
# Currently on 254 out of 1400 |::| City: Itaituba, BR
#
# Currently on 255 out of 1400 |::| City: Diamantina, BR
#
# Currently on 256 out of 1400 |::| City: North Platte, US
#
# Currently on 257 out of 1400 |::| City: Camacha, PT
#
# Currently on 258 out of 1400 |::| City: Dunedin, NZ
# Currently on 259 out of 1400 |::| City: Pontianak, ID
#
# Currently on 260 out of 1400 |::| City: Karratha, AU
#
# Currently on 261 out of 1400 |::| City: San Quintin, MX
#
# Currently on 262 out of 1400 |::| City: Coahuayana, MX
#
# Currently on 263 out of 1400 |::| City: Adrar, DZ
#
# Currently on 264 out of 1400 |::| City: Ayorou, NE
#
# Currently on 265 out of 1400 |::| City: Severnoye, RU
#
# Currently on 266 out of 1400 |::| City: Cockburn Town, TC
#
# Currently on 267 out of 1400 |::| City: Khatanga, RU
#
# Currently on 268 out of 1400 |::| City: Morant Bay, JM
#
# Currently on 269 out of 1400 |::| City: Nizhneyansk, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 270 out of 1400 |::| City: Seymchan, RU
#
# Currently on 271 out of 1400 |::| City: Orangeburg, US
#
# Currently on 272 out of 1400 |::| City: Prince Rupert, CA
#
# Currently on 273 out of 1400 |::| City: Sterling, US
#
# Currently on 274 out of 1400 |::| City: Teguise, ES
#
# Currently on 275 out of 1400 |::| City: Hamilton, BM
#
# Currently on 276 out of 1400 |::| City: Geraldton, AU
#
# Currently on 277 out of 1400 |::| City: Faanui, PF
#
# Currently on 278 out of 1400 |::| City: Wajima, JP
#
# Currently on 279 out of 1400 |::| City: Mys Shmidta, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 280 out of 1400 |::| City: Outlook, CA
#
# Currently on 281 out of 1400 |::| City: Tuatapere, NZ
#
# Currently on 282 out of 1400 |::| City: Lumeje, AO
#
# Currently on 283 out of 1400 |::| City: Kavieng, PG
#
# Currently on 284 out of 1400 |::| City: Zhangye, CN
#
# Currently on 285 out of 1400 |::| City: Purranque, CL
#
# Currently on 286 out of 1400 |::| City: Iqaluit, CA
#
# Currently on 287 out of 1400 |::| City: Pokhara, NP
#
# Currently on 288 out of 1400 |::| City: Nampula, MZ
#
# Currently on 289 out of 1400 |::| City: Vassouras, BR
#
# Currently on 290 out of 1400 |::| City: Ambilobe, MG
#
# Currently on 291 out of 1400 |::| City: Victoria, SC
#
# Currently on 292 out of 1400 |::| City: Sharjah, AE
#
# Currently on 293 out of 1400 |::| City: San Carlos De Bariloche, AR
#
# Currently on 294 out of 1400 |::| City: Lagunas, PE
#
# Currently on 295 out of 1400 |::| City: Sibolga, ID
#
# Currently on 296 out of 1400 |::| City: Safwah, SA
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 297 out of 1400 |::| City: Kirakira, SB
#
# Currently on 298 out of 1400 |::| City: Fortuna, US
#
# Currently on 299 out of 1400 |::| City: Los Llanos De Aridane, ES
#
# Currently on 300 out of 1400 |::| City: Cobija, BO
#
# Currently on 301 out of 1400 |::| City: Ternate, ID
#
# Currently on 302 out of 1400 |::| City: Hervey Bay, AU
#
# Currently on 303 out of 1400 |::| City: Saint-Pierre, RE
#
# Currently on 304 out of 1400 |::| City: Trairi, BR
#
# Currently on 305 out of 1400 |::| City: Kahului, US
#
# Currently on 306 out of 1400 |::| City: Yerbogachen, RU
#
# Currently on 307 out of 1400 |::| City: Kaeo, NZ
#
# Currently on 308 out of 1400 |::| City: Souillac, MU
#
# Currently on 309 out of 1400 |::| City: Guerrero Negro, MX
#
# Currently on 310 out of 1400 |::| City: Voula, GR
#
# Currently on 311 out of 1400 |::| City: Henties Bay, NA
#
# Currently on 312 out of 1400 |::| City: Alma, US
#
# Currently on 313 out of 1400 |::| City: Lorengau, PG
#
# Currently on 314 out of 1400 |::| City: Toamasina, MG
#
# Currently on 315 out of 1400 |::| City: Acapulco, MX
#
# Currently on 316 out of 1400 |::| City: Yar-Sale, RU
#
# Currently on 317 out of 1400 |::| City: Sakassou, CI
#
# Currently on 318 out of 1400 |::| City: Kita, ML
#
# Currently on 319 out of 1400 |::| City: Viedma, AR
#
# Currently on 320 out of 1400 |::| City: Cabo San Lucas, MX
#
# Currently on 321 out of 1400 |::| City: Nouadhibou, MR
#
# Currently on 322 out of 1400 |::| City: Airai, PW
#
# Currently on 323 out of 1400 |::| City: Deputatskiy, RU
#
# Currently on 324 out of 1400 |::| City: Riyadh, SA
#
# Currently on 325 out of 1400 |::| City: Aktas, KZ
#
# Currently on 326 out of 1400 |::| City: Lobito, AO
#
# Currently on 327 out of 1400 |::| City: Atambua, ID
#
# Currently on 328 out of 1400 |::| City: Cozumel, MX
#
# Currently on 329 out of 1400 |::| City: Torbay, CA
#
# Currently on 330 out of 1400 |::| City: Teeli, RU
#
# Currently on 331 out of 1400 |::| City: Chhindwara, IN
#
# Currently on 332 out of 1400 |::| City: Kadykchan, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 333 out of 1400 |::| City: Timra, SE
#
# Currently on 334 out of 1400 |::| City: Son La, VN
#
# Currently on 335 out of 1400 |::| City: Yongan, CN
#
# Currently on 336 out of 1400 |::| City: Roald, NO
#
# Currently on 337 out of 1400 |::| City: Jinchang, CN
#
# Currently on 338 out of 1400 |::| City: Bayburt, TR
#
# Currently on 339 out of 1400 |::| City: Hollola, FI
#
# Currently on 340 out of 1400 |::| City: Cowra, AU
#
# Currently on 341 out of 1400 |::| City: Cheyur, IN
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 342 out of 1400 |::| City: Khoriyion, GR
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 343 out of 1400 |::| City: Paramonga, PE
#
# Currently on 344 out of 1400 |::| City: Attawapiskat, CA
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 345 out of 1400 |::| City: Amapa, BR
#
# Currently on 346 out of 1400 |::| City: Lafiagi, NG
#
# Currently on 347 out of 1400 |::| City: Kenai, US
#
# Currently on 348 out of 1400 |::| City: Morgan City, US
#
# Currently on 349 out of 1400 |::| City: Hwange, ZW
#
# Currently on 350 out of 1400 |::| City: Gobabis, NA
#
# Currently on 351 out of 1400 |::| City: Ixtapa, MX
#
# Currently on 352 out of 1400 |::| City: Hauterive, CA
#
# Currently on 353 out of 1400 |::| City: Geraldton, CA
#
# Currently on 354 out of 1400 |::| City: Doha, KW
#
# Currently on 355 out of 1400 |::| City: Korla, CN
#
# Currently on 356 out of 1400 |::| City: Katsuura, JP
#
# Currently on 357 out of 1400 |::| City: Cidreira, BR
#
# Currently on 358 out of 1400 |::| City: Batticaloa, LK
#
# Currently on 359 out of 1400 |::| City: Yelizovo, RU
#
# Currently on 360 out of 1400 |::| City: Khani, RU
#
# Currently on 361 out of 1400 |::| City: Gat, LY
#
# Currently on 362 out of 1400 |::| City: Narsaq, GL
#
# Currently on 363 out of 1400 |::| City: Ostrovnoy, RU
#
# Currently on 364 out of 1400 |::| City: Devrek, TR
#
# Currently on 365 out of 1400 |::| City: Eureka, US
#
# Currently on 366 out of 1400 |::| City: Mount Gambier, AU
#
# Currently on 367 out of 1400 |::| City: Lavrentiya, RU
#
# Currently on 368 out of 1400 |::| City: Asau, TV
#
# Currently on 369 out of 1400 |::| City: Fukue, JP
#
# Currently on 370 out of 1400 |::| City: Bozeman, US
#
# Currently on 371 out of 1400 |::| City: San Policarpo, PH
#
# Currently on 372 out of 1400 |::| City: Romanovo, RU
#
# Currently on 373 out of 1400 |::| City: Kemijarvi, FI
#
# Currently on 374 out of 1400 |::| City: Sete, FR
#
# Currently on 375 out of 1400 |::| City: Meulaboh, ID
#
# Currently on 376 out of 1400 |::| City: Luderitz, NA
#
# Currently on 377 out of 1400 |::| City: Soc Trang, VN
#
# Currently on 378 out of 1400 |::| City: Kudahuvadhoo, MV
#
# Currently on 379 out of 1400 |::| City: Paracuru, BR
#
# Currently on 380 out of 1400 |::| City: Nabire, ID
#
# Currently on 381 out of 1400 |::| City: Nuzvid, IN
#
# Currently on 382 out of 1400 |::| City: Hovd, MN
#
# Currently on 383 out of 1400 |::| City: Ishigaki, JP
#
# Currently on 384 out of 1400 |::| City: Zambezi, ZM
#
# Currently on 385 out of 1400 |::| City: Ponta Delgada, PT
#
# Currently on 386 out of 1400 |::| City: Nome, US
#
# Currently on 387 out of 1400 |::| City: Zhuhai, CN
#
# Currently on 388 out of 1400 |::| City: Umea, SE
#
# Currently on 389 out of 1400 |::| City: Neyshabur, IR
#
# Currently on 390 out of 1400 |::| City: Mount Isa, AU
#
# Currently on 391 out of 1400 |::| City: Satinka, RU
#
# Currently on 392 out of 1400 |::| City: Barcelona, VE
#
# Currently on 393 out of 1400 |::| City: Khandyga, RU
#
# Currently on 394 out of 1400 |::| City: Karauzyak, UZ
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 395 out of 1400 |::| City: Lahaina, US
#
# Currently on 396 out of 1400 |::| City: Katobu, ID
#
# Currently on 397 out of 1400 |::| City: Kyzyl-Suu, KG
# Currently on 398 out of 1400 |::| City: Ranong, TH
#
# Currently on 399 out of 1400 |::| City: Pasighat, IN
#
# Currently on 400 out of 1400 |::| City: Dolores, AR
#
# Currently on 401 out of 1400 |::| City: Altay, CN
#
# Currently on 402 out of 1400 |::| City: Saint-Joseph, RE
#
# Currently on 403 out of 1400 |::| City: Bengkulu, ID
#
# Currently on 404 out of 1400 |::| City: Namibe, AO
#
# Currently on 405 out of 1400 |::| City: Sao Joao Da Barra, BR
#
# Currently on 406 out of 1400 |::| City: Belyy Yar, RU
#
# Currently on 407 out of 1400 |::| City: Dublin, US
#
# Currently on 408 out of 1400 |::| City: Mattoon, US
#
# Currently on 409 out of 1400 |::| City: Crab Hill, BB
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 410 out of 1400 |::| City: Saint-Pierre, PM
#
# Currently on 411 out of 1400 |::| City: Altagracia De Orituco, VE
#
# Currently on 412 out of 1400 |::| City: Gonbad-E Qabus, IR
#
# Currently on 413 out of 1400 |::| City: Elko, US
#
# Currently on 414 out of 1400 |::| City: Benbrook, US
#
# Currently on 415 out of 1400 |::| City: Portland, AU
#
# Currently on 416 out of 1400 |::| City: Monte Carmelo, BR
#
# Currently on 417 out of 1400 |::| City: Uyuni, BO
#
# Currently on 418 out of 1400 |::| City: Doha, QA
#
# Currently on 419 out of 1400 |::| City: Helong, CN
#
# Currently on 420 out of 1400 |::| City: Taga, WS
#
# Currently on 421 out of 1400 |::| City: Awbari, LY
#
# Currently on 422 out of 1400 |::| City: Iquitos, PE
#
# Currently on 423 out of 1400 |::| City: Morehead, PG
#
# Currently on 424 out of 1400 |::| City: Bambanglipuro, ID
#
# Currently on 425 out of 1400 |::| City: Avera, PF
#
# Currently on 426 out of 1400 |::| City: Adwa, ET
#
# Currently on 427 out of 1400 |::| City: Yankton, US
#
# Currently on 428 out of 1400 |::| City: Atar, MR
#
# Currently on 429 out of 1400 |::| City: Kanakapura, IN
#
# Currently on 430 out of 1400 |::| City: Kisangani, CD
#
# Currently on 431 out of 1400 |::| City: Slupca, PL
#
# Currently on 432 out of 1400 |::| City: Kanniyakumari, IN
#
# Currently on 433 out of 1400 |::| City: Tigil, RU
#
# Currently on 434 out of 1400 |::| City: Yining, CN
#
# Currently on 435 out of 1400 |::| City: Wahran, DZ
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 436 out of 1400 |::| City: Vila Velha, BR
#
# Currently on 437 out of 1400 |::| City: Tiksi, RU
#
# Currently on 438 out of 1400 |::| City: Ballater, GB
#
# Currently on 439 out of 1400 |::| City: San Cristobal, EC
#
# Currently on 440 out of 1400 |::| City: Churachandpur, IN
#
# Currently on 441 out of 1400 |::| City: Boende, CD
#
# Currently on 442 out of 1400 |::| City: Ahar, IR
#
# Currently on 443 out of 1400 |::| City: Saquarema, BR
#
# Currently on 444 out of 1400 |::| City: Uppsala, SE
#
# Currently on 445 out of 1400 |::| City: Jos, NG
#
# Currently on 446 out of 1400 |::| City: Logansport, US
#
# Currently on 447 out of 1400 |::| City: Faya, TD
#
# Currently on 448 out of 1400 |::| City: Natal, BR
#
# Currently on 449 out of 1400 |::| City: Clyde River, CA
#
# Currently on 450 out of 1400 |::| City: Midland, US
#
# Currently on 451 out of 1400 |::| City: Karema, TZ
#
# Currently on 452 out of 1400 |::| City: Murakami, JP
#
# Currently on 453 out of 1400 |::| City: Whitianga, NZ
#
# Currently on 454 out of 1400 |::| City: Lamu, KE
#
# Currently on 455 out of 1400 |::| City: Maloshuyka, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 456 out of 1400 |::| City: Sao Cristovao, BR
#
# Currently on 457 out of 1400 |::| City: Esna, EG
#
# Currently on 458 out of 1400 |::| City: Codrington, AG
#
# Currently on 459 out of 1400 |::| City: Tautira, PF
#
# Currently on 460 out of 1400 |::| City: Tabou, CI
#
# Currently on 461 out of 1400 |::| City: Barra Do Garcas, BR
#
# Currently on 462 out of 1400 |::| City: Alofi, NU
#
# Currently on 463 out of 1400 |::| City: Gisborne, NZ
#
# Currently on 464 out of 1400 |::| City: Mayang Imphal, IN
#
# Currently on 465 out of 1400 |::| City: Tshikapa, CD
#
# Currently on 466 out of 1400 |::| City: Batagay-Alyta, RU
#
# Currently on 467 out of 1400 |::| City: Sorland, NO
#
# Currently on 468 out of 1400 |::| City: Wanaka, NZ
#
# Currently on 469 out of 1400 |::| City: Qui Nhon, VN
#
# Currently on 470 out of 1400 |::| City: Senaki, GE
#
# Currently on 471 out of 1400 |::| City: Nguiu, AU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 472 out of 1400 |::| City: Watsa, CD
#
# Currently on 473 out of 1400 |::| City: Bullhead City, US
#
# Currently on 474 out of 1400 |::| City: Trincomalee, LK
#
# Currently on 475 out of 1400 |::| City: Cayenne, GF
#
# Currently on 476 out of 1400 |::| City: Sao Filipe, CV
#
# Currently on 477 out of 1400 |::| City: Mancio Lima, BR
#
# Currently on 478 out of 1400 |::| City: Saint-Francois, GP
#
# Currently on 479 out of 1400 |::| City: Mahajanga, MG
#
# Currently on 480 out of 1400 |::| City: Evensk, RU
#
# Currently on 481 out of 1400 |::| City: Egvekinot, RU
#
# Currently on 482 out of 1400 |::| City: Moindou, NC
#
# Currently on 483 out of 1400 |::| City: Lata, SB
#
# Currently on 484 out of 1400 |::| City: Vestmanna, FO
#
# Currently on 485 out of 1400 |::| City: Tabuk, SA
#
# Currently on 486 out of 1400 |::| City: Elliot Lake, CA
#
# Currently on 487 out of 1400 |::| City: Balingasay, PH
#
# Currently on 488 out of 1400 |::| City: Baiyin, CN
#
# Currently on 489 out of 1400 |::| City: Port-Gentil, GA
#
# Currently on 490 out of 1400 |::| City: Ankazoabo, MG
#
# Currently on 491 out of 1400 |::| City: Porto Recanati, IT
#
# Currently on 492 out of 1400 |::| City: Inirida, CO
#
# Currently on 493 out of 1400 |::| City: Nuuk, GL
#
# Currently on 494 out of 1400 |::| City: Kovdor, RU
#
# Currently on 495 out of 1400 |::| City: Rochester, US
#
# Currently on 496 out of 1400 |::| City: Beyneu, KZ
#
# Currently on 497 out of 1400 |::| City: Sorong, ID
#
# Currently on 498 out of 1400 |::| City: Mamallapuram, IN
#
# Currently on 499 out of 1400 |::| City: Karachev, RU
#
# Currently on 500 out of 1400 |::| City: Purnia, IN
#
# Currently on 501 out of 1400 |::| City: Nishihara, JP
#
# Currently on 502 out of 1400 |::| City: Taloda, IN
#
# Currently on 503 out of 1400 |::| City: Lebu, CL
#
# Currently on 504 out of 1400 |::| City: Galesong, ID
#
# Currently on 505 out of 1400 |::| City: Nador, MA
#
# Currently on 506 out of 1400 |::| City: Nokaneng, BW
#
# Currently on 507 out of 1400 |::| City: Sartell, US
#
# Currently on 508 out of 1400 |::| City: Puerto El Triunfo, SV
#
# Currently on 509 out of 1400 |::| City: Vitoria Do Mearim, BR
#
# Currently on 510 out of 1400 |::| City: Brus Laguna, HN
#
# Currently on 511 out of 1400 |::| City: Port Hardy, CA
#
# Currently on 512 out of 1400 |::| City: Ust-Koksa, RU
#
# Currently on 513 out of 1400 |::| City: Talnakh, RU
#
# Currently on 514 out of 1400 |::| City: Grand Centre, CA
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 515 out of 1400 |::| City: Aljezur, PT
#
# Currently on 516 out of 1400 |::| City: Bacsalmas, HU
#
# Currently on 517 out of 1400 |::| City: Shuyskoye, RU
#
# Currently on 518 out of 1400 |::| City: Jieshi, CN
#
# Currently on 519 out of 1400 |::| City: Penha, BR
#
# Currently on 520 out of 1400 |::| City: Aksarayskiy, RU
#
# Currently on 521 out of 1400 |::| City: Tursunzoda, TJ
#
# Currently on 522 out of 1400 |::| City: Tilichiki, RU
#
# Currently on 523 out of 1400 |::| City: Linchuan, CN
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 524 out of 1400 |::| City: Kawasaki, JP
#
# Currently on 525 out of 1400 |::| City: Coihaique, CL
#
# Currently on 526 out of 1400 |::| City: Kodinsk, RU
#
# Currently on 527 out of 1400 |::| City: Matara, LK
#
# Currently on 528 out of 1400 |::| City: Okakarara, NA
#
# Currently on 529 out of 1400 |::| City: Tubruq, LY
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 530 out of 1400 |::| City: Manzhouli, CN
#
# Currently on 531 out of 1400 |::| City: Itoman, JP
#
# Currently on 532 out of 1400 |::| City: Redmond, US
#
# Currently on 533 out of 1400 |::| City: Koungou, YT
#
# Currently on 534 out of 1400 |::| City: Jimeta, NG
#
# Currently on 535 out of 1400 |::| City: Usinsk, RU
#
# Currently on 536 out of 1400 |::| City: Karkaralinsk, KZ
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
# Currently on 537 out of 1400 |::| City: Balakhninskiy, RU
#
# Currently on 538 out of 1400 |::| City: Talara, PE
#
# Currently on 539 out of 1400 |::| City: Micheweni, TZ
#
# Currently on 540 out of 1400 |::| City: Alice Springs, AU
#
# Currently on 541 out of 1400 |::| City: Bagan, RU
#
# Currently on 542 out of 1400 |::| City: Contai, IN
#
# Currently on 543 out of 1400 |::| City: Poum, NC
#
# Currently on 544 out of 1400 |::| City: Denpasar, ID
#
# Currently on 545 out of 1400 |::| City: Sept-Iles, CA
#
# Currently on 546 out of 1400 |::| City: Sao Miguel Do Oeste, BR
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 547 out of 1400 |::| City: Ust-Nera, RU
#
# Currently on 548 out of 1400 |::| City: Verkhoyansk, RU
#
# Currently on 549 out of 1400 |::| City: Bougouni, ML
#
# Currently on 550 out of 1400 |::| City: Chara, RU
#
# Currently on 551 out of 1400 |::| City: Samarai, PG
#
# Currently on 552 out of 1400 |::| City: Babanusah, SD
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 553 out of 1400 |::| City: Atsiki, GR
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 554 out of 1400 |::| City: Lagoa, PT
#
# Currently on 555 out of 1400 |::| City: Le Vauclin, MQ
#
# Currently on 556 out of 1400 |::| City: Pochutla, MX
#
# Currently on 557 out of 1400 |::| City: Novovasylivka, UA
#
# Currently on 558 out of 1400 |::| City: Acari, PE
#
# Currently on 559 out of 1400 |::| City: Boguchany, RU
#
# Currently on 560 out of 1400 |::| City: Hachinohe, JP
#
# Currently on 561 out of 1400 |::| City: Vostok, RU
#
# Currently on 562 out of 1400 |::| City: Tateyama, JP
#
# Currently on 563 out of 1400 |::| City: Vao, NC
#
# Currently on 564 out of 1400 |::| City: Manhattan, US
#
# Currently on 565 out of 1400 |::| City: Rio Grande, BR
#
# Currently on 566 out of 1400 |::| City: Nicoya, CR
#
# Currently on 567 out of 1400 |::| City: Te Anau, NZ
#
# Currently on 568 out of 1400 |::| City: Taltal, CL
#
# Currently on 569 out of 1400 |::| City: Quatre Cocos, MU
#
# Currently on 570 out of 1400 |::| City: Andros Town, BS
#
# Currently on 571 out of 1400 |::| City: Brawley, US
#
# Currently on 572 out of 1400 |::| City: Bundaberg, AU
#
# Currently on 573 out of 1400 |::| City: Joshimath, IN
#
# Currently on 574 out of 1400 |::| City: Kashan, IR
#
# Currently on 575 out of 1400 |::| City: Tuysarkan, IR
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 576 out of 1400 |::| City: Broome, AU
#
# Currently on 577 out of 1400 |::| City: San Juan, US
#
# Currently on 578 out of 1400 |::| City: Arman, RU
#
# Currently on 579 out of 1400 |::| City: Saint George, BM
#
# Currently on 580 out of 1400 |::| City: Toliary, MG
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 581 out of 1400 |::| City: Bodrum, TR
#
# Currently on 582 out of 1400 |::| City: Bolshaya Orlovka, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 583 out of 1400 |::| City: Sur, OM
#
# Currently on 584 out of 1400 |::| City: Amarante Do Maranhao, BR
#
# Currently on 585 out of 1400 |::| City: Thinadhoo, MV
#
# Currently on 586 out of 1400 |::| City: Stokmarknes, NO
#
# Currently on 587 out of 1400 |::| City: Agadez, NE
#
# Currently on 588 out of 1400 |::| City: Murupara, NZ
#
# Currently on 589 out of 1400 |::| City: Marsh Harbour, BS
#
# Currently on 590 out of 1400 |::| City: Jalu, LY
#
# Currently on 591 out of 1400 |::| City: Ventspils, LV
#
# Currently on 592 out of 1400 |::| City: Witu, KE
#
# Currently on 593 out of 1400 |::| City: Zhob, PK
#
# Currently on 594 out of 1400 |::| City: Moron, MN
#
# Currently on 595 out of 1400 |::| City: Severobaykalsk, RU
#
# Currently on 596 out of 1400 |::| City: Koshurnikovo, RU
#
# Currently on 597 out of 1400 |::| City: Panzhihua, CN
#
# Currently on 598 out of 1400 |::| City: Xintai, CN
#
# Currently on 599 out of 1400 |::| City: Qaqortoq, GL
#
# Currently on 600 out of 1400 |::| City: Bosaso, SO
#
# Currently on 601 out of 1400 |::| City: Artyk, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 602 out of 1400 |::| City: Sorvag, FO
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 603 out of 1400 |::| City: Muros, ES
#
# Currently on 604 out of 1400 |::| City: Lamar, US
#
# Currently on 605 out of 1400 |::| City: San Francisco Menendez, SV
#
# Currently on 606 out of 1400 |::| City: Wanning, CN
#
# Currently on 607 out of 1400 |::| City: Sanchursk, RU
#
# Currently on 608 out of 1400 |::| City: Azar Shahr, IR
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 609 out of 1400 |::| City: Seredka, RU
#
# Currently on 610 out of 1400 |::| City: Izumo, JP
#
# Currently on 611 out of 1400 |::| City: Ondjiva, AO
#
# Currently on 612 out of 1400 |::| City: Anzio, IT
#
# Currently on 613 out of 1400 |::| City: Baker City, US
#
# Currently on 614 out of 1400 |::| City: Hit, IQ
#
# Currently on 615 out of 1400 |::| City: Hunza, PK
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 616 out of 1400 |::| City: Tres Palos, MX
#
# Currently on 617 out of 1400 |::| City: Fez, MA
#
# Currently on 618 out of 1400 |::| City: Shimoda, JP
#
# Currently on 619 out of 1400 |::| City: Manado, ID
#
# Currently on 620 out of 1400 |::| City: Chute-Aux-Outardes, CA
#
# Currently on 621 out of 1400 |::| City: Archidona, EC
#
# Currently on 622 out of 1400 |::| City: Shaoyang, CN
#
# Currently on 623 out of 1400 |::| City: Brae, GB
#
# Currently on 624 out of 1400 |::| City: Filingue, NE
#
# Currently on 625 out of 1400 |::| City: Kalaleh, IR
#
# Currently on 626 out of 1400 |::| City: Lasa, CN
#
# Currently on 627 out of 1400 |::| City: Sibenik, HR
#
# Currently on 628 out of 1400 |::| City: Toftir, FO
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 629 out of 1400 |::| City: Chipinge, ZW
#
# Currently on 630 out of 1400 |::| City: Highland Springs, US
#
# Currently on 631 out of 1400 |::| City: Auki, SB
#
# Currently on 632 out of 1400 |::| City: Verkhovazhye, RU
#
# Currently on 633 out of 1400 |::| City: La Maddalena, IT
#
# Currently on 634 out of 1400 |::| City: Meyungs, PW
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 635 out of 1400 |::| City: Omboue, GA
#
# Currently on 636 out of 1400 |::| City: Bani, DO
#
# Currently on 637 out of 1400 |::| City: Salina Cruz, MX
#
# Currently on 638 out of 1400 |::| City: Zabid, YE
#
# Currently on 639 out of 1400 |::| City: Axim, GH
#
# Currently on 640 out of 1400 |::| City: Gizo, SB
#
# Currently on 641 out of 1400 |::| City: Gasa, BT
#
# Currently on 642 out of 1400 |::| City: Gao, ML
#
# Currently on 643 out of 1400 |::| City: Bensonville, LR
#
# Currently on 644 out of 1400 |::| City: Biak, ID
#
# Currently on 645 out of 1400 |::| City: Goderich, SL
#
# Currently on 646 out of 1400 |::| City: Anklam, DE
#
# Currently on 647 out of 1400 |::| City: Anchorage, US
#
# Currently on 648 out of 1400 |::| City: Cheyenne, US
#
# Currently on 649 out of 1400 |::| City: Kloulklubed, PW
#
# Currently on 650 out of 1400 |::| City: Praia Da Vitoria, PT
#
# Currently on 651 out of 1400 |::| City: Tecoanapa, MX
#
# Currently on 652 out of 1400 |::| City: North Bend, US
#
# Currently on 653 out of 1400 |::| City: Prabumulih, ID
#
# Currently on 654 out of 1400 |::| City: Tutoia, BR
#
# Currently on 655 out of 1400 |::| City: Santa Isabel Do Rio Negro, BR
#
# Currently on 656 out of 1400 |::| City: Salinopolis, BR
#
# Currently on 657 out of 1400 |::| City: Hohhot, CN
#
# Currently on 658 out of 1400 |::| City: Verkhniy Lomov, RU
#
# Currently on 659 out of 1400 |::| City: Kathu, TH
#
# Currently on 660 out of 1400 |::| City: Pomuch, MX
#
# Currently on 661 out of 1400 |::| City: Saint Anthony, CA
#
# Currently on 662 out of 1400 |::| City: Jacareacanga, BR
#
# Currently on 663 out of 1400 |::| City: Roma, AU
#
# Currently on 664 out of 1400 |::| City: Gorontalo, ID
#
# Currently on 665 out of 1400 |::| City: Harper, LR
#
# Currently on 666 out of 1400 |::| City: Tazovskiy, RU
#
# Currently on 667 out of 1400 |::| City: Gimbi, ET
# Currently on 668 out of 1400 |::| City: Honningsvag, NO
#
# Currently on 669 out of 1400 |::| City: Salym, RU
#
# Currently on 670 out of 1400 |::| City: Dosso, NE
#
# Currently on 671 out of 1400 |::| City: Calbuco, CL
#
# Currently on 672 out of 1400 |::| City: Itarema, BR
#
# Currently on 673 out of 1400 |::| City: Manta, EC
#
# Currently on 674 out of 1400 |::| City: Osmena, PH
#
# Currently on 675 out of 1400 |::| City: Cairns, AU
#
# Currently on 676 out of 1400 |::| City: Xianshuigu, CN
#
# Currently on 677 out of 1400 |::| City: Virudunagar, IN
#
# Currently on 678 out of 1400 |::| City: Ponta Do Sol, PT
#
# Currently on 679 out of 1400 |::| City: Mandeville, US
#
# Currently on 680 out of 1400 |::| City: Grimmen, DE
#
# Currently on 681 out of 1400 |::| City: Merke, KZ
#
# Currently on 682 out of 1400 |::| City: Price, US
#
# Currently on 683 out of 1400 |::| City: Vanimo, PG
#
# Currently on 684 out of 1400 |::| City: Vaitape, PF
#
# Currently on 685 out of 1400 |::| City: Bombay, IN
#
# Currently on 686 out of 1400 |::| City: Kamaishi, JP
#
# Currently on 687 out of 1400 |::| City: Cacu, BR
#
# Currently on 688 out of 1400 |::| City: Huaiyuan, CN
#
# Currently on 689 out of 1400 |::| City: Sibu, MY
#
# Currently on 690 out of 1400 |::| City: Gamba, GA
#
# Currently on 691 out of 1400 |::| City: Bedburg, DE
#
# Currently on 692 out of 1400 |::| City: Coruripe, BR
#
# Currently on 693 out of 1400 |::| City: Sandakan, MY
#
# Currently on 694 out of 1400 |::| City: Qurunbaliyah, TN
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 695 out of 1400 |::| City: Siauliai, LT
#
# Currently on 696 out of 1400 |::| City: Quepos, CR
#
# Currently on 697 out of 1400 |::| City: Marawi, SD
#
# Currently on 698 out of 1400 |::| City: Ucluelet, CA
#
# Currently on 699 out of 1400 |::| City: Watertown, US
#
# Currently on 700 out of 1400 |::| City: Porto Walter, BR
#
# Currently on 701 out of 1400 |::| City: Idanre, NG
#
# Currently on 702 out of 1400 |::| City: Mrirt, MA
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 703 out of 1400 |::| City: Selcuk, TR
#
# Currently on 704 out of 1400 |::| City: Balimo, PG
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 705 out of 1400 |::| City: Juruti, BR
#
# Currently on 706 out of 1400 |::| City: Passa Quatro, BR
#
# Currently on 707 out of 1400 |::| City: Abu Dhabi, AE
#
# Currently on 708 out of 1400 |::| City: Berlevag, NO
#
# Currently on 709 out of 1400 |::| City: Senanga, ZM
#
# Currently on 710 out of 1400 |::| City: Batemans Bay, AU
#
# Currently on 711 out of 1400 |::| City: Pangnirtung, CA
#
# Currently on 712 out of 1400 |::| City: Synya, RU
#
# Currently on 713 out of 1400 |::| City: Palabuhanratu, ID
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 714 out of 1400 |::| City: Suruc, TR
#
# Currently on 715 out of 1400 |::| City: Pathein, MM
#
# Currently on 716 out of 1400 |::| City: Northam, AU
#
# Currently on 717 out of 1400 |::| City: Keetmanshoop, NA
#
# Currently on 718 out of 1400 |::| City: Novopokrovka, RU
#
# Currently on 719 out of 1400 |::| City: Canberra, AU
#
# Currently on 720 out of 1400 |::| City: Yaguajay, CU
#
# Currently on 721 out of 1400 |::| City: Severodvinsk, RU
#
# Currently on 722 out of 1400 |::| City: Lolua, TV
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 723 out of 1400 |::| City: Saurimo, AO
#
# Currently on 724 out of 1400 |::| City: Kabalo, CD
#
# Currently on 725 out of 1400 |::| City: Bimbo, CF
#
# Currently on 726 out of 1400 |::| City: Half Moon Bay, US
#
# Currently on 727 out of 1400 |::| City: Bandarbeyla, SO
#
# Currently on 728 out of 1400 |::| City: Camacupa, AO
#
# Currently on 729 out of 1400 |::| City: Kavaratti, IN
#
# Currently on 730 out of 1400 |::| City: Kulhudhuffushi, MV
#
# Currently on 731 out of 1400 |::| City: Madisonville, US
#
# Currently on 732 out of 1400 |::| City: Haines Junction, CA
#
# Currently on 733 out of 1400 |::| City: Bogo, CM
#
# Currently on 734 out of 1400 |::| City: Usakos, NA
#
# Currently on 735 out of 1400 |::| City: Iguape, BR
#
# Currently on 736 out of 1400 |::| City: Bestobe, KZ
#
# Currently on 737 out of 1400 |::| City: Vicksburg, US
#
# Currently on 738 out of 1400 |::| City: Maniitsoq, GL
#
# Currently on 739 out of 1400 |::| City: Brookhaven, US
#
# Currently on 740 out of 1400 |::| City: General Pico, AR
#
# Currently on 741 out of 1400 |::| City: Banjar, ID
#
# Currently on 742 out of 1400 |::| City: Mega, ET
#
# Currently on 743 out of 1400 |::| City: Mortka, RU
#
# Currently on 744 out of 1400 |::| City: Agadir, MA
#
# Currently on 745 out of 1400 |::| City: Shitanjing, CN
#
# Currently on 746 out of 1400 |::| City: Tangzhai, CN
#
# Currently on 747 out of 1400 |::| City: Teya, RU
#
# Currently on 748 out of 1400 |::| City: Grande Prairie, CA
#
# Currently on 749 out of 1400 |::| City: Balagansk, RU
#
# Currently on 750 out of 1400 |::| City: Fort Frances, CA
#
# Currently on 751 out of 1400 |::| City: Bilibino, RU
#
# Currently on 752 out of 1400 |::| City: Bajil, YE
#
# Currently on 753 out of 1400 |::| City: Panguna, PG
#
# Currently on 754 out of 1400 |::| City: Milkovo, RU
#
# Currently on 755 out of 1400 |::| City: Rognan, NO
#
# Currently on 756 out of 1400 |::| City: Walvis Bay, NA
#
# Currently on 757 out of 1400 |::| City: Sergeyevka, KZ
#
# Currently on 758 out of 1400 |::| City: Shakawe, BW
#
# Currently on 759 out of 1400 |::| City: Kabompo, ZM
#
# Currently on 760 out of 1400 |::| City: Jumla, NP
#
# Currently on 761 out of 1400 |::| City: Mackay, AU
#
# Currently on 762 out of 1400 |::| City: Great Bend, US
#
# Currently on 763 out of 1400 |::| City: Mrakovo, RU
#
# Currently on 764 out of 1400 |::| City: Kidero, RU
#
# Currently on 765 out of 1400 |::| City: Nevers, FR
#
# Currently on 766 out of 1400 |::| City: Torrevieja, ES
#
# Currently on 767 out of 1400 |::| City: Aswan, EG
#
# Currently on 768 out of 1400 |::| City: Acarau, BR
#
# Currently on 769 out of 1400 |::| City: Tel Aviv-Yafo, IL
#
# Currently on 770 out of 1400 |::| City: Leningradskiy, RU
#
# Currently on 771 out of 1400 |::| City: Honghu, CN
#
# Currently on 772 out of 1400 |::| City: Linqiong, CN
#
# Currently on 773 out of 1400 |::| City: Hami, CN
#
# Currently on 774 out of 1400 |::| City: Scottsbluff, US
#
# Currently on 775 out of 1400 |::| City: Port-Cartier, CA
#
# Currently on 776 out of 1400 |::| City: Port Angeles, US
#
# Currently on 777 out of 1400 |::| City: Ruatoria, NZ
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 778 out of 1400 |::| City: Necochea, AR
#
# Currently on 779 out of 1400 |::| City: Sofiysk, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 780 out of 1400 |::| City: Amga, RU
#
# Currently on 781 out of 1400 |::| City: Dalvik, IS
#
# ...
#
# Currently on 1138 out of 1400 |::| City: Poya, NC
#
# Currently on 1139 out of 1400 |::| City: Pontes E Lacerda, BR
#
# Currently on 1140 out of 1400 |::| City: Srednyaya Akhtuba, RU
#
# Currently on 1141 out of 1400 |::| City: Krasnyy Luch, UA
#
# Currently on 1142 out of 1400 |::| City: Varkaus, FI
#
# Currently on 1143 out of 1400 |::| City: Thunder Bay, CA
#
# Currently on 1144 out of 1400 |::| City: Conde, BR
#
# Currently on 1145 out of 1400 |::| City: Ahuimanu, US
#
# Currently on 1146 out of 1400 |::| City: Veraval, IN
#
# Currently on 1147 out of 1400 |::| City: Palora, EC
#
# Currently on 1148 out of 1400 |::| City: Ferme-Neuve, CA
#
# Currently on 1149 out of 1400 |::| City: Chupa, RU
#
# Currently on 1150 out of 1400 |::| City: Agaro, ET
#
# Currently on 1151 out of 1400 |::| City: Cedar City, US
#
# Currently on 1152 out of 1400 |::| City: Qujing, CN
#
# Currently on 1153 out of 1400 |::| City: Slave Lake, CA
#
# Currently on 1154 out of 1400 |::| City: Ilebo, CD
#
# Currently on 1155 out of 1400 |::| City: Indianola, US
#
# Currently on 1156 out of 1400 |::| City: Hirado, JP
#
# Currently on 1157 out of 1400 |::| City: Upata, VE
#
# Currently on 1158 out of 1400 |::| City: Ambon, ID
#
# Currently on 1159 out of 1400 |::| City: Honiara, SB
#
# Currently on 1160 out of 1400 |::| City: Fare, PF
#
# Currently on 1161 out of 1400 |::| City: Kampot, KH
#
# Currently on 1162 out of 1400 |::| City: Jasper, US
#
# Currently on 1163 out of 1400 |::| City: Kumano, JP
#
# Currently on 1164 out of 1400 |::| City: Kyzyl, RU
#
# Currently on 1165 out of 1400 |::| City: Clovis, US
#
# Currently on 1166 out of 1400 |::| City: Kontagora, NG
#
# Currently on 1167 out of 1400 |::| City: Chitipa, MW
#
# Currently on 1168 out of 1400 |::| City: Kismayo, SO
#
# Currently on 1169 out of 1400 |::| City: Mogochin, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1170 out of 1400 |::| City: Bokspits, BW
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1171 out of 1400 |::| City: Landeck, AT
#
# Currently on 1172 out of 1400 |::| City: Praya, ID
#
# Currently on 1173 out of 1400 |::| City: Sobolevo, RU
#
# Currently on 1174 out of 1400 |::| City: Pomoryany, UA
#
# Currently on 1175 out of 1400 |::| City: Talakan, RU
#
# Currently on 1176 out of 1400 |::| City: San Miguel, PA
#
# Currently on 1177 out of 1400 |::| City: Foumban, CM
#
# Currently on 1178 out of 1400 |::| City: Brandon, US
#
# Currently on 1179 out of 1400 |::| City: Waitati, NZ
#
# Currently on 1180 out of 1400 |::| City: Santa Barbara, BO
#
# Currently on 1181 out of 1400 |::| City: Bonga, ET
#
# Currently on 1182 out of 1400 |::| City: Shingu, JP
#
# Currently on 1183 out of 1400 |::| City: Barbar, SD
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1184 out of 1400 |::| City: Aksarka, RU
#
# Currently on 1185 out of 1400 |::| City: Esqueda, MX
#
# Currently on 1186 out of 1400 |::| City: Luba, GQ
#
# Currently on 1187 out of 1400 |::| City: Nortelandia, BR
#
# Currently on 1188 out of 1400 |::| City: Koyelga, RU
#
# Currently on 1189 out of 1400 |::| City: Dalby, AU
#
# Currently on 1190 out of 1400 |::| City: Westport, IE
#
# Currently on 1191 out of 1400 |::| City: Bafra, TR
#
# Currently on 1192 out of 1400 |::| City: Harer, ET
#
# Currently on 1193 out of 1400 |::| City: Flin Flon, CA
#
# Currently on 1194 out of 1400 |::| City: Gravdal, NO
#
# Currently on 1195 out of 1400 |::| City: Chernyshevskiy, RU
#
# Currently on 1196 out of 1400 |::| City: Kashary, RU
#
# Currently on 1197 out of 1400 |::| City: Ozernovskiy, RU
#
# Currently on 1198 out of 1400 |::| City: Goundam, ML
#
# Currently on 1199 out of 1400 |::| City: Bur Gabo, SO
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1200 out of 1400 |::| City: Dembi Dolo, ET
#
# Currently on 1201 out of 1400 |::| City: Mutoko, ZW
#
# Currently on 1202 out of 1400 |::| City: Nikolayevsk-Na-Amure, RU
#
# Currently on 1203 out of 1400 |::| City: Porto Tolle, IT
#
# Currently on 1204 out of 1400 |::| City: Cleethorpes, GB
#
# Currently on 1205 out of 1400 |::| City: Pryozerne, UA
#
# Currently on 1206 out of 1400 |::| City: Dudinka, RU
#
# Currently on 1207 out of 1400 |::| City: Simao Dias, BR
#
# Currently on 1208 out of 1400 |::| City: Isla Mujeres, MX
# Currently on 1209 out of 1400 |::| City: Cody, US
#
# Currently on 1210 out of 1400 |::| City: Chern, RU
#
# Currently on 1211 out of 1400 |::| City: Tyup, KG
#
# Currently on 1212 out of 1400 |::| City: Nanuque, BR
#
# Currently on 1213 out of 1400 |::| City: Lerwick, GB
#
# Currently on 1214 out of 1400 |::| City: Abu Zabad, SD
#
# Currently on 1215 out of 1400 |::| City: Muscat, OM
#
# Currently on 1216 out of 1400 |::| City: Lazaro Cardenas, MX
#
# Currently on 1217 out of 1400 |::| City: Yugorsk, RU
#
# Currently on 1218 out of 1400 |::| City: Ahipara, NZ
#
# Currently on 1219 out of 1400 |::| City: Poole, GB
#
# Currently on 1220 out of 1400 |::| City: Kuruman, ZA
#
# Currently on 1221 out of 1400 |::| City: Balakhta, RU
#
# Currently on 1222 out of 1400 |::| City: Bol, TD
#
# Currently on 1223 out of 1400 |::| City: Bowen, AU
#
# Currently on 1224 out of 1400 |::| City: Manjeshwar, IN
#
# Currently on 1225 out of 1400 |::| City: Gilbues, BR
#
# Currently on 1226 out of 1400 |::| City: Sawakin, SD
#
# Currently on 1227 out of 1400 |::| City: Ladario, BR
#
# Currently on 1228 out of 1400 |::| City: Kargopol, RU
#
# Currently on 1229 out of 1400 |::| City: Mozelos, PT
#
# Currently on 1230 out of 1400 |::| City: Pangkalanbuun, ID
#
# Currently on 1231 out of 1400 |::| City: Puerto Lempira, HN
#
# Currently on 1232 out of 1400 |::| City: Parker, US
#
# Currently on 1233 out of 1400 |::| City: Bemidji, US
#
# Currently on 1234 out of 1400 |::| City: Pinega, RU
#
# Currently on 1235 out of 1400 |::| City: Grants Pass, US
#
# Currently on 1236 out of 1400 |::| City: Krasnaya Gora, RU
#
# Currently on 1237 out of 1400 |::| City: Belle Fourche, US
#
# Currently on 1238 out of 1400 |::| City: Amahai, ID
#
# Currently on 1239 out of 1400 |::| City: Tarakan, ID
#
# Currently on 1240 out of 1400 |::| City: Jian, CN
#
# Currently on 1241 out of 1400 |::| City: Bagdarin, RU
#
# Currently on 1242 out of 1400 |::| City: Saint-Denis, RE
#
# Currently on 1243 out of 1400 |::| City: Hangu, CN
#
# Currently on 1244 out of 1400 |::| City: Crixas, BR
#
# Currently on 1245 out of 1400 |::| City: Raudeberg, NO
#
# Currently on 1246 out of 1400 |::| City: Galgani, SD
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1247 out of 1400 |::| City: Menomonie, US
#
# Currently on 1248 out of 1400 |::| City: Mutsamudu, KM
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1249 out of 1400 |::| City: Igarka, RU
#
# Currently on 1250 out of 1400 |::| City: Dhidhdhoo, MV
#
# Currently on 1251 out of 1400 |::| City: Asasa, ET
#
# Currently on 1252 out of 1400 |::| City: Stranda, NO
#
# Currently on 1253 out of 1400 |::| City: Pedernales, EC
#
# Currently on 1254 out of 1400 |::| City: Brora, GB
#
# Currently on 1255 out of 1400 |::| City: Khowst, AF
#
# Currently on 1256 out of 1400 |::| City: Dolbeau, CA
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1257 out of 1400 |::| City: Puerto Penasco, MX
#
# Currently on 1258 out of 1400 |::| City: Sambava, MG
#
# Currently on 1259 out of 1400 |::| City: Beaverlodge, CA
#
# Currently on 1260 out of 1400 |::| City: Issenye, TZ
#
# Currently on 1261 out of 1400 |::| City: Kyren, RU
#
# Currently on 1262 out of 1400 |::| City: Panjab, AF
#
# Currently on 1263 out of 1400 |::| City: Hailey, US
#
# Currently on 1264 out of 1400 |::| City: Burkhala, RU
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1265 out of 1400 |::| City: Jaru, BR
#
# Currently on 1266 out of 1400 |::| City: Paracatu, BR
#
# Currently on 1267 out of 1400 |::| City: Corinto, NI
#
# Currently on 1268 out of 1400 |::| City: The Valley, AI
#
# Currently on 1269 out of 1400 |::| City: Gimli, CA
#
# Currently on 1270 out of 1400 |::| City: Ongandjera, NA
#
# Currently on 1271 out of 1400 |::| City: Buala, SB
#
# Currently on 1272 out of 1400 |::| City: Punta Cardon, VE
#
# Currently on 1273 out of 1400 |::| City: Uzunovo, RU
#
# Currently on 1274 out of 1400 |::| City: Orodara, BF
#
# Currently on 1275 out of 1400 |::| City: Tambopata, PE
#
# Currently on 1276 out of 1400 |::| City: Mecca, SA
#
# Currently on 1277 out of 1400 |::| City: Yaan, CN
#
# Currently on 1278 out of 1400 |::| City: Siilinjarvi, FI
#
# Currently on 1279 out of 1400 |::| City: Hebi, CN
#
# Currently on 1280 out of 1400 |::| City: Santa Maria, CV
#
# Currently on 1281 out of 1400 |::| City: Pokrovsk, RU
#
# Currently on 1282 out of 1400 |::| City: Kholodnyy, RU
#
# Currently on 1283 out of 1400 |::| City: Comodoro Rivadavia, AR
#
# Currently on 1284 out of 1400 |::| City: Novobirilyussy, RU
#
# Currently on 1285 out of 1400 |::| City: Orocue, CO
#
# Currently on 1286 out of 1400 |::| City: Turukhansk, RU
#
# Currently on 1287 out of 1400 |::| City: Syamzha, RU
#
# Currently on 1288 out of 1400 |::| City: Koslan, RU
#
# Currently on 1289 out of 1400 |::| City: Gorin, RU
#
# Currently on 1290 out of 1400 |::| City: Jiutai, CN
#
# Currently on 1291 out of 1400 |::| City: Klaebu, NO
#
# Currently on 1292 out of 1400 |::| City: Sumenep, ID
#
# Currently on 1293 out of 1400 |::| City: Girne, CY
#
# Currently on 1294 out of 1400 |::| City: Kendari, ID
#
# Currently on 1295 out of 1400 |::| City: Novikovo, RU
#
# Currently on 1296 out of 1400 |::| City: Montorio Al Vomano, IT
#
# Currently on 1297 out of 1400 |::| City: Ulladulla, AU
#
# Currently on 1298 out of 1400 |::| City: Challans, FR
#
# Currently on 1299 out of 1400 |::| City: Agva, TR
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1300 out of 1400 |::| City: Ginir, ET
#
# Currently on 1301 out of 1400 |::| City: Ganzhou, CN
#
# Currently on 1302 out of 1400 |::| City: Mareeba, AU
#
# Currently on 1303 out of 1400 |::| City: Cochrane, CA
#
# Currently on 1304 out of 1400 |::| City: Polunochnoye, RU
#
# Currently on 1305 out of 1400 |::| City: Izhma, RU
#
# Currently on 1306 out of 1400 |::| City: Sorab, IN
#
# Currently on 1307 out of 1400 |::| City: Koufovounon, GR
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1308 out of 1400 |::| City: Kuusamo, FI
#
# Currently on 1309 out of 1400 |::| City: Santo Antonio Do Ica, BR
#
# Currently on 1310 out of 1400 |::| City: Parabel, RU
#
# Currently on 1311 out of 1400 |::| City: Ludvika, SE
#
# Currently on 1312 out of 1400 |::| City: Mogadishu, SO
#
# Currently on 1313 out of 1400 |::| City: Karakol, KG
#
# Currently on 1314 out of 1400 |::| City: Lewistown, US
#
# Currently on 1315 out of 1400 |::| City: Tuy Hoa, VN
#
# Currently on 1316 out of 1400 |::| City: Belmonte, BR
#
# Currently on 1317 out of 1400 |::| City: Perpignan, FR
#
# Currently on 1318 out of 1400 |::| City: Arcos De La Frontera, ES
#
# Currently on 1319 out of 1400 |::| City: Tarudant, MA
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1320 out of 1400 |::| City: Panguipulli, CL
#
# Currently on 1321 out of 1400 |::| City: Grand-Santi, GF
#
# Currently on 1322 out of 1400 |::| City: Ubata, BR
#
# Currently on 1323 out of 1400 |::| City: Mokrousovo, RU
#
# Currently on 1324 out of 1400 |::| City: Huanan, CN
#
# Currently on 1325 out of 1400 |::| City: Sisophon, KH
#
# Currently on 1326 out of 1400 |::| City: Ambanja, MG
#
# Currently on 1327 out of 1400 |::| City: Jardim, BR
#
# Currently on 1328 out of 1400 |::| City: Shangzhi, CN
#
# Currently on 1329 out of 1400 |::| City: Alta Floresta, BR
#
# Currently on 1330 out of 1400 |::| City: Zaria, NG
#
# Currently on 1331 out of 1400 |::| City: Merritt, CA
#
# Currently on 1332 out of 1400 |::| City: Campo, PT
#
# Currently on 1333 out of 1400 |::| City: Korem, ET
#
# Currently on 1334 out of 1400 |::| City: Verkhnyaya Sysert, RU
#
# Currently on 1335 out of 1400 |::| City: Namatanai, PG
#
# Currently on 1336 out of 1400 |::| City: Kirkland Lake, CA
#
# Currently on 1337 out of 1400 |::| City: Beira, MZ
#
# Currently on 1338 out of 1400 |::| City: Areka, ET
#
# Currently on 1339 out of 1400 |::| City: Lensk, RU
#
# Currently on 1340 out of 1400 |::| City: Danielskuil, ZA
#
# Currently on 1341 out of 1400 |::| City: Pitea, SE
#
# Currently on 1342 out of 1400 |::| City: Nyurba, RU
#
# Currently on 1343 out of 1400 |::| City: Monroe, US
#
# Currently on 1344 out of 1400 |::| City: Vadso, NO
#
# Currently on 1345 out of 1400 |::| City: Azogues, EC
#
# Currently on 1346 out of 1400 |::| City: Caninde De Sao Francisco, BR
# Currently on 1347 out of 1400 |::| City: Bodo, NO
#
# Currently on 1348 out of 1400 |::| City: Kathmandu, NP
#
# Currently on 1349 out of 1400 |::| City: Erzin, RU
#
# Currently on 1350 out of 1400 |::| City: Kabanjahe, ID
#
# Currently on 1351 out of 1400 |::| City: Sudzha, RU
#
# Currently on 1352 out of 1400 |::| City: Rabo De Peixe, PT
#
# Currently on 1353 out of 1400 |::| City: Tura, RU
#
# Currently on 1354 out of 1400 |::| City: Franklin, US
#
# Currently on 1355 out of 1400 |::| City: Andenes, NO
#
# Currently on 1356 out of 1400 |::| City: Lokoja, NG
#
# Currently on 1357 out of 1400 |::| City: Preobrazheniye, RU
#
# Currently on 1358 out of 1400 |::| City: Nsanje, MW
#
# Currently on 1359 out of 1400 |::| City: Saryshagan, KZ
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1360 out of 1400 |::| City: Rutland, US
#
# Currently on 1361 out of 1400 |::| City: Tawzar, TN
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1362 out of 1400 |::| City: Kapit, MY
#
# Currently on 1363 out of 1400 |::| City: Palmerston, AU
#
# Currently on 1364 out of 1400 |::| City: Phan Rang, VN
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1365 out of 1400 |::| City: Khovu-Aksy, RU
#
# Currently on 1366 out of 1400 |::| City: Orichi, RU
#
# Currently on 1367 out of 1400 |::| City: Charters Towers, AU
#
# Currently on 1368 out of 1400 |::| City: Bac Lieu, VN
#
# Currently on 1369 out of 1400 |::| City: Panorama, BR
#
# Currently on 1370 out of 1400 |::| City: Parbhani, IN
#
# Currently on 1371 out of 1400 |::| City: Tiarei, PF
#
# Currently on 1372 out of 1400 |::| City: Guapore, BR
#
# Currently on 1373 out of 1400 |::| City: Samarinda, ID
#
# Currently on 1374 out of 1400 |::| City: Killarney, CA
#
# Currently on 1375 out of 1400 |::| City: Hinton, CA
#
# Currently on 1376 out of 1400 |::| City: Bocaranga, CF
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1377 out of 1400 |::| City: Buta, CD
#
# Currently on 1378 out of 1400 |::| City: Araouane, ML
#
# Currently on 1379 out of 1400 |::| City: Lowestoft, GB
#
# Currently on 1380 out of 1400 |::| City: Svetlaya, RU
#
# Currently on 1381 out of 1400 |::| City: Konstantinovka, RU
#
# Currently on 1382 out of 1400 |::| City: Los Algarrobos, PA
#
# Currently on 1383 out of 1400 |::| City: Sehithwa, BW
#
# Currently on 1384 out of 1400 |::| City: Dongzhen, CN
#
# Currently on 1385 out of 1400 |::| City: Banda Aceh, ID
#
# Currently on 1386 out of 1400 |::| City: Biryusinsk, RU
#
# Currently on 1387 out of 1400 |::| City: Esmeraldas, EC
#
# Currently on 1388 out of 1400 |::| City: Las Colinas, PA
#
# Currently on 1389 out of 1400 |::| City: Bowling Green, US
#
# Currently on 1390 out of 1400 |::| City: Davenda, RU
#
# Currently on 1391 out of 1400 |::| City: Pasni, PK
#
# Currently on 1392 out of 1400 |::| City: Aksu, CN
#
# Currently on 1393 out of 1400 |::| City: Snasa, NO
#
# Currently on 1394 out of 1400 |::| City: Rongcheng, CN
#
# Currently on 1395 out of 1400 |::| City: Nova Olimpia, BR
#
# Currently on 1396 out of 1400 |::| City: Buqayq, SA
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1397 out of 1400 |::| City: Qianguo, CN
#
# Currently on 1398 out of 1400 |::| City: Biltine, TD
#
# Currently on 1399 out of 1400 |::| City: Seddon, NZ
#
# Currently on 1400 out of 1400 |::| City: Paradise Valley, US

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Add collected weather data to Weather DF
weather_df["Temperature (F)"] = temperature_list
weather_df["Humidity (%)"] = humidity_list
weather_df["Cloud Cover (%)"] = cloudiness_list
weather_df["Wind Speed (MPH)"] = wind_speed_list
weather_df["Date (UTC)"] = date_list
weather_df["Latitude"] = latitude_list_v2
weather_df["Longitude"] = longitude_list_v2
weather_df["City"] = city_list_v2
weather_df["Country"] = country_list_v2

# Drop rows where we assigned Error too, because there was no data to pull
weather_df_v2 = weather_df[weather_df["Temperature (F)"] != "Error"]

# Reset Index after removing errors
weather_df_v2 = weather_df_v2.reset_index(drop=True)

# Save DF as .csv
weather_df_v2.to_csv("weather_data.csv")

print("Total number of unique cities in weather dataframe is: " + str(len(weather_df_v2.index)))
weather_df_v2.head(5)
# Out:
# Total number of unique cities in weather dataframe is: 1297
#   Latitude Longitude            City Country Temperature (F) Humidity (%)  \
# 0    55.64     95.45      Irbeyskoye      RU           32.67           88
# 1   -21.36     55.77  Saint-Philippe      RE           62.92           64
# 2   -42.88    147.33          Hobart      AU           64.71           54
# 3   -34.42     19.23        Hermanus      ZA           62.01           72
# 4   -34.53     20.04      Bredasdorp      ZA            62.6           59
#
#   Cloud Cover (%) Wind Speed (MPH)  Date (UTC)
# 0              41            12.03  1603932457
# 1               0             5.82  1603931947
# 2              25             1.99  1603931762
# 3             100             1.01  1603931918
# 4             100             2.24  1603931919

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get list of the indices of cities that have humidity over 100%.

over_100 = weather_df_v2.index[weather_df_v2["Humidity (%)"] > 100].tolist()
print(over_100)
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df_v2.drop(over_100)


clean_city_data = clean_city_data.reset_index(drop=True)
print("Total number of unique cities in weather dataframe is: " + str(len(weather_df_v2.index)))
clean_city_data.head(100)
# Out:
# Total number of unique cities in weather dataframe is: 1297
#    Latitude Longitude               City Country Temperature (F) Humidity (%)  \
# 0     55.64     95.45         Irbeyskoye      RU           32.67           88
# 1    -21.36     55.77     Saint-Philippe      RE           62.92           64
# 2    -42.88    147.33             Hobart      AU           64.71           54
# 3    -34.42     19.23           Hermanus      ZA           62.01           72
# 4    -34.53     20.04         Bredasdorp      ZA            62.6           59
# ..      ...       ...                ...     ...             ...          ...
# 95    38.69     35.55              Talas      TR           53.17           63
# 96       49     -64.4  Riviere-au-Renard      CA           29.14           89
# 97    -8.84     13.23             Luanda      AO           75.58           87
# 98    38.52     -28.7     Ribeira Grande      PT           67.64           86
# 99    -33.7    -53.46               Chui      UY           56.28           80
#
#    Cloud Cover (%) Wind Speed (MPH)  Date (UTC)
# 0               41            12.03  1603932457
# 1                0             5.82  1603931947
# 2               25             1.99  1603931762
# 3              100             1.01  1603931918
# 4              100             2.24  1603931919
# ..             ...              ...         ...
# 95               0             2.35  1603932573
# 96             100            10.92  1603932336
# 97             100             8.01  1603932575
# 98              64            21.21  1603932576
# 99              55             10.4  1603932578
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Temperature (F)"]

# Create Scatter Plot
fig_1 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Temperature - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

fig_1.figure.savefig('lat_v_temp.png')

print("This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.")

plt.show
# Out:
# This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Humidity (%)"]

# Create Scatter Plot
fig_2 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Humidity - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

fig_2.figure.savefig('lat_v_humid.png')

print("This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Cloud Cover (%)"]

# Create Scatter Plot
fig_3 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Cloudiness - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

fig_3.figure.savefig('lat_v_cloud.png')


print("This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Wind Speed (MPH)"]

# Create Scatter Plot
fig_4 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Wind Speed - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

fig_4.figure.savefig('lat_v_wind.png')


print("This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.")




plt.show
# Out:
# This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Linear Regression

# %%
# Set Clean City DF to North and South Hemispheres
north_hem = clean_city_data[clean_city_data["Latitude"] > 0]
south_hem = clean_city_data[clean_city_data["Latitude"] < 0]
print("Total number of unique cities in Northern Hemisphere is: " + str(len(north_hem.index)))
print("Total number of unique cities in Southern Hemisphere is: " + str(len(south_hem.index)))
# Out:
# Total number of unique cities in Northern Hemisphere is: 934
# Total number of unique cities in Southern Hemisphere is: 363

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set Axises

x_axis = north_hem["Latitude"]
y_axis = north_hem["Temperature (F)"]

# Create Scatter Plot
fig_5 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Northern Hemisphere - Latitude vs. Temperature - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")


# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")




fig_5.figure.savefig('n_hem_lat_v_temp.png')

print("This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.")

plt.show
# Out:
# The correlation between both factors is -0.86
# This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set Axises

x_axis = south_hem["Latitude"]
y_axis = south_hem["Temperature (F)"]

# Create Scatter Plot
fig_6 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("southern Hemisphere - Latitude vs. Temperature - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")


# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-90, 90),fontsize=15,color="red")




fig_6.figure.savefig('s_hem_lat_v_temp.png')

print("This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.")

plt.show
# Out:
# The correlation between both factors is 0.69
# This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = north_hem["Latitude"]
y_axis = north_hem["Humidity (%)"]

# Create Scatter Plot
fig_7 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Humidity - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=15,color="red")



fig_7.figure.savefig('n_hem_lat_v_humid.png')

print("This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.32
# This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = south_hem["Latitude"]
y_axis = south_hem["Humidity (%)"]

# Create Scatter Plot
fig_8 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Humidity - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")


# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-80,20),fontsize=15,color="red")


fig_8.figure.savefig('s_hem_lat_v_humid.png')

print("This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.18
# This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = north_hem["Latitude"]
y_axis = north_hem["Cloud Cover (%)"]

# Create Scatter Plot
fig_9 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Cloudiness - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(50,30),fontsize=15,color="red")



fig_9.figure.savefig('n_hem_lat_v_cloud.png')


print("This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.16
# This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = south_hem["Latitude"]
y_axis = south_hem["Cloud Cover (%)"]

# Create Scatter Plot
fig_10 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Cloudiness - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-90,20),fontsize=15,color="red")




fig_10.figure.savefig('s_hem_lat_v_cloud.png')


print("This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.19
# This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = north_hem["Latitude"]
y_axis = north_hem["Wind Speed (MPH)"]

# Create Scatter Plot
fig_11 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Wind Speed - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")


fig_11.figure.savefig('n_hem_lat_v_wind.png')


print("This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.")




plt.show
# Out:
# The correlation between both factors is 0.14
# This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = south_hem["Latitude"]
y_axis = south_hem["Wind Speed (MPH)"]

# Create Scatter Plot
fig_12 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Wind Speed - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-90,18),fontsize=15,color="red")


fig_12.figure.savefig('s_hem_lat_v_wind.png')


print("This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.")




plt.show
# Out:
# The correlation between both factors is -0.16
# This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>
