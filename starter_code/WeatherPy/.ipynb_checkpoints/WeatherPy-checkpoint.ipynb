# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import requests
import json
from api_keys import weather_api_key
from citipy import citipy
import random
import decimal
import time

# %% [markdown]
# ## Generate Cities List

# %%
#set up latitude and longitude lists
latitude_list = []
longitude_list = []

# Generate 1000 random latitude and logitude values and add them to there respective list
for x in range(0, 2500):
    latitude = float(decimal.Decimal(random.randrange(-9000, 9000))/100)
    longitude = float(decimal.Decimal(random.randrange(-18000, 18000))/100)
    latitude_list.append(latitude)
    longitude_list.append(longitude)

# Set up the Weather DF
weather_df = pd.DataFrame({"Latitude": latitude_list, "Longitude": longitude_list})

# set up list to hold city names and what there country there from
city_list = []
country_list = []

# goes through each value of Latitude and Longitude in the Weather DF and uses the value as inputs to determin there city and country
for a in range(0, len(weather_df["Latitude"])):
    lat_value = weather_df.iloc[a]["Latitude"]
    long_value = weather_df.iloc[a]["Longitude"]    
    city_cord = citipy.nearest_city(lat_value, long_value)
    city_name = city_cord.city_name
    city_list.append(city_name)
    country = city_cord.country_code
    country_list.append(country)

    
# adds the city and country lists into our weather data frame, and then a touch of formatting   
weather_df["City"] = city_list
weather_df["Country"] = country_list
weather_df["City"] = weather_df["City"].str.title()
weather_df["Country"] = weather_df["Country"].str.upper()


#drop duplicates duplicates
weather_df = weather_df.drop_duplicates(subset=["City", "Country"], keep="first")
weather_df = weather_df.reset_index(drop=True)

print("Total number of unique cities in weather dataframe is: " + str(len(weather_df.index)))
# Out:
# Total number of unique cities in weather dataframe is: 915

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set up list for variables we want
temperature_list = [] 
humidity_list = []
cloudiness_list = []
wind_speed_list = []
date_list = []
# Base URL before adding variable componets
url = "http://api.openweathermap.org/data/2.5/weather?"

    

for target in range(0, len(weather_df.index)):
    
    # Select city on weather DF, and formate for proper url code in event city has spaces in name
    target_city = weather_df.iloc[target]["City"]
    target_city = target_city.replace(" ","+")
    
    # Build query URL
    query_url = f"{url}appid={weather_api_key}&q={target_city}&units=imperial"
    
    # Use URL to make a request of information, bring back in the json format, and print URL
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    print(f"Currently on {(target + 1)} out of {(len(weather_df.index))}")
    print(query_url)
    
    # This will collect and store desired information, but if there is an error it will print a line and move on to next
    try:
        cities_temp = weather_json["main"]["temp"]
        temperature_list.append(cities_temp)
        
        cities_humid = weather_json["main"]["humidity"]
        humidity_list.append(cities_humid)
        
        cities_cloud = weather_json["clouds"]["all"]
        cloudiness_list.append(cities_cloud)
        
        cities_wind = weather_json["wind"]["speed"]
        wind_speed_list.append(cities_wind)
        
        cities_date = weather_json["dt"]
        date_list.append(cities_date)
    except:
        print("I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.")
        
        # Usuccessful API request will result in a blank value in list that will throw off list alignment
        # We will but in a dummy value in its place to clean out later
        temperature_list.append("Error")
        humidity_list.append("Error")
        cloudiness_list.append("Error")
        wind_speed_list.append("Error")
        date_list.append("Error")
    print()
    
    # Add a sleep timer to prevent my API requests from going over 60 per min and causing a 1 hour lock out.
    time.sleep(1) # in seconds
# Out:
# Currently on 1 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rudnogorsk&units=imperial
#
# Currently on 2 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Thompson&units=imperial
#
# Currently on 3 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Geraldton&units=imperial
#
# Currently on 4 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rawannawi&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 5 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Buala&units=imperial
#
# Currently on 6 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Belushya+Guba&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 7 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Punta+Arenas&units=imperial
#
# Currently on 8 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vaini&units=imperial
#
# Currently on 9 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Quintin&units=imperial
#
# Currently on 10 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Castro&units=imperial
#
# Currently on 11 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vagur&units=imperial
#
# Currently on 12 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sahuaripa&units=imperial
#
# Currently on 13 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=East+London&units=imperial
#
# Currently on 14 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Leshukonskoye&units=imperial
#
# Currently on 15 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kruisfontein&units=imperial
#
# Currently on 16 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dikson&units=imperial
#
# Currently on 17 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nador&units=imperial
#
# Currently on 18 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Butaritari&units=imperial
#
# Currently on 19 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gillette&units=imperial
#
# Currently on 20 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Shizilu&units=imperial
#
# Currently on 21 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ushuaia&units=imperial
#
# Currently on 22 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kapaa&units=imperial
#
# Currently on 23 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Atuona&units=imperial
#
# Currently on 24 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Meulaboh&units=imperial
#
# Currently on 25 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Darhan&units=imperial
#
# Currently on 26 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Airai&units=imperial
#
# Currently on 27 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Klyuchi&units=imperial
#
# Currently on 28 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bredasdorp&units=imperial
#
# Currently on 29 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Deputatskiy&units=imperial
#
# Currently on 30 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Illoqqortoormiut&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 31 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bosaso&units=imperial
#
# Currently on 32 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Santa+Isabel+Do+Rio+Negro&units=imperial
#
# Currently on 33 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Alfred&units=imperial
#
# Currently on 34 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kingaroy&units=imperial
#
# Currently on 35 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Novyy+Svit&units=imperial
#
# Currently on 36 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Taoudenni&units=imperial
#
# Currently on 37 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Faya&units=imperial
#
# Currently on 38 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Taolanaro&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 39 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Henties+Bay&units=imperial
#
# Currently on 40 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pidhorodne&units=imperial
#
# Currently on 41 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Teguldet&units=imperial
#
# Currently on 42 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Marcona&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 43 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kaeo&units=imperial
#
# Currently on 44 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rikitea&units=imperial
#
# Currently on 45 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dali&units=imperial
#
# Currently on 46 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tasiilaq&units=imperial
#
# Currently on 47 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tayginka&units=imperial
#
# Currently on 48 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Azare&units=imperial
#
# Currently on 49 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ayorou&units=imperial
#
# Currently on 50 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Busselton&units=imperial
#
# Currently on 51 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hermanus&units=imperial
#
# Currently on 52 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Coahuayana&units=imperial
#
# Currently on 53 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Puerto+Ayora&units=imperial
#
# Currently on 54 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barrow&units=imperial
#
# Currently on 55 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Awka&units=imperial
#
# Currently on 56 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bandarbeyla&units=imperial
# Currently on 57 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tsihombe&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 58 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sumbe&units=imperial
#
# Currently on 59 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cabo+San+Lucas&units=imperial
#
# Currently on 60 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Grand-Santi&units=imperial
#
# Currently on 61 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Georgetown&units=imperial
#
# Currently on 62 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Wangou&units=imperial
#
# Currently on 63 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barentsburg&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 64 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hithadhoo&units=imperial
#
# Currently on 65 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Torbay&units=imperial
#
# Currently on 66 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ojinaga&units=imperial
#
# Currently on 67 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ponta+Delgada&units=imperial
#
# Currently on 68 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yellowknife&units=imperial
#
# Currently on 69 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=New+Norfolk&units=imperial
#
# Currently on 70 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jumla&units=imperial
#
# Currently on 71 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mae+Ramat&units=imperial
#
# Currently on 72 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Peleduy&units=imperial
#
# Currently on 73 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Half+Moon+Bay&units=imperial
#
# Currently on 74 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hobart&units=imperial
#
# Currently on 75 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lagdo&units=imperial
#
# Currently on 76 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lagoa&units=imperial
#
# Currently on 77 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Atambua&units=imperial
#
# Currently on 78 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mataura&units=imperial
#
# Currently on 79 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Matagami&units=imperial
#
# Currently on 80 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mandalgovi&units=imperial
#
# Currently on 81 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Voh&units=imperial
#
# Currently on 82 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cherskiy&units=imperial
#
# Currently on 83 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saleaula&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 84 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Xalpatlahuac&units=imperial
#
# Currently on 85 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saskylakh&units=imperial
#
# Currently on 86 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tautira&units=imperial
#
# Currently on 87 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Atar&units=imperial
#
# Currently on 88 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Riyadh&units=imperial
#
# Currently on 89 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gambela&units=imperial
#
# Currently on 90 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tiksi&units=imperial
#
# Currently on 91 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gomel&units=imperial
#
# Currently on 92 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Guilin&units=imperial
#
# Currently on 93 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=High+Rock&units=imperial
#
# Currently on 94 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cockburn+Town&units=imperial
#
# Currently on 95 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint+George&units=imperial
#
# Currently on 96 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Coihaique&units=imperial
#
# Currently on 97 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Provideniya&units=imperial
#
# Currently on 98 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Avarua&units=imperial
#
# Currently on 99 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hilo&units=imperial
#
# Currently on 100 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ribeira+Grande&units=imperial
#
# Currently on 101 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bluff&units=imperial
#
# Currently on 102 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Muros&units=imperial
#
# Currently on 103 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Najran&units=imperial
#
# Currently on 104 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maceio&units=imperial
#
# Currently on 105 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Albany&units=imperial
#
# Currently on 106 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bambous+Virieux&units=imperial
#
# Currently on 107 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rojhan&units=imperial
#
# Currently on 108 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Faanui&units=imperial
#
# Currently on 109 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Valley+City&units=imperial
#
# Currently on 110 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Altay&units=imperial
#
# Currently on 111 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Juneau&units=imperial
#
# Currently on 112 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pagondas&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
# Currently on 113 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Linchuan&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 114 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Beringovskiy&units=imperial
#
# Currently on 115 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sao+Filipe&units=imperial
#
# Currently on 116 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hamilton&units=imperial
#
# Currently on 117 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Christchurch&units=imperial
#
# Currently on 118 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lompoc&units=imperial
#
# Currently on 119 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Asau&units=imperial
#
# Currently on 120 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bethel&units=imperial
#
# Currently on 121 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pyinmana&units=imperial
#
# Currently on 122 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=North+Las+Vegas&units=imperial
#
# Currently on 123 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vila+Velha&units=imperial
#
# Currently on 124 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mullaitivu&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 125 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Alice+Springs&units=imperial
#
# Currently on 126 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Victoria&units=imperial
#
# Currently on 127 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Serebryansk&units=imperial
#
# Currently on 128 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Novi+Pazar&units=imperial
#
# Currently on 129 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Poya&units=imperial
#
# Currently on 130 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Goderich&units=imperial
#
# Currently on 131 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ilulissat&units=imperial
#
# Currently on 132 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nha+Trang&units=imperial
#
# Currently on 133 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Patricio&units=imperial
#
# Currently on 134 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Katherine&units=imperial
#
# Currently on 135 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Arraial+Do+Cabo&units=imperial
#
# Currently on 136 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tuktoyaktuk&units=imperial
#
# Currently on 137 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Umm+Ruwabah&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 138 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chokurdakh&units=imperial
#
# Currently on 139 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Liling&units=imperial
#
# Currently on 140 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tyukhtet&units=imperial
#
# Currently on 141 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Constitucion&units=imperial
#
# Currently on 142 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Puerto+Leguizamo&units=imperial
#
# Currently on 143 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Belmonte&units=imperial
#
# Currently on 144 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Moresby&units=imperial
#
# Currently on 145 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Augusta&units=imperial
#
# Currently on 146 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Suruc&units=imperial
#
# Currently on 147 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dickinson&units=imperial
#
# Currently on 148 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tarata&units=imperial
#
# Currently on 149 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Marsh+Harbour&units=imperial
#
# Currently on 150 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nanortalik&units=imperial
#
# Currently on 151 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Piacabucu&units=imperial
#
# Currently on 152 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sentyabrskiy&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 153 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Attawapiskat&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 154 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Skjervoy&units=imperial
#
# Currently on 155 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yulara&units=imperial
#
# Currently on 156 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Whitehorse&units=imperial
#
# Currently on 157 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kalabo&units=imperial
#
# Currently on 158 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Elizabeth&units=imperial
#
# Currently on 159 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sakaiminato&units=imperial
#
# Currently on 160 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=New+Castle&units=imperial
#
# Currently on 161 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mukhen&units=imperial
#
# Currently on 162 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Namibe&units=imperial
#
# Currently on 163 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mar+Del+Plata&units=imperial
#
# Currently on 164 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aksu&units=imperial
#
# Currently on 165 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Midland&units=imperial
#
# Currently on 166 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lebu&units=imperial
#
# Currently on 167 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Palasa&units=imperial
# Currently on 168 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Hardy&units=imperial
#
# Currently on 169 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Champasak&units=imperial
#
# Currently on 170 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Abatskoye&units=imperial
#
# Currently on 171 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chifeng&units=imperial
#
# Currently on 172 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cidreira&units=imperial
#
# Currently on 173 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Napier&units=imperial
#
# Currently on 174 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint-Philippe&units=imperial
#
# Currently on 175 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Varzea+Da+Palma&units=imperial
#
# Currently on 176 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pedernales&units=imperial
#
# Currently on 177 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kristiansand&units=imperial
#
# Currently on 178 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Darnah&units=imperial
#
# Currently on 179 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Preobrazheniye&units=imperial
#
# Currently on 180 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chuy&units=imperial
#
# Currently on 181 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Burmakino&units=imperial
#
# Currently on 182 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Khatanga&units=imperial
#
# Currently on 183 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Taltal&units=imperial
#
# Currently on 184 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pinega&units=imperial
#
# Currently on 185 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kitwe&units=imperial
#
# Currently on 186 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Grand+River+South+East&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 187 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ponta+Do+Sol&units=imperial
#
# Currently on 188 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Starosubkhangulovo&units=imperial
#
# Currently on 189 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Guanare&units=imperial
#
# Currently on 190 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gemena&units=imperial
#
# Currently on 191 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nizhneyansk&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 192 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sar-E+Pul&units=imperial
#
# Currently on 193 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Visnes&units=imperial
#
# Currently on 194 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jamestown&units=imperial
#
# Currently on 195 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Esfahan&units=imperial
#
# Currently on 196 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Prince+Rupert&units=imperial
#
# Currently on 197 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Plock&units=imperial
#
# Currently on 198 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Marau&units=imperial
#
# Currently on 199 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mersing&units=imperial
#
# Currently on 200 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Norman+Wells&units=imperial
#
# Currently on 201 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mandera&units=imperial
#
# Currently on 202 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ilam&units=imperial
#
# Currently on 203 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nantucket&units=imperial
#
# Currently on 204 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Skagen&units=imperial
#
# Currently on 205 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nikolskoye&units=imperial
#
# Currently on 206 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Boa+Vista&units=imperial
#
# Currently on 207 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Am+Timan&units=imperial
#
# Currently on 208 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Poum&units=imperial
#
# Currently on 209 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bodden+Town&units=imperial
#
# Currently on 210 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hami&units=imperial
#
# Currently on 211 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mitu&units=imperial
#
# Currently on 212 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Upernavik&units=imperial
#
# Currently on 213 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Navahrudak&units=imperial
#
# Currently on 214 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Treinta+Y+Tres&units=imperial
#
# Currently on 215 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rundu&units=imperial
#
# Currently on 216 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Inhambane&units=imperial
#
# Currently on 217 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tiznit&units=imperial
#
# Currently on 218 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Asfi&units=imperial
#
# Currently on 219 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Muzquiz&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 220 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mount+Gambier&units=imperial
#
# Currently on 221 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kysyl-Syr&units=imperial
#
# Currently on 222 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yerbogachen&units=imperial
#
# Currently on 223 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cape+Town&units=imperial
# Currently on 224 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kloulklubed&units=imperial
#
# Currently on 225 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Balimo&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 226 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Springbok&units=imperial
#
# Currently on 227 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bukachacha&units=imperial
#
# Currently on 228 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Macquarie&units=imperial
#
# Currently on 229 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Amderma&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 230 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Carutapera&units=imperial
#
# Currently on 231 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Oranjestad&units=imperial
#
# Currently on 232 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Klaksvik&units=imperial
#
# Currently on 233 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bekhtery&units=imperial
#
# Currently on 234 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kingsport&units=imperial
#
# Currently on 235 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Shimoda&units=imperial
#
# Currently on 236 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kitale&units=imperial
#
# Currently on 237 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Wahiawa&units=imperial
#
# Currently on 238 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Guerrero+Negro&units=imperial
#
# Currently on 239 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Soligalich&units=imperial
#
# Currently on 240 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tuatapere&units=imperial
#
# Currently on 241 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Camacha&units=imperial
#
# Currently on 242 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Montauban&units=imperial
#
# Currently on 243 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zhigansk&units=imperial
#
# Currently on 244 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Doctor+Pedro+P.+Pena&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 245 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lasa&units=imperial
#
# Currently on 246 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cortez&units=imperial
#
# Currently on 247 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Warrnambool&units=imperial
#
# Currently on 248 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kenora&units=imperial
#
# Currently on 249 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Coruripe&units=imperial
#
# Currently on 250 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dongzhen&units=imperial
#
# Currently on 251 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lowestoft&units=imperial
#
# Currently on 252 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Khandbari&units=imperial
#
# Currently on 253 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kahului&units=imperial
#
# Currently on 254 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ushtobe&units=imperial
#
# Currently on 255 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Berlevag&units=imperial
#
# Currently on 256 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lugo&units=imperial
#
# Currently on 257 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Paucartambo&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 258 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dingle&units=imperial
#
# Currently on 259 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nicoya&units=imperial
#
# Currently on 260 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Adrar&units=imperial
#
# Currently on 261 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Homer&units=imperial
#
# Currently on 262 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barra+Do+Garcas&units=imperial
#
# Currently on 263 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vestmannaeyjar&units=imperial
#
# Currently on 264 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kumluca&units=imperial
#
# Currently on 265 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Richards+Bay&units=imperial
#
# Currently on 266 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Iqaluit&units=imperial
#
# Currently on 267 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sibolga&units=imperial
#
# Currently on 268 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Priiskovyy&units=imperial
#
# Currently on 269 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chapais&units=imperial
#
# Currently on 270 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Hedland&units=imperial
#
# Currently on 271 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Livingston&units=imperial
#
# Currently on 272 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Banda+Aceh&units=imperial
#
# Currently on 273 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lukoyanov&units=imperial
#
# Currently on 274 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dawei&units=imperial
#
# Currently on 275 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vaitupu&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 276 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tevriz&units=imperial
#
# Currently on 277 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Longview&units=imperial
#
# Currently on 278 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Luderitz&units=imperial
# Currently on 279 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Fairbanks&units=imperial
#
# Currently on 280 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Devils+Lake&units=imperial
#
# Currently on 281 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bengkulu&units=imperial
#
# Currently on 282 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zhangye&units=imperial
#
# Currently on 283 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Garoua&units=imperial
#
# Currently on 284 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lardos&units=imperial
#
# Currently on 285 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ibra&units=imperial
#
# Currently on 286 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nalut&units=imperial
#
# Currently on 287 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Shahganj&units=imperial
#
# Currently on 288 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tekeli&units=imperial
#
# Currently on 289 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zyryanka&units=imperial
#
# Currently on 290 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chardara&units=imperial
#
# Currently on 291 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kajiado&units=imperial
#
# Currently on 292 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Karachi&units=imperial
#
# Currently on 293 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Moron&units=imperial
#
# Currently on 294 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mwinilunga&units=imperial
#
# Currently on 295 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Russell&units=imperial
#
# Currently on 296 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Salsomaggiore+Terme&units=imperial
#
# Currently on 297 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sao+Gabriel+Da+Cachoeira&units=imperial
#
# Currently on 298 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lavrentiya&units=imperial
#
# Currently on 299 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ereymentau&units=imperial
#
# Currently on 300 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Campoverde&units=imperial
#
# Currently on 301 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nemuro&units=imperial
#
# Currently on 302 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hualmay&units=imperial
#
# Currently on 303 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Neiafu&units=imperial
#
# Currently on 304 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Umm+Kaddadah&units=imperial
#
# Currently on 305 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chara&units=imperial
#
# Currently on 306 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kodiak&units=imperial
#
# Currently on 307 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ostrovnoy&units=imperial
#
# Currently on 308 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lolua&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 309 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Batemans+Bay&units=imperial
#
# Currently on 310 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kappeln&units=imperial
#
# Currently on 311 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ganzhou&units=imperial
#
# Currently on 312 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kryve+Ozero&units=imperial
#
# Currently on 313 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Itupiranga&units=imperial
#
# Currently on 314 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nhulunbuy&units=imperial
#
# Currently on 315 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Grindavik&units=imperial
#
# Currently on 316 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Siparia&units=imperial
#
# Currently on 317 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Luba&units=imperial
#
# Currently on 318 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Muswellbrook&units=imperial
#
# Currently on 319 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Acarau&units=imperial
#
# Currently on 320 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sola&units=imperial
#
# Currently on 321 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mrirt&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 322 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jerez&units=imperial
#
# Currently on 323 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dalbandin&units=imperial
#
# Currently on 324 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Opunake&units=imperial
#
# ...
#
# Currently on 809 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hun&units=imperial
#
# Currently on 810 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Damara&units=imperial
#
# Currently on 811 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Morehead&units=imperial
#
# Currently on 812 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Natal&units=imperial
#
# Currently on 813 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ambilobe&units=imperial
#
# Currently on 814 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gorontalo&units=imperial
#
# Currently on 815 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rassvet&units=imperial
#
# Currently on 816 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Isagarh&units=imperial
#
# Currently on 817 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Shubarkuduk&units=imperial
#
# Currently on 818 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Alofi&units=imperial
#
# Currently on 819 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ostersund&units=imperial
#
# Currently on 820 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ravar&units=imperial
#
# Currently on 821 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Emba&units=imperial
#
# Currently on 822 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tortoli&units=imperial
#
# Currently on 823 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bulungu&units=imperial
#
# Currently on 824 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hendijan&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 825 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Polis&units=imperial
#
# Currently on 826 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cockburn+Harbour&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 827 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Phan+Thiet&units=imperial
#
# Currently on 828 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=North+Bend&units=imperial
#
# Currently on 829 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mount+Isa&units=imperial
#
# Currently on 830 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lebedyn&units=imperial
#
# Currently on 831 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Naryan-Mar&units=imperial
#
# Currently on 832 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Komsomolskiy&units=imperial
#
# Currently on 833 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Oparino&units=imperial
#
# Currently on 834 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Oistins&units=imperial
#
# Currently on 835 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zaplyusye&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 836 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Itoigawa&units=imperial
#
# Currently on 837 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pokrovsk&units=imperial
# Currently on 838 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Namatanai&units=imperial
#
# Currently on 839 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Asbury+Park&units=imperial
#
# Currently on 840 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Grand+Centre&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 841 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tucupita&units=imperial
#
# Currently on 842 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Enkhuizen&units=imperial
#
# Currently on 843 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Puerto+Cabezas&units=imperial
#
# Currently on 844 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Portland&units=imperial
#
# Currently on 845 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Taseyevo&units=imperial
#
# Currently on 846 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aktau&units=imperial
#
# Currently on 847 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dingzhou&units=imperial
#
# Currently on 848 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hayden&units=imperial
#
# Currently on 849 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Doha&units=imperial
#
# Currently on 850 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maniitsoq&units=imperial
#
# Currently on 851 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kenscoff&units=imperial
#
# Currently on 852 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Huilong&units=imperial
#
# Currently on 853 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Manggar&units=imperial
#
# Currently on 854 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sungairaya&units=imperial
#
# Currently on 855 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sovetskiy&units=imperial
#
# Currently on 856 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nevelsk&units=imperial
#
# Currently on 857 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sao+Jose+Da+Coroa+Grande&units=imperial
#
# Currently on 858 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Emerald&units=imperial
#
# Currently on 859 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Valparaiso&units=imperial
#
# Currently on 860 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Muttupet&units=imperial
#
# Currently on 861 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Laredo&units=imperial
#
# Currently on 862 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pringsewu&units=imperial
#
# Currently on 863 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Guiratinga&units=imperial
#
# Currently on 864 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bogorodskoye&units=imperial
#
# Currently on 865 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ratnapura&units=imperial
#
# Currently on 866 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Wang+Saphung&units=imperial
#
# Currently on 867 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gracac&units=imperial
#
# Currently on 868 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pocos+De+Caldas&units=imperial
#
# Currently on 869 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hofn&units=imperial
#
# Currently on 870 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Awjilah&units=imperial
#
# Currently on 871 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yanan&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 872 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Longhua&units=imperial
#
# Currently on 873 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Caldwell&units=imperial
#
# Currently on 874 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pochutla&units=imperial
#
# Currently on 875 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lexington&units=imperial
#
# Currently on 876 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tilichiki&units=imperial
#
# Currently on 877 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Calbuco&units=imperial
#
# Currently on 878 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zemio&units=imperial
#
# Currently on 879 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Manitouwadge&units=imperial
#
# Currently on 880 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Padang&units=imperial
#
# Currently on 881 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Antonio&units=imperial
#
# Currently on 882 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cap-Aux-Meules&units=imperial
#
# Currently on 883 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sanming&units=imperial
#
# Currently on 884 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Carahue&units=imperial
#
# Currently on 885 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aporawan&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 886 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Quixeramobim&units=imperial
#
# Currently on 887 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maraa&units=imperial
#
# Currently on 888 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Santa+Maria&units=imperial
#
# Currently on 889 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chama&units=imperial
#
# Currently on 890 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Turan&units=imperial
#
# Currently on 891 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Macon&units=imperial
#
# Currently on 892 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sobolevo&units=imperial
#
# Currently on 893 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tigzirt&units=imperial
# Currently on 894 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Foz&units=imperial
#
# Currently on 895 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Klaebu&units=imperial
#
# Currently on 896 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Haines+Junction&units=imperial
#
# Currently on 897 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tornio&units=imperial
#
# Currently on 898 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aflu&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 899 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tengushevo&units=imperial
#
# Currently on 900 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bangui&units=imperial
#
# Currently on 901 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sept-Iles&units=imperial
#
# Currently on 902 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bolungarvik&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 903 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gurskoye&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 904 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Malpura&units=imperial
#
# Currently on 905 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Riachao+Das+Neves&units=imperial
#
# Currently on 906 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mweka&units=imperial
#
# Currently on 907 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Teshie&units=imperial
#
# Currently on 908 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Krasnoarmeysk&units=imperial
#
# Currently on 909 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saryagash&units=imperial
#
# Currently on 910 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ninghai&units=imperial
#
# Currently on 911 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lang+Son&units=imperial
#
# Currently on 912 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tyup&units=imperial
#
# Currently on 913 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sorong&units=imperial
#
# Currently on 914 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sambava&units=imperial
#
# Currently on 915 out of 915
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kailua&units=imperial

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Add collected weather data to Weather DF
weather_df["Temperature (F)"] = temperature_list
weather_df["Humidity (%)"] = humidity_list
weather_df["Cloud Cover (%)"] = cloudiness_list
weather_df["Wind Speed (MPH)"] = wind_speed_list
weather_df["Date (UTC)"] = date_list

# Drop rows where we assigned Error too, because there was no data to pull
weather_df_v2 = weather_df[weather_df["Temperature (F)"] != "Error"]

# Reset Index after removing errors
weather_df_v2 = weather_df_v2.reset_index(drop=True)

# Save DF as .csv
weather_df_v2.to_csv("weather_data.csv")

print("Total number of unique cities in weather dataframe is: " + str(len(weather_df_v2.index)))
weather_df_v2.head(5)
# Out:
# Total number of unique cities in weather dataframe is: 847
#    Latitude  Longitude          City Country Temperature (F) Humidity (%)  \
# 0     57.55     103.67    Rudnogorsk      RU           21.58           95
# 1     58.85     -98.01      Thompson      CA              23           67
# 2    -31.18     108.16     Geraldton      AU            73.4           64
# 3     -0.54     161.68         Buala      SB           84.18           73
# 4    -55.11     -86.40  Punta Arenas      CL           42.39           93
#
#   Cloud Cover (%) Wind Speed (MPH)  Date (UTC)
# 0              14                4  1603677290
# 1              90             3.36  1603677291
# 2              40            12.75  1603677292
# 3              85             2.15  1603677294
# 4              75             3.36  1603677025

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
