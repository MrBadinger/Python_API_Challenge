# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import requests
import json
from api_keys import weather_api_key
from citipy import citipy
import random
import decimal
import time

# %% [markdown]
# ## Generate Cities List

# %%
#set up latitude and longitude lists
latitude_list = []
longitude_list = []

# Generate 1000 random latitude and logitude values and add them to there respective list
for x in range(0, 2500):
    latitude = float(decimal.Decimal(random.randrange(-9000, 9000))/100)
    longitude = float(decimal.Decimal(random.randrange(-18000, 18000))/100)
    latitude_list.append(latitude)
    longitude_list.append(longitude)

# Set up the Weather DF
weather_df = pd.DataFrame({"Latitude": latitude_list, "Longitude": longitude_list})

# set up list to hold city names and what there country there from
city_list = []
country_list = []

# goes through each value of Latitude and Longitude in the Weather DF and uses the value as inputs to determin there city and country
for a in range(0, len(weather_df["Latitude"])):
    lat_value = weather_df.iloc[a]["Latitude"]
    long_value = weather_df.iloc[a]["Longitude"]    
    city_cord = citipy.nearest_city(lat_value, long_value)
    city_name = city_cord.city_name
    city_list.append(city_name)
    country = city_cord.country_code
    country_list.append(country)

    
# adds the city and country lists into our weather data frame, and then a touch of formatting   
weather_df["City"] = city_list
weather_df["Country"] = country_list
weather_df["City"] = weather_df["City"].str.title()
weather_df["Country"] = weather_df["Country"].str.upper()


#drop duplicates duplicates
weather_df = weather_df.drop_duplicates(subset=["City", "Country"], keep="first")
weather_df = weather_df.reset_index(drop=True)

print("Total number of unique cities in weather dataframe is: " + str(len(weather_df.index)))
# Out:
# Total number of unique cities in weather dataframe is: 913

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set up list for variables we want
temperature_list = [] 
humidity_list = []
cloudiness_list = []
wind_speed_list = []
date_list = []
# Base URL before adding variable componets
url = "http://api.openweathermap.org/data/2.5/weather?"

    

for target in range(0, len(weather_df.index)):
    
    # Select city on weather DF, and formate for proper url code in event city has spaces in name
    target_city = weather_df.iloc[target]["City"]
    target_city = target_city.replace(" ","+")
    
    # Build query URL
    query_url = f"{url}appid={weather_api_key}&q={target_city}&units=imperial"
    
    # Use URL to make a request of information, bring back in the json format, and print URL
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    print(f"Currently on {(target + 1)} out of {(len(weather_df.index))}")
    print(query_url)
    
    # This will collect and store desired information, but if there is an error it will print a line and move on to next
    try:
        cities_temp = weather_json["main"]["temp"]
        temperature_list.append(cities_temp)
        cities_humid = weather_json["main"]["humidity"]
        humidity_list.append(cities_temp)
        cities_cloud = weather_json["clouds"]["all"]
        cloudiness_list.append(cities_temp)
        cities_wind = weather_json["wind"]["speed"]
        wind_speed_list.append(cities_temp)
        cities_date = weather_json["dt"]
        date_list.append(cities_date)
    except:
        print("I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.")
        
        # Usuccessful API request will result in a blank value in list that will throw off list alignment
        # We will but in a dummy value in its place to clean out later
        temperature_list.append("Error")
        humidity_list.append("Error")
        cloudiness_list.append("Error")
        wind_speed_list.append("Error")
        date_list.append("Error")
    print()
    
    # Add a sleep timer to prevent my API requests from going over 60 per min and causing a 1 hour lock out.
    time.sleep(1) # in seconds
# Out:
# Currently on 1 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Carnarvon&units=imperial
#
# Currently on 2 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Belushya+Guba&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 3 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vaini&units=imperial
#
# Currently on 4 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nepa+Nagar&units=imperial
#
# Currently on 5 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jamestown&units=imperial
#
# Currently on 6 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bolungarvik&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 7 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Prince+Rupert&units=imperial
#
# Currently on 8 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mys+Shmidta&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 9 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Thompson&units=imperial
#
# Currently on 10 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tsihombe&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 11 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Springdale&units=imperial
#
# Currently on 12 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kusti&units=imperial
#
# Currently on 13 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kavieng&units=imperial
#
# Currently on 14 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Illoqqortoormiut&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 15 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Castro&units=imperial
#
# Currently on 16 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kahului&units=imperial
#
# Currently on 17 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Panlaitan&units=imperial
#
# Currently on 18 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nizhneyansk&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 19 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Marcona&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 20 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vila+Franca+Do+Campo&units=imperial
#
# Currently on 21 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sungaipenuh&units=imperial
#
# Currently on 22 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rikitea&units=imperial
#
# Currently on 23 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rocha&units=imperial
#
# Currently on 24 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Takoradi&units=imperial
#
# Currently on 25 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kushmurun&units=imperial
#
# Currently on 26 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Waiouru&units=imperial
#
# Currently on 27 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Busselton&units=imperial
#
# Currently on 28 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cape+Town&units=imperial
#
# Currently on 29 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Fethiye&units=imperial
#
# Currently on 30 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Atuona&units=imperial
#
# Currently on 31 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mataura&units=imperial
#
# Currently on 32 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Halalo&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 33 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bucerias&units=imperial
#
# Currently on 34 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Rafael&units=imperial
#
# Currently on 35 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=La+Ronge&units=imperial
#
# Currently on 36 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dingle&units=imperial
#
# Currently on 37 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ponta+Delgada&units=imperial
#
# Currently on 38 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Huazolotitlan&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 39 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kalmunai&units=imperial
#
# Currently on 40 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Seoul&units=imperial
#
# Currently on 41 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zyryanka&units=imperial
#
# Currently on 42 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ye&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 43 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Beeville&units=imperial
#
# Currently on 44 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Puerto+Ayora&units=imperial
#
# Currently on 45 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vaitupu&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 46 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nikolskoye&units=imperial
#
# Currently on 47 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yefremov&units=imperial
#
# Currently on 48 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Punta+Arenas&units=imperial
#
# Currently on 49 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Puerto+Baquerizo+Moreno&units=imperial
#
# Currently on 50 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bluff&units=imperial
#
# Currently on 51 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cockburn+Town&units=imperial
# Currently on 52 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kapaa&units=imperial
#
# Currently on 53 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Katangli&units=imperial
#
# Currently on 54 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Motala&units=imperial
#
# Currently on 55 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hermanus&units=imperial
#
# Currently on 56 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Havelock&units=imperial
#
# Currently on 57 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Avarua&units=imperial
#
# Currently on 58 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Te+Anau&units=imperial
#
# Currently on 59 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Russell&units=imperial
#
# Currently on 60 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Victoria&units=imperial
#
# Currently on 61 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Butaritari&units=imperial
#
# Currently on 62 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Constitucion&units=imperial
#
# Currently on 63 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saskylakh&units=imperial
#
# Currently on 64 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tiksi&units=imperial
#
# Currently on 65 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cockburn+Town&units=imperial
#
# Currently on 66 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cherskiy&units=imperial
#
# Currently on 67 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aklavik&units=imperial
#
# Currently on 68 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Alfred&units=imperial
#
# Currently on 69 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Billings&units=imperial
#
# Currently on 70 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ushuaia&units=imperial
#
# Currently on 71 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Safwah&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 72 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ostersund&units=imperial
#
# Currently on 73 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sentyabrskiy&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 74 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Albany&units=imperial
#
# Currently on 75 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jalu&units=imperial
#
# Currently on 76 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Half+Moon+Bay&units=imperial
#
# Currently on 77 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Taolanaro&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 78 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Batouri&units=imperial
#
# Currently on 79 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nagaur&units=imperial
#
# Currently on 80 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tondano&units=imperial
#
# Currently on 81 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=New+Norfolk&units=imperial
#
# Currently on 82 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Langham&units=imperial
#
# Currently on 83 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Necochea&units=imperial
#
# Currently on 84 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mareeba&units=imperial
#
# Currently on 85 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ukiah&units=imperial
#
# Currently on 86 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yellowknife&units=imperial
#
# Currently on 87 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Labuhan&units=imperial
#
# Currently on 88 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Roald&units=imperial
#
# Currently on 89 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aden&units=imperial
#
# Currently on 90 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hobart&units=imperial
#
# Currently on 91 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Amderma&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 92 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Manhush&units=imperial
#
# Currently on 93 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kaeo&units=imperial
#
# Currently on 94 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sao+Filipe&units=imperial
#
# Currently on 95 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Seydi&units=imperial
#
# Currently on 96 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lorengau&units=imperial
#
# Currently on 97 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mar+Del+Plata&units=imperial
#
# Currently on 98 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Porangatu&units=imperial
#
# Currently on 99 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Svetlaya&units=imperial
#
# Currently on 100 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Severo-Kurilsk&units=imperial
#
# Currently on 101 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Manta&units=imperial
#
# Currently on 102 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Okhotsk&units=imperial
#
# Currently on 103 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Khatanga&units=imperial
#
# Currently on 104 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jingdezhen&units=imperial
#
# Currently on 105 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=College&units=imperial
#
# Currently on 106 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kodiak&units=imperial
#
# Currently on 107 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kanniyakumari&units=imperial
# Currently on 108 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barrow&units=imperial
#
# Currently on 109 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint-Georges&units=imperial
#
# Currently on 110 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Scutelnici&units=imperial
#
# Currently on 111 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Evensk&units=imperial
#
# Currently on 112 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hilo&units=imperial
#
# Currently on 113 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Fairbanks&units=imperial
#
# Currently on 114 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barentsburg&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 115 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bathsheba&units=imperial
#
# Currently on 116 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chuy&units=imperial
#
# Currently on 117 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lukovetskiy&units=imperial
#
# Currently on 118 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Namatanai&units=imperial
#
# Currently on 119 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Clyde+River&units=imperial
#
# Currently on 120 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Husavik&units=imperial
#
# Currently on 121 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rotifunk&units=imperial
#
# Currently on 122 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lodja&units=imperial
#
# Currently on 123 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hamilton&units=imperial
#
# Currently on 124 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Palasa&units=imperial
#
# Currently on 125 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Adrar&units=imperial
#
# Currently on 126 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nago&units=imperial
#
# Currently on 127 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ruston&units=imperial
#
# Currently on 128 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Walvis+Bay&units=imperial
#
# Currently on 129 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kieta&units=imperial
#
# Currently on 130 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Guerrero+Negro&units=imperial
#
# Currently on 131 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Boa+Vista&units=imperial
#
# Currently on 132 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yulara&units=imperial
#
# Currently on 133 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pangnirtung&units=imperial
#
# Currently on 134 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bima&units=imperial
#
# Currently on 135 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maine-Soroa&units=imperial
#
# Currently on 136 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Marsabit&units=imperial
#
# Currently on 137 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Khonsa&units=imperial
#
# Currently on 138 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zaysan&units=imperial
#
# Currently on 139 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Touros&units=imperial
#
# Currently on 140 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cidreira&units=imperial
#
# Currently on 141 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Honiara&units=imperial
#
# Currently on 142 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Isangel&units=imperial
#
# Currently on 143 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Skeldon&units=imperial
#
# Currently on 144 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ketchikan&units=imperial
#
# Currently on 145 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Geraldton&units=imperial
#
# Currently on 146 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Marzuq&units=imperial
#
# Currently on 147 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ribeira+Grande&units=imperial
#
# Currently on 148 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kaitangata&units=imperial
#
# Currently on 149 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ossora&units=imperial
#
# Currently on 150 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Padang&units=imperial
#
# Currently on 151 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kamaishi&units=imperial
#
# Currently on 152 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint+George&units=imperial
#
# Currently on 153 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yanan&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 154 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Hardy&units=imperial
#
# Currently on 155 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Santa+Cruz&units=imperial
#
# Currently on 156 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Fortuna&units=imperial
#
# Currently on 157 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dikson&units=imperial
#
# Currently on 158 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Esperance&units=imperial
#
# Currently on 159 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Huilong&units=imperial
#
# Currently on 160 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Klaksvik&units=imperial
#
# Currently on 161 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Vicente&units=imperial
#
# Currently on 162 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mayo&units=imperial
#
# Currently on 163 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ligayan&units=imperial
#
# Currently on 164 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kotelnikovo&units=imperial
# Currently on 165 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bairiki&units=imperial
#
# Currently on 166 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ulaanbaatar&units=imperial
#
# Currently on 167 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Provideniya&units=imperial
#
# Currently on 168 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kudahuvadhoo&units=imperial
#
# Currently on 169 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Qaanaaq&units=imperial
#
# Currently on 170 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sladkovo&units=imperial
#
# Currently on 171 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Havre-Saint-Pierre&units=imperial
#
# Currently on 172 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bandar-E+Lengeh&units=imperial
#
# Currently on 173 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Attawapiskat&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 174 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lavrentiya&units=imperial
#
# Currently on 175 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=North+Marysville&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 176 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zhanatas&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 177 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ciudad+Bolivar&units=imperial
#
# Currently on 178 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kedougou&units=imperial
#
# Currently on 179 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kloulklubed&units=imperial
#
# Currently on 180 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hirara&units=imperial
#
# Currently on 181 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Longyearbyen&units=imperial
#
# Currently on 182 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kishi&units=imperial
#
# Currently on 183 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Minab&units=imperial
#
# Currently on 184 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Almenara&units=imperial
#
# Currently on 185 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bogatyye+Saby&units=imperial
#
# Currently on 186 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Elizabeth&units=imperial
#
# Currently on 187 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ilulissat&units=imperial
#
# Currently on 188 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Santa+Luzia&units=imperial
#
# Currently on 189 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Karratha&units=imperial
#
# Currently on 190 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Setermoen&units=imperial
#
# Currently on 191 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bredasdorp&units=imperial
#
# Currently on 192 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Palmas&units=imperial
#
# Currently on 193 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sao+Jose+Da+Coroa+Grande&units=imperial
#
# Currently on 194 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Otta&units=imperial
#
# Currently on 195 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Burnie&units=imperial
#
# Currently on 196 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Numaligarh&units=imperial
#
# Currently on 197 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Channel-Port+Aux+Basques&units=imperial
#
# Currently on 198 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cam+Ranh&units=imperial
#
# Currently on 199 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=East+London&units=imperial
#
# Currently on 200 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Santa+Barbara&units=imperial
#
# Currently on 201 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yeppoon&units=imperial
#
# Currently on 202 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Shingu&units=imperial
#
# Currently on 203 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Santiago+Del+Estero&units=imperial
#
# Currently on 204 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cabatuan&units=imperial
#
# Currently on 205 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Moron&units=imperial
#
# Currently on 206 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Namibe&units=imperial
#
# Currently on 207 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Narsaq&units=imperial
#
# Currently on 208 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Arraial+Do+Cabo&units=imperial
#
# Currently on 209 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Farafangana&units=imperial
#
# Currently on 210 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pundaguitan&units=imperial
#
# Currently on 211 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Isakly&units=imperial
#
# Currently on 212 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Umm+Kaddadah&units=imperial
#
# Currently on 213 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Severnyy&units=imperial
#
# Currently on 214 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kiunga&units=imperial
#
# Currently on 215 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Faanui&units=imperial
#
# Currently on 216 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Susangerd&units=imperial
#
# Currently on 217 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kruisfontein&units=imperial
#
# Currently on 218 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kalamnuri&units=imperial
#
# Currently on 219 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Arlit&units=imperial
#
# Currently on 220 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kaifeng&units=imperial
# Currently on 221 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Onguday&units=imperial
#
# Currently on 222 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Camabatela&units=imperial
#
# Currently on 223 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Los+Llanos+De+Aridane&units=imperial
#
# Currently on 224 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vestbygda&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 225 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tilichiki&units=imperial
#
# Currently on 226 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tuatapere&units=imperial
#
# Currently on 227 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Georgetown&units=imperial
#
# Currently on 228 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cabo+San+Lucas&units=imperial
#
# Currently on 229 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Upernavik&units=imperial
#
# Currently on 230 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Geraldton&units=imperial
#
# Currently on 231 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Senneterre&units=imperial
#
# Currently on 232 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yamada&units=imperial
#
# Currently on 233 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Takestan&units=imperial
#
# Currently on 234 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Blair&units=imperial
#
# Currently on 235 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Lincoln&units=imperial
#
# Currently on 236 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mahebourg&units=imperial
#
# Currently on 237 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Freeport&units=imperial
#
# Currently on 238 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Callaway&units=imperial
#
# Currently on 239 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Talnakh&units=imperial
#
# Currently on 240 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lolua&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 241 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Novyy+Nekouz&units=imperial
#
# Currently on 242 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Puli&units=imperial
#
# Currently on 243 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pendleton&units=imperial
#
# Currently on 244 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Beyneu&units=imperial
#
# Currently on 245 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ornskoldsvik&units=imperial
#
# Currently on 246 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pravia&units=imperial
#
# Currently on 247 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zhanakorgan&units=imperial
#
# Currently on 248 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tongliao&units=imperial
#
# Currently on 249 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tiarei&units=imperial
#
# Currently on 250 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Piacabucu&units=imperial
#
# Currently on 251 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Berlevag&units=imperial
#
# Currently on 252 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mandalgarh&units=imperial
#
# Currently on 253 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Richards+Bay&units=imperial
#
# Currently on 254 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Miyako&units=imperial
#
# Currently on 255 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bonthe&units=imperial
#
# Currently on 256 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Papara&units=imperial
#
# Currently on 257 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tsabong&units=imperial
#
# Currently on 258 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dhanaura&units=imperial
#
# Currently on 259 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sisimiut&units=imperial
#
# Currently on 260 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Perth&units=imperial
#
# Currently on 261 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kihei&units=imperial
#
# Currently on 262 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pisco&units=imperial
#
# Currently on 263 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aracati&units=imperial
#
# Currently on 264 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Atkinson&units=imperial
#
# Currently on 265 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Makat&units=imperial
#
# Currently on 266 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Iqaluit&units=imperial
#
# Currently on 267 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Quatre+Cocos&units=imperial
#
# Currently on 268 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Baghdad&units=imperial
#
# Currently on 269 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tuktoyaktuk&units=imperial
#
# Currently on 270 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint-Philippe&units=imperial
#
# Currently on 271 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sistranda&units=imperial
#
# Currently on 272 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Fort+Nelson&units=imperial
#
# Currently on 273 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nanjing&units=imperial
#
# Currently on 274 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Semme&units=imperial
#
# Currently on 275 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Plover&units=imperial
#
# Currently on 276 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lusambo&units=imperial
#
# Currently on 277 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aswan&units=imperial
# Currently on 278 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Katsuura&units=imperial
#
# Currently on 279 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tevaitoa&units=imperial
#
# Currently on 280 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Poum&units=imperial
#
# Currently on 281 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Naze&units=imperial
#
# Currently on 282 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Parana&units=imperial
#
# Currently on 283 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sambava&units=imperial
#
# Currently on 284 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ituni&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 285 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kambove&units=imperial
#
# Currently on 286 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Changying&units=imperial
#
# Currently on 287 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yambio&units=imperial
#
# Currently on 288 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jahrom&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 289 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dubbo&units=imperial
#
# Currently on 290 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lalsk&units=imperial
#
# Currently on 291 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chicama&units=imperial
#
# Currently on 292 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tarskoye&units=imperial
#
# Currently on 293 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Stromness&units=imperial
#
# Currently on 294 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mariental&units=imperial
#
# Currently on 295 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mogadishu&units=imperial
#
# Currently on 296 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zhanaozen&units=imperial
#
# Currently on 297 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vikulovo&units=imperial
#
# Currently on 298 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chapais&units=imperial
#
# Currently on 299 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yar-Sale&units=imperial
#
# Currently on 300 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Siilinjarvi&units=imperial
#
# Currently on 301 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hithadhoo&units=imperial
#
# Currently on 302 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Payson&units=imperial
#
# Currently on 303 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yuzhno-Yeniseyskiy&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 304 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Somerset&units=imperial
#
# Currently on 305 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zambezi&units=imperial
#
# Currently on 306 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Naryan-Mar&units=imperial
#
# Currently on 307 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bubaque&units=imperial
#
# Currently on 308 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Christchurch&units=imperial
#
# Currently on 309 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kupang&units=imperial
#
# Currently on 310 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Shiraz&units=imperial
#
# Currently on 311 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hasaki&units=imperial
#
# Currently on 312 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=High+Level&units=imperial
#
# Currently on 313 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Koygorodok&units=imperial
#
# Currently on 314 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Carutapera&units=imperial
#
# Currently on 315 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Artyk&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 316 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Umtata&units=imperial
#
# Currently on 317 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yushu&units=imperial
#
# Currently on 318 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Huicungo&units=imperial
#
# Currently on 319 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Krasnovishersk&units=imperial
#
# Currently on 320 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Clarence+Town&units=imperial
#
# Currently on 321 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Oranjemund&units=imperial
#
# Currently on 322 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bilibino&units=imperial
#
# Currently on 323 out of 913
# ...
#
# Currently on 806 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tefe&units=imperial
#
# Currently on 807 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Hedland&units=imperial
#
# Currently on 808 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Raudeberg&units=imperial
#
# Currently on 809 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bonoua&units=imperial
#
# Currently on 810 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Goderich&units=imperial
#
# Currently on 811 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yumen&units=imperial
#
# Currently on 812 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zychlin&units=imperial
#
# Currently on 813 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pailon&units=imperial
#
# Currently on 814 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Westport&units=imperial
#
# Currently on 815 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Petroton&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 816 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Leh&units=imperial
#
# Currently on 817 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dangriga&units=imperial
#
# Currently on 818 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Madras&units=imperial
#
# Currently on 819 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ati&units=imperial
#
# Currently on 820 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Baherden&units=imperial
#
# Currently on 821 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Conde&units=imperial
#
# Currently on 822 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Birin&units=imperial
#
# Currently on 823 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nicoya&units=imperial
#
# Currently on 824 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gladstone&units=imperial
#
# Currently on 825 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Meyungs&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 826 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tambura&units=imperial
#
# Currently on 827 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rincon&units=imperial
#
# Currently on 828 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kenzhe&units=imperial
#
# Currently on 829 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Emet&units=imperial
#
# Currently on 830 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Damaturu&units=imperial
# Currently on 831 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hamina&units=imperial
#
# Currently on 832 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Villa+Rica&units=imperial
#
# Currently on 833 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sao+Raimundo+Das+Mangabeiras&units=imperial
#
# Currently on 834 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vastervik&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 835 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Malpe&units=imperial
#
# Currently on 836 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jamestown&units=imperial
#
# Currently on 837 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Corpus+Christi&units=imperial
#
# Currently on 838 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pindiga&units=imperial
#
# Currently on 839 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mantua&units=imperial
#
# Currently on 840 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Luderitz&units=imperial
#
# Currently on 841 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Umm+Lajj&units=imperial
#
# Currently on 842 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ambon&units=imperial
#
# Currently on 843 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bermejo&units=imperial
#
# Currently on 844 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Astoria&units=imperial
#
# Currently on 845 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint-Joseph&units=imperial
#
# Currently on 846 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gangotri&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 847 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Wattegama&units=imperial
#
# Currently on 848 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tuensang&units=imperial
#
# Currently on 849 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Pedro&units=imperial
#
# Currently on 850 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Birao&units=imperial
#
# Currently on 851 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mentok&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 852 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Inverell&units=imperial
#
# Currently on 853 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bokspits&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 854 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nizwa&units=imperial
#
# Currently on 855 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lamu&units=imperial
#
# Currently on 856 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kota+Bahru&units=imperial
#
# Currently on 857 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chiredzi&units=imperial
#
# Currently on 858 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Guican&units=imperial
#
# Currently on 859 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Paramirim&units=imperial
#
# Currently on 860 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tanout&units=imperial
#
# Currently on 861 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aberdeen&units=imperial
#
# Currently on 862 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Teya&units=imperial
#
# Currently on 863 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Olafsvik&units=imperial
#
# Currently on 864 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Baisha&units=imperial
#
# Currently on 865 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kuito&units=imperial
#
# Currently on 866 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Omboue&units=imperial
#
# Currently on 867 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sterling&units=imperial
#
# Currently on 868 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Plattsburgh&units=imperial
#
# Currently on 869 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Winneba&units=imperial
#
# Currently on 870 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Veraval&units=imperial
#
# Currently on 871 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cauquenes&units=imperial
#
# Currently on 872 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kapuskasing&units=imperial
#
# Currently on 873 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Manzhouli&units=imperial
#
# Currently on 874 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cagayan+De+Tawi-Tawi&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 875 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yakeshi&units=imperial
#
# Currently on 876 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Davlekanovo&units=imperial
#
# Currently on 877 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tabas&units=imperial
#
# Currently on 878 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kashary&units=imperial
#
# Currently on 879 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pecos&units=imperial
#
# Currently on 880 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ghiror&units=imperial
#
# Currently on 881 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kargat&units=imperial
#
# Currently on 882 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Shakiso&units=imperial
#
# Currently on 883 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kitui&units=imperial
#
# Currently on 884 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Motihari&units=imperial
#
# Currently on 885 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kisiwani&units=imperial
# Currently on 886 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ust-Nera&units=imperial
#
# Currently on 887 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kirando&units=imperial
#
# Currently on 888 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Huinan&units=imperial
#
# Currently on 889 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Falealupo&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 890 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Wentzville&units=imperial
#
# Currently on 891 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Haapsalu&units=imperial
#
# Currently on 892 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Krasnyy+Chikoy&units=imperial
#
# Currently on 893 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Arani&units=imperial
#
# Currently on 894 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ulaangom&units=imperial
#
# Currently on 895 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Presidente+Epitacio&units=imperial
#
# Currently on 896 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sokoto&units=imperial
#
# Currently on 897 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Uige&units=imperial
#
# Currently on 898 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bac+Lieu&units=imperial
#
# Currently on 899 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Santander&units=imperial
#
# Currently on 900 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Khorramshahr&units=imperial
#
# Currently on 901 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Alnavar&units=imperial
#
# Currently on 902 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nelson+Bay&units=imperial
#
# Currently on 903 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pascagoula&units=imperial
#
# Currently on 904 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Plettenberg+Bay&units=imperial
#
# Currently on 905 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barao+De+Melgaco&units=imperial
#
# Currently on 906 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Beloha&units=imperial
#
# Currently on 907 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Larkana&units=imperial
#
# Currently on 908 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Obera&units=imperial
#
# Currently on 909 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Seymchan&units=imperial
#
# Currently on 910 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ridgecrest&units=imperial
#
# Currently on 911 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gondanglegi&units=imperial
#
# Currently on 912 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Severodvinsk&units=imperial
#
# Currently on 913 out of 913
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Otacilio+Costa&units=imperial

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Add collected weather data to Weather DF
weather_df["Temperature"] = temperature_list
weather_df["Humidity"] = humidity_list
weather_df["Coud Cover"] = cloudiness_list
weather_df["Wind Speed"] = wind_speed_list
weather_df["Date (UTC)"] = date_list

weather_df.head(100)
# Out:
#     Latitude  Longitude            City Country Temperature Humidity  \
# 0     -31.41      94.89       Carnarvon      AU        71.6     71.6
# 1      86.35      48.73   Belushya Guba      RU       Error    Error
# 2     -81.91    -169.58           Vaini      TO        73.4     73.4
# 3      21.69      76.74      Nepa Nagar      IN       71.19    71.19
# 4     -19.19     -12.15       Jamestown      SH       43.97    43.97
# ..       ...        ...             ...     ...         ...      ...
# 95      9.64     150.34        Lorengau      PG        84.9     84.9
# 96    -50.95     -48.40   Mar Del Plata      AR       59.67    59.67
# 97    -13.81     -49.54       Porangatu      BR       77.25    77.25
# 98     45.61     139.79        Svetlaya      RU        48.4     48.4
# 99     46.81     154.19  Severo-Kurilsk      RU       46.47    46.47
#
#    Coud Cover Wind Speed  Date (UTC)
# 0        71.6       71.6  1603674257
# 1       Error      Error       Error
# 2        73.4       73.4  1603674260
# 3       71.19      71.19  1603674261
# 4       43.97      43.97  1603673658
# ..        ...        ...         ...
# 95       84.9       84.9  1603674221
# 96      59.67      59.67  1603674092
# 97      77.25      77.25  1603674367
# 98       48.4       48.4  1603674369
# 99      46.47      46.47  1603674282
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
