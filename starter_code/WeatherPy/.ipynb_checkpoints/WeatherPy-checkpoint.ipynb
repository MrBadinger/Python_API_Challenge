# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# #Observations
# ---------------------
#
# * 1) We can see from our regression analysis that there are strong correlations between latitude and temperature.
# ------------------------------------------------------------------------------------------------------------------------------
# * 2) We can see from the regression analysis that there is correlation between latitude and the other relationships, but they have weak correlation. While latitude might have some impact, there are several other geographical factors that might have a greater impact.
# ------------------------------------------------------------------------------------------------------------------------------
# * 3) The number of cities greatly favored the Northern Hemisphere data. This was due to randomly generating the latitude coordinates at the beginning of the code. I feel like we got a more accurate sample of Northern Hemisphere weather data when compared to Southern Hemisphere data. We could run the code a few more times or at greater quantity to see how the data might have changed.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import requests
import json
from api_keys import weather_api_key
from citipy import citipy
import random
import decimal
import time

# %% [markdown]
# ## Generate Cities List

# %%
#set up latitude and longitude lists
latitude_list = []
longitude_list = []

# Generate 5000 random latitude and logitude values and add them to there respective list
for x in range(0, 5000):
    latitude = float(decimal.Decimal(random.randrange(-9000, 9000))/100)
    longitude = float(decimal.Decimal(random.randrange(-18000, 18000))/100)
    latitude_list.append(latitude)
    longitude_list.append(longitude)

# Set up the Weather DF
weather_df = pd.DataFrame({"Latitude": latitude_list, "Longitude": longitude_list})

# set up list to hold city names and what there country there from
city_list = []
country_list = []

# goes through each value of Latitude and Longitude in the Weather DF and uses the value as inputs to determin there city and country
for a in range(0, len(weather_df["Latitude"])):
    lat_value = weather_df.iloc[a]["Latitude"]
    long_value = weather_df.iloc[a]["Longitude"]    
    city_cord = citipy.nearest_city(lat_value, long_value)
    city_name = city_cord.city_name
    city_list.append(city_name)
    country = city_cord.country_code
    country_list.append(country)

    
# adds the city and country lists into our weather data frame, and then a touch of formatting   
weather_df["City"] = city_list
weather_df["Country"] = country_list
weather_df["City"] = weather_df["City"].str.title()
weather_df["Country"] = weather_df["Country"].str.upper()


#drop duplicates duplicates
weather_df = weather_df.drop_duplicates(subset=["City", "Country"], keep="first")
weather_df = weather_df.reset_index(drop=True)

print("Total number of unique cities in weather dataframe is: " + str(len(weather_df.index)))
# Out:
# Total number of unique cities in weather dataframe is: 1381

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set up list for variables we want
temperature_list = [] 
humidity_list = []
cloudiness_list = []
wind_speed_list = []
date_list = []
latitude_list_v2 = []
longitude_list_v2 = []
city_list_v2 = []
country_list_v2 = []

# Base URL before adding variable componets
url = "http://api.openweathermap.org/data/2.5/weather?"

    

for target in range(0, len(weather_df.index)):
    
    # Select city on weather DF, and formate for proper url code in event city has spaces in name
    display_city = weather_df.iloc[target]["City"]
    display_country = weather_df.iloc[target]["Country"]
    target_city = weather_df.iloc[target]["City"]
    target_city = target_city.replace(" ","+")
    
    # Build query URL
    query_url = f"{url}appid={weather_api_key}&q={target_city}&units=imperial"
    
    # Use URL to make a request of information, bring back in the json format, and print URL
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    print(f"Currently on {(target + 1)} out of {(len(weather_df.index))} |::| City: {display_city}, {display_country}")
    print(query_url)
    
    # This will collect and store desired information, but if there is an error it will print a line and move on to next
    try:
        cities_temp = weather_json["main"]["temp"]
        temperature_list.append(cities_temp)
        
        cities_humid = weather_json["main"]["humidity"]
        humidity_list.append(cities_humid)
        
        cities_cloud = weather_json["clouds"]["all"]
        cloudiness_list.append(cities_cloud)
        
        cities_wind = weather_json["wind"]["speed"]
        wind_speed_list.append(cities_wind)
        
        cities_date = weather_json["dt"]
        date_list.append(cities_date)
        
        cities_lat_update = weather_json["coord"]["lat"]
        latitude_list_v2.append(cities_lat_update)
        
        cities_long_update = weather_json["coord"]["lon"]
        longitude_list_v2.append(cities_long_update)
        
        cities_city_update = weather_json["name"]
        city_list_v2.append(cities_city_update)
        
        cities_con_update = weather_json["sys"]["country"]       
        country_list_v2.append(cities_con_update)
        
    except:
        print("I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.")
        
        # Usuccessful API request will result in a blank value in list that will throw off list alignment
        # We will but in a dummy value in its place to clean out later
        temperature_list.append("Error")
        humidity_list.append("Error")
        cloudiness_list.append("Error")
        wind_speed_list.append("Error")
        date_list.append("Error")
        latitude_list_v2.append("Error")
        longitude_list_v2.append("Error")
        city_list_v2.append("Error")
        country_list_v2.append("Error")
        
        
    print()
    
    # Add a sleep timer to prevent my API requests from going over 60 per min and causing a 1 hour lock out.
    time.sleep(1) # in seconds
# Out:
# Currently on 1 out of 1381 |::| City: Luau, AO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Luau&units=imperial
#
# Currently on 2 out of 1381 |::| City: Louisbourg, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Louisbourg&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 3 out of 1381 |::| City: Atuona, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Atuona&units=imperial
#
# Currently on 4 out of 1381 |::| City: Ilulissat, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ilulissat&units=imperial
#
# Currently on 5 out of 1381 |::| City: Albany, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Albany&units=imperial
#
# Currently on 6 out of 1381 |::| City: Port Elizabeth, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Elizabeth&units=imperial
#
# Currently on 7 out of 1381 |::| City: Yellowknife, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yellowknife&units=imperial
#
# Currently on 8 out of 1381 |::| City: Merauke, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Merauke&units=imperial
#
# Currently on 9 out of 1381 |::| City: Vaini, TO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vaini&units=imperial
#
# Currently on 10 out of 1381 |::| City: Barrow, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barrow&units=imperial
#
# Currently on 11 out of 1381 |::| City: Srednekolymsk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Srednekolymsk&units=imperial
#
# Currently on 12 out of 1381 |::| City: San Jeronimo, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Jeronimo&units=imperial
#
# Currently on 13 out of 1381 |::| City: Port-Cartier, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port-Cartier&units=imperial
#
# Currently on 14 out of 1381 |::| City: Mitsamiouli, KM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mitsamiouli&units=imperial
#
# Currently on 15 out of 1381 |::| City: Boulder, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Boulder&units=imperial
#
# Currently on 16 out of 1381 |::| City: Butaritari, KI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Butaritari&units=imperial
#
# Currently on 17 out of 1381 |::| City: Rikitea, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rikitea&units=imperial
#
# Currently on 18 out of 1381 |::| City: Clyde River, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Clyde+River&units=imperial
#
# Currently on 19 out of 1381 |::| City: Quang Ngai, VN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Quang+Ngai&units=imperial
#
# Currently on 20 out of 1381 |::| City: San Cristobal, EC
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Cristobal&units=imperial
#
# Currently on 21 out of 1381 |::| City: Busselton, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Busselton&units=imperial
#
# Currently on 22 out of 1381 |::| City: Yerofey Pavlovich, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yerofey+Pavlovich&units=imperial
#
# Currently on 23 out of 1381 |::| City: Markapur, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Markapur&units=imperial
#
# Currently on 24 out of 1381 |::| City: Chuy, UY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chuy&units=imperial
#
# Currently on 25 out of 1381 |::| City: Lao Cai, VN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lao+Cai&units=imperial
#
# Currently on 26 out of 1381 |::| City: Port Blair, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Blair&units=imperial
#
# Currently on 27 out of 1381 |::| City: Somerset East, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Somerset+East&units=imperial
#
# Currently on 28 out of 1381 |::| City: Khatanga, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Khatanga&units=imperial
#
# Currently on 29 out of 1381 |::| City: Punta Arenas, CL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Punta+Arenas&units=imperial
#
# Currently on 30 out of 1381 |::| City: Castro, CL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Castro&units=imperial
#
# Currently on 31 out of 1381 |::| City: Huilong, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Huilong&units=imperial
#
# Currently on 32 out of 1381 |::| City: Ancud, CL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ancud&units=imperial
#
# Currently on 33 out of 1381 |::| City: Egvekinot, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Egvekinot&units=imperial
#
# Currently on 34 out of 1381 |::| City: Amderma, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Amderma&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 35 out of 1381 |::| City: Provideniya, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Provideniya&units=imperial
#
# Currently on 36 out of 1381 |::| City: Rio Grande, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rio+Grande&units=imperial
#
# Currently on 37 out of 1381 |::| City: East London, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=East+London&units=imperial
#
# Currently on 38 out of 1381 |::| City: Wajid, SO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Wajid&units=imperial
#
# Currently on 39 out of 1381 |::| City: Chanute, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chanute&units=imperial
#
# Currently on 40 out of 1381 |::| City: Kodiak, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kodiak&units=imperial
#
# Currently on 41 out of 1381 |::| City: Honningsvag, NO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Honningsvag&units=imperial
#
# Currently on 42 out of 1381 |::| City: Montepuez, MZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Montepuez&units=imperial
#
# Currently on 43 out of 1381 |::| City: Mujiayingzi, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mujiayingzi&units=imperial
#
# Currently on 44 out of 1381 |::| City: Saint-Augustin, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint-Augustin&units=imperial
#
# Currently on 45 out of 1381 |::| City: Cape Town, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cape+Town&units=imperial
#
# Currently on 46 out of 1381 |::| City: Warqla, DZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Warqla&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 47 out of 1381 |::| City: Leninsk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Leninsk&units=imperial
#
# Currently on 48 out of 1381 |::| City: Gamba, GA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gamba&units=imperial
# Currently on 49 out of 1381 |::| City: Victoria, SC
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Victoria&units=imperial
#
# Currently on 50 out of 1381 |::| City: Airai, PW
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Airai&units=imperial
#
# Currently on 51 out of 1381 |::| City: Bambous Virieux, MU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bambous+Virieux&units=imperial
#
# Currently on 52 out of 1381 |::| City: Saint-Philippe, RE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint-Philippe&units=imperial
#
# Currently on 53 out of 1381 |::| City: Qaanaaq, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Qaanaaq&units=imperial
#
# Currently on 54 out of 1381 |::| City: Navrongo, GH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Navrongo&units=imperial
#
# Currently on 55 out of 1381 |::| City: Rocha, UY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rocha&units=imperial
#
# Currently on 56 out of 1381 |::| City: Mocuba, MZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mocuba&units=imperial
#
# Currently on 57 out of 1381 |::| City: Hermanus, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hermanus&units=imperial
#
# Currently on 58 out of 1381 |::| City: Lenger, KZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lenger&units=imperial
#
# Currently on 59 out of 1381 |::| City: Tiksi, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tiksi&units=imperial
#
# Currently on 60 out of 1381 |::| City: Puerto Ayora, EC
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Puerto+Ayora&units=imperial
#
# Currently on 61 out of 1381 |::| City: Hobart, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hobart&units=imperial
#
# Currently on 62 out of 1381 |::| City: Port Lincoln, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Lincoln&units=imperial
#
# Currently on 63 out of 1381 |::| City: Dingle, IE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dingle&units=imperial
#
# Currently on 64 out of 1381 |::| City: Tezu, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tezu&units=imperial
#
# Currently on 65 out of 1381 |::| City: Hilo, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hilo&units=imperial
#
# Currently on 66 out of 1381 |::| City: Sao Filipe, CV
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sao+Filipe&units=imperial
#
# Currently on 67 out of 1381 |::| City: Tukrah, LY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tukrah&units=imperial
#
# Currently on 68 out of 1381 |::| City: Saint George, BM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint+George&units=imperial
#
# Currently on 69 out of 1381 |::| City: Kapaa, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kapaa&units=imperial
#
# Currently on 70 out of 1381 |::| City: Upernavik, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Upernavik&units=imperial
#
# Currently on 71 out of 1381 |::| City: Sept-Iles, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sept-Iles&units=imperial
#
# Currently on 72 out of 1381 |::| City: Marawi, SD
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Marawi&units=imperial
#
# Currently on 73 out of 1381 |::| City: Mar Del Plata, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mar+Del+Plata&units=imperial
#
# Currently on 74 out of 1381 |::| City: Lebu, CL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lebu&units=imperial
#
# Currently on 75 out of 1381 |::| City: Biak, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Biak&units=imperial
#
# Currently on 76 out of 1381 |::| City: Kavieng, PG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kavieng&units=imperial
#
# Currently on 77 out of 1381 |::| City: Saryshagan, KZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saryshagan&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 78 out of 1381 |::| City: Port Alfred, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Alfred&units=imperial
#
# Currently on 79 out of 1381 |::| City: Mrirt, MA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mrirt&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 80 out of 1381 |::| City: Jamestown, SH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jamestown&units=imperial
#
# Currently on 81 out of 1381 |::| City: Bredasdorp, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bredasdorp&units=imperial
#
# Currently on 82 out of 1381 |::| City: Winnemucca, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Winnemucca&units=imperial
#
# Currently on 83 out of 1381 |::| City: Fortuna, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Fortuna&units=imperial
#
# Currently on 84 out of 1381 |::| City: Temir, KZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Temir&units=imperial
#
# Currently on 85 out of 1381 |::| City: Chokurdakh, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chokurdakh&units=imperial
#
# Currently on 86 out of 1381 |::| City: Ushuaia, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ushuaia&units=imperial
#
# Currently on 87 out of 1381 |::| City: Bluff, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bluff&units=imperial
#
# Currently on 88 out of 1381 |::| City: Itabera, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Itabera&units=imperial
#
# Currently on 89 out of 1381 |::| City: Missoula, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Missoula&units=imperial
#
# Currently on 90 out of 1381 |::| City: Veraval, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Veraval&units=imperial
#
# Currently on 91 out of 1381 |::| City: Hithadhoo, MV
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hithadhoo&units=imperial
#
# Currently on 92 out of 1381 |::| City: Tandalti, SD
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tandalti&units=imperial
#
# Currently on 93 out of 1381 |::| City: Podstepki, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Podstepki&units=imperial
#
# Currently on 94 out of 1381 |::| City: Hasaki, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hasaki&units=imperial
#
# Currently on 95 out of 1381 |::| City: Barawe, SO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barawe&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 96 out of 1381 |::| City: Gamboula, CF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gamboula&units=imperial
#
# Currently on 97 out of 1381 |::| City: Kuvandyk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kuvandyk&units=imperial
# Currently on 98 out of 1381 |::| City: Taolanaro, MG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Taolanaro&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 99 out of 1381 |::| City: Necochea, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Necochea&units=imperial
#
# Currently on 100 out of 1381 |::| City: Vetovo, BG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vetovo&units=imperial
#
# Currently on 101 out of 1381 |::| City: Rundu, NA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rundu&units=imperial
#
# Currently on 102 out of 1381 |::| City: Souillac, MU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Souillac&units=imperial
#
# Currently on 103 out of 1381 |::| City: Nikolskoye, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nikolskoye&units=imperial
#
# Currently on 104 out of 1381 |::| City: Arraial Do Cabo, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Arraial+Do+Cabo&units=imperial
#
# Currently on 105 out of 1381 |::| City: Illoqqortoormiut, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Illoqqortoormiut&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 106 out of 1381 |::| City: Atar, MR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Atar&units=imperial
#
# Currently on 107 out of 1381 |::| City: Mataura, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mataura&units=imperial
#
# Currently on 108 out of 1381 |::| City: Pisco, PE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pisco&units=imperial
#
# Currently on 109 out of 1381 |::| City: Korla, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Korla&units=imperial
#
# Currently on 110 out of 1381 |::| City: At-Bashi, KG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=At-Bashi&units=imperial
#
# Currently on 111 out of 1381 |::| City: Barentsburg, SJ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barentsburg&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 112 out of 1381 |::| City: Aykhal, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aykhal&units=imperial
#
# Currently on 113 out of 1381 |::| City: Itoman, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Itoman&units=imperial
#
# Currently on 114 out of 1381 |::| City: Tateyama, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tateyama&units=imperial
#
# Currently on 115 out of 1381 |::| City: Kysyl-Syr, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kysyl-Syr&units=imperial
#
# Currently on 116 out of 1381 |::| City: Ust-Kamchatsk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ust-Kamchatsk&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 117 out of 1381 |::| City: Dikson, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dikson&units=imperial
#
# Currently on 118 out of 1381 |::| City: Geraldton, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Geraldton&units=imperial
#
# Currently on 119 out of 1381 |::| City: Ust-Nera, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ust-Nera&units=imperial
#
# Currently on 120 out of 1381 |::| City: Beringovskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Beringovskiy&units=imperial
#
# Currently on 121 out of 1381 |::| City: New Norfolk, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=New+Norfolk&units=imperial
#
# Currently on 122 out of 1381 |::| City: Goderich, SL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Goderich&units=imperial
#
# Currently on 123 out of 1381 |::| City: Sayyan, YE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sayyan&units=imperial
#
# Currently on 124 out of 1381 |::| City: Ostersund, SE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ostersund&units=imperial
#
# Currently on 125 out of 1381 |::| City: Treinta Y Tres, UY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Treinta+Y+Tres&units=imperial
#
# Currently on 126 out of 1381 |::| City: Georgetown, SH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Georgetown&units=imperial
#
# Currently on 127 out of 1381 |::| City: Podgornoye, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Podgornoye&units=imperial
#
# Currently on 128 out of 1381 |::| City: Pangnirtung, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pangnirtung&units=imperial
#
# Currently on 129 out of 1381 |::| City: Mandera, KE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mandera&units=imperial
#
# Currently on 130 out of 1381 |::| City: Caravelas, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Caravelas&units=imperial
#
# Currently on 131 out of 1381 |::| City: Tabory, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tabory&units=imperial
#
# Currently on 132 out of 1381 |::| City: Sisimiut, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sisimiut&units=imperial
#
# Currently on 133 out of 1381 |::| City: Hofn, IS
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hofn&units=imperial
#
# Currently on 134 out of 1381 |::| City: Belushya Guba, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Belushya+Guba&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 135 out of 1381 |::| City: Ginda, ER
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ginda&units=imperial
#
# Currently on 136 out of 1381 |::| City: Iranshahr, IR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Iranshahr&units=imperial
#
# Currently on 137 out of 1381 |::| City: Anadyr, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Anadyr&units=imperial
#
# Currently on 138 out of 1381 |::| City: Visp, CH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Visp&units=imperial
#
# Currently on 139 out of 1381 |::| City: Lodja, CD
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lodja&units=imperial
#
# Currently on 140 out of 1381 |::| City: Mwinilunga, ZM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mwinilunga&units=imperial
#
# Currently on 141 out of 1381 |::| City: Bonthe, SL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bonthe&units=imperial
#
# Currently on 142 out of 1381 |::| City: Mahadday Weyne, SO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mahadday+Weyne&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 143 out of 1381 |::| City: Ostrovnoy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ostrovnoy&units=imperial
# Currently on 144 out of 1381 |::| City: Turukhansk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Turukhansk&units=imperial
#
# Currently on 145 out of 1381 |::| City: Puerto Escondido, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Puerto+Escondido&units=imperial
#
# Currently on 146 out of 1381 |::| City: Nampula, MZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nampula&units=imperial
#
# Currently on 147 out of 1381 |::| City: Chaykovskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chaykovskiy&units=imperial
#
# Currently on 148 out of 1381 |::| City: Grand River South East, MU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Grand+River+South+East&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 149 out of 1381 |::| City: Tamandare, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tamandare&units=imperial
#
# Currently on 150 out of 1381 |::| City: Kingaroy, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kingaroy&units=imperial
#
# Currently on 151 out of 1381 |::| City: Ponta Do Sol, CV
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ponta+Do+Sol&units=imperial
#
# Currently on 152 out of 1381 |::| City: Georgetown, GY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Georgetown&units=imperial
#
# Currently on 153 out of 1381 |::| City: Bengkulu, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bengkulu&units=imperial
#
# Currently on 154 out of 1381 |::| City: Bethel, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bethel&units=imperial
#
# Currently on 155 out of 1381 |::| City: Ribeira Grande, PT
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ribeira+Grande&units=imperial
#
# Currently on 156 out of 1381 |::| City: Safakulevo, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Safakulevo&units=imperial
#
# Currently on 157 out of 1381 |::| City: Attawapiskat, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Attawapiskat&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 158 out of 1381 |::| City: Flinders, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Flinders&units=imperial
#
# Currently on 159 out of 1381 |::| City: Sovetskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sovetskiy&units=imperial
#
# Currently on 160 out of 1381 |::| City: Faanui, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Faanui&units=imperial
#
# Currently on 161 out of 1381 |::| City: Kabwe, ZM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kabwe&units=imperial
#
# Currently on 162 out of 1381 |::| City: Tabiauea, KI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tabiauea&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 163 out of 1381 |::| City: Longyearbyen, SJ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Longyearbyen&units=imperial
#
# Currently on 164 out of 1381 |::| City: Tayturka, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tayturka&units=imperial
#
# Currently on 165 out of 1381 |::| City: Kruisfontein, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kruisfontein&units=imperial
#
# Currently on 166 out of 1381 |::| City: Tuatapere, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tuatapere&units=imperial
#
# Currently on 167 out of 1381 |::| City: Bolungarvik, IS
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bolungarvik&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 168 out of 1381 |::| City: Lagunas, PE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lagunas&units=imperial
#
# Currently on 169 out of 1381 |::| City: San Carlos De Bariloche, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Carlos+De+Bariloche&units=imperial
#
# Currently on 170 out of 1381 |::| City: Tazovskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tazovskiy&units=imperial
#
# Currently on 171 out of 1381 |::| City: Marcona, PE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Marcona&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 172 out of 1381 |::| City: Jiddah, SA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jiddah&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 173 out of 1381 |::| City: North Bend, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=North+Bend&units=imperial
#
# Currently on 174 out of 1381 |::| City: Codrington, AG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Codrington&units=imperial
#
# Currently on 175 out of 1381 |::| City: Gat, LY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gat&units=imperial
#
# Currently on 176 out of 1381 |::| City: Thompson, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Thompson&units=imperial
#
# Currently on 177 out of 1381 |::| City: Alofi, NU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Alofi&units=imperial
#
# Currently on 178 out of 1381 |::| City: Ossora, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ossora&units=imperial
#
# Currently on 179 out of 1381 |::| City: Sena Madureira, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sena+Madureira&units=imperial
#
# Currently on 180 out of 1381 |::| City: Cherskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cherskiy&units=imperial
#
# Currently on 181 out of 1381 |::| City: Tasiilaq, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tasiilaq&units=imperial
#
# Currently on 182 out of 1381 |::| City: Key Largo, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Key+Largo&units=imperial
#
# Currently on 183 out of 1381 |::| City: Avera, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Avera&units=imperial
#
# Currently on 184 out of 1381 |::| City: Ahipara, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ahipara&units=imperial
#
# Currently on 185 out of 1381 |::| City: Nouadhibou, MR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nouadhibou&units=imperial
#
# Currently on 186 out of 1381 |::| City: San Juan, HN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Juan&units=imperial
#
# Currently on 187 out of 1381 |::| City: Alamosa, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Alamosa&units=imperial
#
# Currently on 188 out of 1381 |::| City: Tommot, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tommot&units=imperial
#
# Currently on 189 out of 1381 |::| City: Torbay, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Torbay&units=imperial
# Currently on 190 out of 1381 |::| City: Burgeo, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Burgeo&units=imperial
#
# Currently on 191 out of 1381 |::| City: Cap Malheureux, MU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cap+Malheureux&units=imperial
#
# Currently on 192 out of 1381 |::| City: Cabo San Lucas, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cabo+San+Lucas&units=imperial
#
# Currently on 193 out of 1381 |::| City: Mahajanga, MG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mahajanga&units=imperial
#
# Currently on 194 out of 1381 |::| City: Marsh Harbour, BS
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Marsh+Harbour&units=imperial
#
# Currently on 195 out of 1381 |::| City: Maragogi, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maragogi&units=imperial
#
# Currently on 196 out of 1381 |::| City: Broken Hill, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Broken+Hill&units=imperial
#
# Currently on 197 out of 1381 |::| City: Kenai, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kenai&units=imperial
#
# Currently on 198 out of 1381 |::| City: Boden, SE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Boden&units=imperial
#
# Currently on 199 out of 1381 |::| City: Hosakote, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hosakote&units=imperial
#
# Currently on 200 out of 1381 |::| City: Lata, SB
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lata&units=imperial
#
# Currently on 201 out of 1381 |::| City: Kazachinskoye, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kazachinskoye&units=imperial
#
# Currently on 202 out of 1381 |::| City: Letlhakane, BW
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Letlhakane&units=imperial
#
# Currently on 203 out of 1381 |::| City: Tapes, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tapes&units=imperial
#
# Currently on 204 out of 1381 |::| City: Ayaviri, PE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ayaviri&units=imperial
#
# Currently on 205 out of 1381 |::| City: Pangai, TO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pangai&units=imperial
#
# Currently on 206 out of 1381 |::| City: Vaitupu, WF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vaitupu&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 207 out of 1381 |::| City: Severnyy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Severnyy&units=imperial
#
# Currently on 208 out of 1381 |::| City: Labytnangi, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Labytnangi&units=imperial
#
# Currently on 209 out of 1381 |::| City: Dickinson, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dickinson&units=imperial
#
# Currently on 210 out of 1381 |::| City: Northam, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Northam&units=imperial
#
# Currently on 211 out of 1381 |::| City: Zhuanghe, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zhuanghe&units=imperial
#
# Currently on 212 out of 1381 |::| City: Adolfo Lopez Mateos, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Adolfo+Lopez+Mateos&units=imperial
#
# Currently on 213 out of 1381 |::| City: Carnarvon, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Carnarvon&units=imperial
#
# Currently on 214 out of 1381 |::| City: Burnie, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Burnie&units=imperial
#
# Currently on 215 out of 1381 |::| City: Oum Hadjer, TD
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Oum+Hadjer&units=imperial
#
# Currently on 216 out of 1381 |::| City: Pacific Grove, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pacific+Grove&units=imperial
#
# Currently on 217 out of 1381 |::| City: Okhotsk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Okhotsk&units=imperial
#
# Currently on 218 out of 1381 |::| City: Sitka, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sitka&units=imperial
#
# Currently on 219 out of 1381 |::| City: Muzhi, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Muzhi&units=imperial
#
# Currently on 220 out of 1381 |::| City: Ternate, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ternate&units=imperial
#
# Currently on 221 out of 1381 |::| City: Palmer, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Palmer&units=imperial
#
# Currently on 222 out of 1381 |::| City: Kidal, ML
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kidal&units=imperial
#
# Currently on 223 out of 1381 |::| City: Colesberg, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Colesberg&units=imperial
#
# Currently on 224 out of 1381 |::| City: Myhove, UA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Myhove&units=imperial
#
# Currently on 225 out of 1381 |::| City: Buariki, KI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Buariki&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 226 out of 1381 |::| City: Norman Wells, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Norman+Wells&units=imperial
#
# Currently on 227 out of 1381 |::| City: Baykit, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Baykit&units=imperial
#
# Currently on 228 out of 1381 |::| City: Maniitsoq, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maniitsoq&units=imperial
#
# Currently on 229 out of 1381 |::| City: Lere, NG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lere&units=imperial
#
# Currently on 230 out of 1381 |::| City: Yulara, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yulara&units=imperial
#
# Currently on 231 out of 1381 |::| City: Eureka, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Eureka&units=imperial
#
# Currently on 232 out of 1381 |::| City: Pecos, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pecos&units=imperial
#
# Currently on 233 out of 1381 |::| City: Lorengau, PG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lorengau&units=imperial
#
# Currently on 234 out of 1381 |::| City: Talnakh, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Talnakh&units=imperial
#
# Currently on 235 out of 1381 |::| City: Jiayuguan, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jiayuguan&units=imperial
#
# Currently on 236 out of 1381 |::| City: Leningradskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Leningradskiy&units=imperial
#
# Currently on 237 out of 1381 |::| City: Altamont, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Altamont&units=imperial
#
# Currently on 238 out of 1381 |::| City: Lokoja, NG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lokoja&units=imperial
# Currently on 239 out of 1381 |::| City: Kaitangata, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kaitangata&units=imperial
#
# Currently on 240 out of 1381 |::| City: Samarai, PG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Samarai&units=imperial
#
# Currently on 241 out of 1381 |::| City: Bud, NO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bud&units=imperial
#
# Currently on 242 out of 1381 |::| City: Ola, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ola&units=imperial
#
# Currently on 243 out of 1381 |::| City: Birao, CF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Birao&units=imperial
#
# Currently on 244 out of 1381 |::| City: Padang, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Padang&units=imperial
#
# Currently on 245 out of 1381 |::| City: Luwero, UG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Luwero&units=imperial
#
# Currently on 246 out of 1381 |::| City: Cidreira, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cidreira&units=imperial
#
# Currently on 247 out of 1381 |::| City: Burg, DE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Burg&units=imperial
#
# Currently on 248 out of 1381 |::| City: Nioro, ML
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nioro&units=imperial
#
# Currently on 249 out of 1381 |::| City: Nanortalik, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nanortalik&units=imperial
#
# Currently on 250 out of 1381 |::| City: Boende, CD
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Boende&units=imperial
#
# Currently on 251 out of 1381 |::| City: Kahului, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kahului&units=imperial
#
# Currently on 252 out of 1381 |::| City: Blackwater, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Blackwater&units=imperial
#
# Currently on 253 out of 1381 |::| City: Batagay, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Batagay&units=imperial
#
# Currently on 254 out of 1381 |::| City: Vila Franca Do Campo, PT
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vila+Franca+Do+Campo&units=imperial
#
# Currently on 255 out of 1381 |::| City: Kiknur, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kiknur&units=imperial
#
# Currently on 256 out of 1381 |::| City: Nizhneyansk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nizhneyansk&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 257 out of 1381 |::| City: Tsihombe, MG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tsihombe&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 258 out of 1381 |::| City: Zhigansk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zhigansk&units=imperial
#
# Currently on 259 out of 1381 |::| City: Chabua, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chabua&units=imperial
#
# Currently on 260 out of 1381 |::| City: Mkushi, ZM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mkushi&units=imperial
#
# Currently on 261 out of 1381 |::| City: Uwayl, SD
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Uwayl&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 262 out of 1381 |::| City: Westport, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Westport&units=imperial
#
# Currently on 263 out of 1381 |::| City: Terrasini, IT
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Terrasini&units=imperial
#
# Currently on 264 out of 1381 |::| City: Mahebourg, MU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mahebourg&units=imperial
#
# Currently on 265 out of 1381 |::| City: Conde, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Conde&units=imperial
#
# Currently on 266 out of 1381 |::| City: Kattivakkam, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kattivakkam&units=imperial
#
# Currently on 267 out of 1381 |::| City: Irtyshskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Irtyshskiy&units=imperial
#
# Currently on 268 out of 1381 |::| City: Mys Shmidta, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mys+Shmidta&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 269 out of 1381 |::| City: Avarua, CK
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Avarua&units=imperial
#
# Currently on 270 out of 1381 |::| City: Ixtapa, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ixtapa&units=imperial
#
# Currently on 271 out of 1381 |::| City: Ucluelet, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ucluelet&units=imperial
#
# Currently on 272 out of 1381 |::| City: Aklavik, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aklavik&units=imperial
#
# Currently on 273 out of 1381 |::| City: Mayo, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mayo&units=imperial
#
# Currently on 274 out of 1381 |::| City: Le Pont-De-Claix, FR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Le+Pont-De-Claix&units=imperial
#
# Currently on 275 out of 1381 |::| City: Pishin, PK
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pishin&units=imperial
#
# ...
#
# Currently on 1290 out of 1381 |::| City: Crab Hill, BB
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Crab+Hill&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1291 out of 1381 |::| City: Longjiang, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Longjiang&units=imperial
#
# Currently on 1292 out of 1381 |::| City: Bougouni, ML
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bougouni&units=imperial
#
# Currently on 1293 out of 1381 |::| City: Etchoropo, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Etchoropo&units=imperial
#
# Currently on 1294 out of 1381 |::| City: Safford, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Safford&units=imperial
#
# Currently on 1295 out of 1381 |::| City: Sibu, MY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sibu&units=imperial
#
# Currently on 1296 out of 1381 |::| City: Victoria Point, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Victoria+Point&units=imperial
#
# Currently on 1297 out of 1381 |::| City: Bafoulabe, ML
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bafoulabe&units=imperial
#
# Currently on 1298 out of 1381 |::| City: Maltahohe, NA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maltahohe&units=imperial
#
# Currently on 1299 out of 1381 |::| City: Garango, BF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Garango&units=imperial
#
# Currently on 1300 out of 1381 |::| City: Tomatlan, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tomatlan&units=imperial
#
# Currently on 1301 out of 1381 |::| City: Gambela, ET
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gambela&units=imperial
#
# Currently on 1302 out of 1381 |::| City: Inverness, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Inverness&units=imperial
#
# Currently on 1303 out of 1381 |::| City: Eaglesham, GB
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Eaglesham&units=imperial
#
# Currently on 1304 out of 1381 |::| City: Baracoa, CU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Baracoa&units=imperial
#
# Currently on 1305 out of 1381 |::| City: Po, BF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Po&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1306 out of 1381 |::| City: Paka, MY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Paka&units=imperial
#
# Currently on 1307 out of 1381 |::| City: Kushmurun, KZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kushmurun&units=imperial
#
# Currently on 1308 out of 1381 |::| City: Praxedis Guerrero, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Praxedis+Guerrero&units=imperial
#
# Currently on 1309 out of 1381 |::| City: Tahoua, NE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tahoua&units=imperial
#
# Currently on 1310 out of 1381 |::| City: Santa Maria, CV
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Santa+Maria&units=imperial
#
# Currently on 1311 out of 1381 |::| City: Kambove, CD
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kambove&units=imperial
#
# Currently on 1312 out of 1381 |::| City: Tlachichuca, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tlachichuca&units=imperial
#
# Currently on 1313 out of 1381 |::| City: Esso, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Esso&units=imperial
#
# Currently on 1314 out of 1381 |::| City: Colombo, LK
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Colombo&units=imperial
#
# Currently on 1315 out of 1381 |::| City: Todos Santos, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Todos+Santos&units=imperial
#
# Currently on 1316 out of 1381 |::| City: Nioro, SN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nioro&units=imperial
#
# Currently on 1317 out of 1381 |::| City: Cayenne, GF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cayenne&units=imperial
#
# Currently on 1318 out of 1381 |::| City: Krasnaya Poyma, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Krasnaya+Poyma&units=imperial
#
# Currently on 1319 out of 1381 |::| City: Naberera, TZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Naberera&units=imperial
#
# Currently on 1320 out of 1381 |::| City: Solenzo, BF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Solenzo&units=imperial
#
# Currently on 1321 out of 1381 |::| City: Doha, KW
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Doha&units=imperial
#
# Currently on 1322 out of 1381 |::| City: Bandarbeyla, SO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bandarbeyla&units=imperial
#
# Currently on 1323 out of 1381 |::| City: Beihai, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Beihai&units=imperial
#
# Currently on 1324 out of 1381 |::| City: Satitoa, WS
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Satitoa&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1325 out of 1381 |::| City: Pinega, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pinega&units=imperial
#
# Currently on 1326 out of 1381 |::| City: Yelizovo, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yelizovo&units=imperial
#
# Currently on 1327 out of 1381 |::| City: Toyooka, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Toyooka&units=imperial
#
# Currently on 1328 out of 1381 |::| City: Morristown, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Morristown&units=imperial
#
# Currently on 1329 out of 1381 |::| City: Karur, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Karur&units=imperial
#
# Currently on 1330 out of 1381 |::| City: Tavricheskoye, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tavricheskoye&units=imperial
#
# Currently on 1331 out of 1381 |::| City: Juquitiba, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Juquitiba&units=imperial
#
# Currently on 1332 out of 1381 |::| City: Aleksandrovsk-Sakhalinskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aleksandrovsk-Sakhalinskiy&units=imperial
#
# Currently on 1333 out of 1381 |::| City: Ures, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ures&units=imperial
#
# Currently on 1334 out of 1381 |::| City: Usinsk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Usinsk&units=imperial
#
# Currently on 1335 out of 1381 |::| City: Amuntai, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Amuntai&units=imperial
#
# Currently on 1336 out of 1381 |::| City: Vestbygda, NO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vestbygda&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
# Currently on 1337 out of 1381 |::| City: Sturgeon Bay, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sturgeon+Bay&units=imperial
#
# Currently on 1338 out of 1381 |::| City: Bokovskaya, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bokovskaya&units=imperial
#
# Currently on 1339 out of 1381 |::| City: Mahibadhoo, MV
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mahibadhoo&units=imperial
#
# Currently on 1340 out of 1381 |::| City: Atambua, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Atambua&units=imperial
#
# Currently on 1341 out of 1381 |::| City: Hue, VN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hue&units=imperial
#
# Currently on 1342 out of 1381 |::| City: Pizarro, CO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pizarro&units=imperial
#
# Currently on 1343 out of 1381 |::| City: Tabarqah, TN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tabarqah&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1344 out of 1381 |::| City: Kiama, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kiama&units=imperial
#
# Currently on 1345 out of 1381 |::| City: Zabol, IR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zabol&units=imperial
#
# Currently on 1346 out of 1381 |::| City: Muzaffarabad, PK
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Muzaffarabad&units=imperial
#
# Currently on 1347 out of 1381 |::| City: Klodzko, PL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Klodzko&units=imperial
#
# Currently on 1348 out of 1381 |::| City: Samsun, TR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Samsun&units=imperial
#
# Currently on 1349 out of 1381 |::| City: Mzimba, MW
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mzimba&units=imperial
#
# Currently on 1350 out of 1381 |::| City: Baghmara, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Baghmara&units=imperial
#
# Currently on 1351 out of 1381 |::| City: Wencheng, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Wencheng&units=imperial
#
# Currently on 1352 out of 1381 |::| City: Karasjok, NO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Karasjok&units=imperial
#
# Currently on 1353 out of 1381 |::| City: Tevaitoa, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tevaitoa&units=imperial
#
# Currently on 1354 out of 1381 |::| City: Ishigaki, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ishigaki&units=imperial
#
# Currently on 1355 out of 1381 |::| City: Tacna, PE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tacna&units=imperial
#
# Currently on 1356 out of 1381 |::| City: Novotroitsk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Novotroitsk&units=imperial
#
# Currently on 1357 out of 1381 |::| City: Jiuquan, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jiuquan&units=imperial
#
# Currently on 1358 out of 1381 |::| City: Tabou, CI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tabou&units=imperial
#
# Currently on 1359 out of 1381 |::| City: Khandyga, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Khandyga&units=imperial
#
# Currently on 1360 out of 1381 |::| City: Caconda, AO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Caconda&units=imperial
#
# Currently on 1361 out of 1381 |::| City: Whitecourt, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Whitecourt&units=imperial
#
# Currently on 1362 out of 1381 |::| City: Villaviciosa, ES
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Villaviciosa&units=imperial
#
# Currently on 1363 out of 1381 |::| City: Along, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Along&units=imperial
#
# Currently on 1364 out of 1381 |::| City: Malwan, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Malwan&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 1365 out of 1381 |::| City: Kishtwar, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kishtwar&units=imperial
#
# Currently on 1366 out of 1381 |::| City: Tigil, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tigil&units=imperial
#
# Currently on 1367 out of 1381 |::| City: Ivanivka, UA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ivanivka&units=imperial
#
# Currently on 1368 out of 1381 |::| City: Bodden Town, KY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bodden+Town&units=imperial
#
# Currently on 1369 out of 1381 |::| City: Kenora, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kenora&units=imperial
#
# Currently on 1370 out of 1381 |::| City: Oussouye, SN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Oussouye&units=imperial
#
# Currently on 1371 out of 1381 |::| City: Benjamin Hill, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Benjamin+Hill&units=imperial
#
# Currently on 1372 out of 1381 |::| City: Campanario, PT
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Campanario&units=imperial
#
# Currently on 1373 out of 1381 |::| City: Aksu, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aksu&units=imperial
#
# Currently on 1374 out of 1381 |::| City: Zaraza, VE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zaraza&units=imperial
#
# Currently on 1375 out of 1381 |::| City: Watertown, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Watertown&units=imperial
#
# Currently on 1376 out of 1381 |::| City: Haapiti, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Haapiti&units=imperial
#
# Currently on 1377 out of 1381 |::| City: Kozhva, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kozhva&units=imperial
#
# Currently on 1378 out of 1381 |::| City: Takaungu, KE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Takaungu&units=imperial
#
# Currently on 1379 out of 1381 |::| City: Tocopilla, CL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tocopilla&units=imperial
#
# Currently on 1380 out of 1381 |::| City: Imbituba, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Imbituba&units=imperial
#
# Currently on 1381 out of 1381 |::| City: Sars, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sars&units=imperial

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Add collected weather data to Weather DF
weather_df["Temperature (F)"] = temperature_list
weather_df["Humidity (%)"] = humidity_list
weather_df["Cloud Cover (%)"] = cloudiness_list
weather_df["Wind Speed (MPH)"] = wind_speed_list
weather_df["Date (UTC)"] = date_list
weather_df["Latitude"] = latitude_list_v2
weather_df["Longitude"] = longitude_list_v2
weather_df["City"] = city_list_v2
weather_df["Country"] = country_list_v2

# Drop rows where we assigned Error too, because there was no data to pull
weather_df_v2 = weather_df[weather_df["Temperature (F)"] != "Error"]

# Reset Index after removing errors
weather_df_v2 = weather_df_v2.reset_index(drop=True)

# Save DF as .csv
weather_df_v2.to_csv("weather_data.csv")

print("Total number of unique cities in weather dataframe is: " + str(len(weather_df_v2.index)))
weather_df_v2.head(5)
# Out:
# Total number of unique cities in weather dataframe is: 1279
#   Latitude Longitude            City Country Temperature (F) Humidity (%)  \
# 0   -10.71     22.22            Luau      AO              66           97
# 1     -9.8   -139.03          Atuona      PF            78.8           73
# 2    69.22     -51.1       Ilulissat      GL              14           61
# 3     42.6    -73.97          Albany      US           44.33           84
# 4   -33.92     25.57  Port Elizabeth      ZA            62.6           72
#
#   Cloud Cover (%) Wind Speed (MPH)  Date (UTC)
# 0             100             2.71  1603853873
# 1               1            19.39  1603853875
# 2              82             2.42  1603853876
# 3             100             0.69  1603853800
# 4               0             3.36  1603853879

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get list of the indices of cities that have humidity over 100%.

over_100 = weather_df_v2.index[weather_df_v2["Humidity (%)"] > 100].tolist()
print(over_100)
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df_v2.drop(over_100)


clean_city_data = clean_city_data.reset_index(drop=True)
print("Total number of unique cities in weather dataframe is: " + str(len(weather_df_v2.index)))
clean_city_data.head(100)
# Out:
# Total number of unique cities in weather dataframe is: 1279
#    Latitude Longitude             City Country Temperature (F) Humidity (%)  \
# 0    -10.71     22.22             Luau      AO              66           97
# 1      -9.8   -139.03           Atuona      PF            78.8           73
# 2     69.22     -51.1        Ilulissat      GL              14           61
# 3      42.6    -73.97           Albany      US           44.33           84
# 4    -33.92     25.57   Port Elizabeth      ZA            62.6           72
# ..      ...       ...              ...     ...             ...          ...
# 95     59.7     30.79       Nikolskoye      RU            51.6           87
# 96   -22.97    -42.03  Arraial do Cabo      BR           72.77           90
# 97    20.52    -13.05             Atar      MR           80.82           24
# 98   -46.19    168.86          Mataura      NZ           55.99           74
# 99    -13.7    -76.22            Pisco      PE           62.76           82
#
#    Cloud Cover (%) Wind Speed (MPH)  Date (UTC)
# 0              100             2.71  1603853873
# 1                1            19.39  1603853875
# 2               82             2.42  1603853876
# 3              100             0.69  1603853800
# 4                0             3.36  1603853879
# ..             ...              ...         ...
# 95              90            11.18  1603853990
# 96              26            19.66  1603853991
# 97              15            10.38  1603853993
# 98              98               10  1603853994
# 99               0            11.41  1603853995
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Temperature (F)"]

# Create Scatter Plot
fig_1 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Temperature - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

fig_1.figure.savefig('lat_v_temp.png')

print("This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.")

plt.show
# Out:
# This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Humidity (%)"]

# Create Scatter Plot
fig_2 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Humidity - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

fig_2.figure.savefig('lat_v_humid.png')

print("This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Cloud Cover (%)"]

# Create Scatter Plot
fig_3 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Cloudiness - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

fig_3.figure.savefig('lat_v_cloud.png')


print("This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Wind Speed (MPH)"]

# Create Scatter Plot
fig_4 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Wind Speed - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

fig_4.figure.savefig('lat_v_wind.png')


print("This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.")




plt.show
# Out:
# This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Linear Regression

# %%
# Set Clean City DF to North and South Hemispheres
north_hem = clean_city_data[clean_city_data["Latitude"] > 0]
south_hem = clean_city_data[clean_city_data["Latitude"] < 0]
print("Total number of unique cities in Northern Hemisphere is: " + str(len(north_hem.index)))
print("Total number of unique cities in Southern Hemisphere is: " + str(len(south_hem.index)))
# Out:
# Total number of unique cities in Northern Hemisphere is: 916
# Total number of unique cities in Southern Hemisphere is: 363

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set Axises

x_axis = north_hem["Latitude"]
y_axis = north_hem["Temperature (F)"]

# Create Scatter Plot
fig_5 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Northern Hemisphere - Latitude vs. Temperature - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")


# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")




fig_5.figure.savefig('n_hem_lat_v_temp.png')

print("This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.")

plt.show
# Out:
# The correlation between both factors is -0.87
# This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set Axises

x_axis = south_hem["Latitude"]
y_axis = south_hem["Temperature (F)"]

# Create Scatter Plot
fig_6 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("southern Hemisphere - Latitude vs. Temperature - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")


# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-90, 90),fontsize=15,color="red")




fig_6.figure.savefig('s_hem_lat_v_temp.png')

print("This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.")

plt.show
# Out:
# The correlation between both factors is 0.63
# This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = north_hem["Latitude"]
y_axis = north_hem["Humidity (%)"]

# Create Scatter Plot
fig_7 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Humidity - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=15,color="red")



fig_7.figure.savefig('n_hem_lat_v_humid.png')

print("This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.27
# This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = south_hem["Latitude"]
y_axis = south_hem["Humidity (%)"]

# Create Scatter Plot
fig_8 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Humidity - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")


# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-80,20),fontsize=15,color="red")


fig_8.figure.savefig('s_hem_lat_v_humid.png')

print("This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.23
# This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = north_hem["Latitude"]
y_axis = north_hem["Cloud Cover (%)"]

# Create Scatter Plot
fig_9 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Cloudiness - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(50,30),fontsize=15,color="red")



fig_9.figure.savefig('n_hem_lat_v_cloud.png')


print("This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.14
# This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = south_hem["Latitude"]
y_axis = south_hem["Cloud Cover (%)"]

# Create Scatter Plot
fig_10 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Cloudiness - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-90,20),fontsize=15,color="red")




fig_10.figure.savefig('s_hem_lat_v_cloud.png')


print("This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.19
# This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = north_hem["Latitude"]
y_axis = north_hem["Wind Speed (MPH)"]

# Create Scatter Plot
fig_11 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Wind Speed - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")


fig_11.figure.savefig('n_hem_lat_v_wind.png')


print("This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.")




plt.show
# Out:
# The correlation between both factors is 0.13
# This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = south_hem["Latitude"]
y_axis = south_hem["Wind Speed (MPH)"]

# Create Scatter Plot
fig_12 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Wind Speed - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-90,18),fontsize=15,color="red")


fig_12.figure.savefig('s_hem_lat_v_wind.png')


print("This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.")




plt.show
# Out:
# The correlation between both factors is -0.26
# This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>
