# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# #Observations
# ---------------------
#
# * 1) We can see from our regression analysis that there are strong correlations between latitude and temperature.
# ------------------------------------------------------------------------------------------------------------------------------
# * 2) We can see from the regression analysis that there is correlation between latitude and the other relationships, but they have weak correlation. While latitude might have some impact, there are several other geographical factors that might have a greater impact.
# ------------------------------------------------------------------------------------------------------------------------------
# * 3) The number of cities in the Northern Hemisphere data was 598, and 253 in the Southern Hemisphere. This was due to randomly generating the latitude coordinates at the beginning of the code. I feel like we got a more accurate sample of Northern Hemisphere weather data when compared to Southern Hemisphere data. We could run the code a few more times or at greater quantity to see how the data might have changed.

# %%
# import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import requests
import json
from api_keys import weather_api_key
from citipy import citipy
import random
import decimal
import time

# %% [markdown]
# ## Generate Cities List

# %%
#set up latitude and longitude lists
latitude_list = []
longitude_list = []

# Generate 1000 random latitude and logitude values and add them to there respective list
for x in range(0, 2500):
    latitude = float(decimal.Decimal(random.randrange(-9000, 9000))/100)
    longitude = float(decimal.Decimal(random.randrange(-18000, 18000))/100)
    latitude_list.append(latitude)
    longitude_list.append(longitude)

# Set up the Weather DF
weather_df = pd.DataFrame({"Latitude": latitude_list, "Longitude": longitude_list})

# set up list to hold city names and what there country there from
city_list = []
country_list = []

# goes through each value of Latitude and Longitude in the Weather DF and uses the value as inputs to determin there city and country
for a in range(0, len(weather_df["Latitude"])):
    lat_value = weather_df.iloc[a]["Latitude"]
    long_value = weather_df.iloc[a]["Longitude"]    
    city_cord = citipy.nearest_city(lat_value, long_value)
    city_name = city_cord.city_name
    city_list.append(city_name)
    country = city_cord.country_code
    country_list.append(country)

    
# adds the city and country lists into our weather data frame, and then a touch of formatting   
weather_df["City"] = city_list
weather_df["Country"] = country_list
weather_df["City"] = weather_df["City"].str.title()
weather_df["Country"] = weather_df["Country"].str.upper()


#drop duplicates duplicates
weather_df = weather_df.drop_duplicates(subset=["City", "Country"], keep="first")
weather_df = weather_df.reset_index(drop=True)

print("Total number of unique cities in weather dataframe is: " + str(len(weather_df.index)))
# Out:
# Total number of unique cities in weather dataframe is: 928

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set up list for variables we want
temperature_list = [] 
humidity_list = []
cloudiness_list = []
wind_speed_list = []
date_list = []
# Base URL before adding variable componets
url = "http://api.openweathermap.org/data/2.5/weather?"

    

for target in range(0, len(weather_df.index)):
    
    # Select city on weather DF, and formate for proper url code in event city has spaces in name
    display_city = weather_df.iloc[target]["City"]
    display_country = weather_df.iloc[target]["Country"]
    target_city = weather_df.iloc[target]["City"]
    target_city = target_city.replace(" ","+")
    
    # Build query URL
    query_url = f"{url}appid={weather_api_key}&q={target_city}&units=imperial"
    
    # Use URL to make a request of information, bring back in the json format, and print URL
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    print(f"Currently on {(target + 1)} out of {(len(weather_df.index))} |::| City: {display_city}, {display_country}")
    print(query_url)
    
    # This will collect and store desired information, but if there is an error it will print a line and move on to next
    try:
        cities_temp = weather_json["main"]["temp"]
        temperature_list.append(cities_temp)
        
        cities_humid = weather_json["main"]["humidity"]
        humidity_list.append(cities_humid)
        
        cities_cloud = weather_json["clouds"]["all"]
        cloudiness_list.append(cities_cloud)
        
        cities_wind = weather_json["wind"]["speed"]
        wind_speed_list.append(cities_wind)
        
        cities_date = weather_json["dt"]
        date_list.append(cities_date)
    except:
        print("I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.")
        
        # Usuccessful API request will result in a blank value in list that will throw off list alignment
        # We will but in a dummy value in its place to clean out later
        temperature_list.append("Error")
        humidity_list.append("Error")
        cloudiness_list.append("Error")
        wind_speed_list.append("Error")
        date_list.append("Error")
    print()
    
    # Add a sleep timer to prevent my API requests from going over 60 per min and causing a 1 hour lock out.
    time.sleep(1) # in seconds
# Out:
# Currently on 1 out of 928 |::| City: Souillac, MU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Souillac&units=imperial
#
# Currently on 2 out of 928 |::| City: Cape Town, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cape+Town&units=imperial
#
# Currently on 3 out of 928 |::| City: Codrington, AG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Codrington&units=imperial
#
# Currently on 4 out of 928 |::| City: Rikitea, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rikitea&units=imperial
#
# Currently on 5 out of 928 |::| City: Montague, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Montague&units=imperial
#
# Currently on 6 out of 928 |::| City: Margate, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Margate&units=imperial
#
# Currently on 7 out of 928 |::| City: Cockburn Town, TC
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cockburn+Town&units=imperial
#
# Currently on 8 out of 928 |::| City: Ushuaia, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ushuaia&units=imperial
#
# Currently on 9 out of 928 |::| City: Talaya, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Talaya&units=imperial
#
# Currently on 10 out of 928 |::| City: Port Alfred, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Alfred&units=imperial
#
# Currently on 11 out of 928 |::| City: Busselton, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Busselton&units=imperial
#
# Currently on 12 out of 928 |::| City: Hasaki, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hasaki&units=imperial
#
# Currently on 13 out of 928 |::| City: Port Elizabeth, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Elizabeth&units=imperial
#
# Currently on 14 out of 928 |::| City: Yellowknife, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yellowknife&units=imperial
#
# Currently on 15 out of 928 |::| City: Comodoro Rivadavia, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Comodoro+Rivadavia&units=imperial
#
# Currently on 16 out of 928 |::| City: Duz, TN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Duz&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 17 out of 928 |::| City: Pallasovka, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pallasovka&units=imperial
#
# Currently on 18 out of 928 |::| City: East London, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=East+London&units=imperial
#
# Currently on 19 out of 928 |::| City: Puerto Ayora, EC
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Puerto+Ayora&units=imperial
#
# Currently on 20 out of 928 |::| City: Kingaroy, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kingaroy&units=imperial
#
# Currently on 21 out of 928 |::| City: Nikolskoye, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nikolskoye&units=imperial
#
# Currently on 22 out of 928 |::| City: Byron Bay, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Byron+Bay&units=imperial
#
# Currently on 23 out of 928 |::| City: Lagos, NG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lagos&units=imperial
#
# Currently on 24 out of 928 |::| City: Kodiak, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kodiak&units=imperial
#
# Currently on 25 out of 928 |::| City: Bambous Virieux, MU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bambous+Virieux&units=imperial
#
# Currently on 26 out of 928 |::| City: Avera, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Avera&units=imperial
#
# Currently on 27 out of 928 |::| City: Maceio, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maceio&units=imperial
#
# Currently on 28 out of 928 |::| City: Sisimiut, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sisimiut&units=imperial
#
# Currently on 29 out of 928 |::| City: Akrini, GR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Akrini&units=imperial
#
# Currently on 30 out of 928 |::| City: Hilo, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hilo&units=imperial
#
# Currently on 31 out of 928 |::| City: Narsaq, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Narsaq&units=imperial
#
# Currently on 32 out of 928 |::| City: Attawapiskat, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Attawapiskat&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 33 out of 928 |::| City: Synya, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Synya&units=imperial
#
# Currently on 34 out of 928 |::| City: Celestun, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Celestun&units=imperial
#
# Currently on 35 out of 928 |::| City: Taolanaro, MG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Taolanaro&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 36 out of 928 |::| City: Rovaniemi, FI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rovaniemi&units=imperial
#
# Currently on 37 out of 928 |::| City: Aksarka, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aksarka&units=imperial
#
# Currently on 38 out of 928 |::| City: Avarua, CK
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Avarua&units=imperial
#
# Currently on 39 out of 928 |::| City: Hay River, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hay+River&units=imperial
#
# Currently on 40 out of 928 |::| City: Sembe, CG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sembe&units=imperial
#
# Currently on 41 out of 928 |::| City: Kurilsk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kurilsk&units=imperial
#
# Currently on 42 out of 928 |::| City: Mataura, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mataura&units=imperial
#
# Currently on 43 out of 928 |::| City: Cidreira, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cidreira&units=imperial
#
# Currently on 44 out of 928 |::| City: Storforshei, NO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Storforshei&units=imperial
#
# Currently on 45 out of 928 |::| City: Biak, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Biak&units=imperial
#
# Currently on 46 out of 928 |::| City: Thunder Bay, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Thunder+Bay&units=imperial
#
# Currently on 47 out of 928 |::| City: Mweka, CD
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mweka&units=imperial
#
# Currently on 48 out of 928 |::| City: Nome, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nome&units=imperial
#
# Currently on 49 out of 928 |::| City: College, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=College&units=imperial
# Currently on 50 out of 928 |::| City: Longyearbyen, SJ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Longyearbyen&units=imperial
#
# Currently on 51 out of 928 |::| City: Hobart, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hobart&units=imperial
#
# Currently on 52 out of 928 |::| City: Aklavik, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aklavik&units=imperial
#
# Currently on 53 out of 928 |::| City: Luderitz, NA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Luderitz&units=imperial
#
# Currently on 54 out of 928 |::| City: Kungurtug, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kungurtug&units=imperial
#
# Currently on 55 out of 928 |::| City: Shebalino, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Shebalino&units=imperial
#
# Currently on 56 out of 928 |::| City: Luganville, VU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Luganville&units=imperial
#
# Currently on 57 out of 928 |::| City: Barrow, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barrow&units=imperial
#
# Currently on 58 out of 928 |::| City: Sitka, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sitka&units=imperial
#
# Currently on 59 out of 928 |::| City: Bafoulabe, ML
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bafoulabe&units=imperial
#
# Currently on 60 out of 928 |::| City: Mragowo, PL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mragowo&units=imperial
#
# Currently on 61 out of 928 |::| City: Thompson, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Thompson&units=imperial
#
# Currently on 62 out of 928 |::| City: Provideniya, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Provideniya&units=imperial
#
# Currently on 63 out of 928 |::| City: Praia, CV
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Praia&units=imperial
#
# Currently on 64 out of 928 |::| City: Saleaula, WS
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saleaula&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 65 out of 928 |::| City: Luoyang, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Luoyang&units=imperial
#
# Currently on 66 out of 928 |::| City: Roswell, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Roswell&units=imperial
#
# Currently on 67 out of 928 |::| City: Batagay, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Batagay&units=imperial
#
# Currently on 68 out of 928 |::| City: Khatanga, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Khatanga&units=imperial
#
# Currently on 69 out of 928 |::| City: Te Anau, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Te+Anau&units=imperial
#
# Currently on 70 out of 928 |::| City: Mount Isa, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mount+Isa&units=imperial
#
# Currently on 71 out of 928 |::| City: Nyurba, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nyurba&units=imperial
#
# Currently on 72 out of 928 |::| City: Katha, MM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Katha&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 73 out of 928 |::| City: New Norfolk, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=New+Norfolk&units=imperial
#
# Currently on 74 out of 928 |::| City: Butaritari, KI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Butaritari&units=imperial
#
# Currently on 75 out of 928 |::| City: Punta Arenas, CL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Punta+Arenas&units=imperial
#
# Currently on 76 out of 928 |::| City: Marathon, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Marathon&units=imperial
#
# Currently on 77 out of 928 |::| City: Puerto Baquerizo Moreno, EC
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Puerto+Baquerizo+Moreno&units=imperial
#
# Currently on 78 out of 928 |::| City: Bengkulu, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bengkulu&units=imperial
#
# Currently on 79 out of 928 |::| City: Ossora, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ossora&units=imperial
#
# Currently on 80 out of 928 |::| City: Komsomolskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Komsomolskiy&units=imperial
#
# Currently on 81 out of 928 |::| City: Saint-Philippe, RE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint-Philippe&units=imperial
#
# Currently on 82 out of 928 |::| City: Iqaluit, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Iqaluit&units=imperial
#
# Currently on 83 out of 928 |::| City: Touros, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Touros&units=imperial
#
# Currently on 84 out of 928 |::| City: Henties Bay, NA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Henties+Bay&units=imperial
#
# Currently on 85 out of 928 |::| City: Hermanus, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hermanus&units=imperial
#
# Currently on 86 out of 928 |::| City: Taihe, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Taihe&units=imperial
#
# Currently on 87 out of 928 |::| City: Chara, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chara&units=imperial
#
# Currently on 88 out of 928 |::| City: Pevek, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pevek&units=imperial
#
# Currently on 89 out of 928 |::| City: Dumingag, PH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dumingag&units=imperial
#
# Currently on 90 out of 928 |::| City: Rosetta, EG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Rosetta&units=imperial
#
# Currently on 91 out of 928 |::| City: Qaanaaq, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Qaanaaq&units=imperial
#
# Currently on 92 out of 928 |::| City: Tasiilaq, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tasiilaq&units=imperial
#
# Currently on 93 out of 928 |::| City: Playas, EC
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Playas&units=imperial
#
# Currently on 94 out of 928 |::| City: Vaini, TO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vaini&units=imperial
#
# Currently on 95 out of 928 |::| City: Inirida, CO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Inirida&units=imperial
#
# Currently on 96 out of 928 |::| City: Yulara, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yulara&units=imperial
#
# Currently on 97 out of 928 |::| City: Muros, ES
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Muros&units=imperial
#
# Currently on 98 out of 928 |::| City: Carnarvon, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Carnarvon&units=imperial
# Currently on 99 out of 928 |::| City: Aflu, DZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aflu&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 100 out of 928 |::| City: Yerofey Pavlovich, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yerofey+Pavlovich&units=imperial
#
# Currently on 101 out of 928 |::| City: Kapaa, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kapaa&units=imperial
#
# Currently on 102 out of 928 |::| City: Clyde River, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Clyde+River&units=imperial
#
# Currently on 103 out of 928 |::| City: Kaitangata, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kaitangata&units=imperial
#
# Currently on 104 out of 928 |::| City: Simdega, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Simdega&units=imperial
#
# Currently on 105 out of 928 |::| City: Makakilo City, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Makakilo+City&units=imperial
#
# Currently on 106 out of 928 |::| City: Matagami, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Matagami&units=imperial
#
# Currently on 107 out of 928 |::| City: Terney, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Terney&units=imperial
#
# Currently on 108 out of 928 |::| City: Hovd, MN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hovd&units=imperial
#
# Currently on 109 out of 928 |::| City: Airai, PW
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Airai&units=imperial
#
# Currently on 110 out of 928 |::| City: Putna, RO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Putna&units=imperial
#
# Currently on 111 out of 928 |::| City: Nemuro, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nemuro&units=imperial
#
# Currently on 112 out of 928 |::| City: Kem, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kem&units=imperial
#
# Currently on 113 out of 928 |::| City: Erdenet, MN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Erdenet&units=imperial
#
# Currently on 114 out of 928 |::| City: Husavik, IS
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Husavik&units=imperial
#
# Currently on 115 out of 928 |::| City: Andevoranto, MG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Andevoranto&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 116 out of 928 |::| City: Along, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Along&units=imperial
#
# Currently on 117 out of 928 |::| City: Sentyabrskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sentyabrskiy&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 118 out of 928 |::| City: Ahuimanu, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ahuimanu&units=imperial
#
# Currently on 119 out of 928 |::| City: The Valley, AI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=The+Valley&units=imperial
#
# Currently on 120 out of 928 |::| City: Villa Rica, PE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Villa+Rica&units=imperial
#
# Currently on 121 out of 928 |::| City: Albany, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Albany&units=imperial
#
# Currently on 122 out of 928 |::| City: Saldanha, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saldanha&units=imperial
#
# Currently on 123 out of 928 |::| City: Quatre Cocos, MU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Quatre+Cocos&units=imperial
#
# Currently on 124 out of 928 |::| City: Saskylakh, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saskylakh&units=imperial
#
# Currently on 125 out of 928 |::| City: Port Said, EG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Said&units=imperial
#
# Currently on 126 out of 928 |::| City: Bluff, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bluff&units=imperial
#
# Currently on 127 out of 928 |::| City: Tsihombe, MG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tsihombe&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 128 out of 928 |::| City: Kuching, MY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kuching&units=imperial
#
# Currently on 129 out of 928 |::| City: Cabo San Lucas, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cabo+San+Lucas&units=imperial
#
# Currently on 130 out of 928 |::| City: Upernavik, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Upernavik&units=imperial
#
# Currently on 131 out of 928 |::| City: Bethel, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bethel&units=imperial
#
# Currently on 132 out of 928 |::| City: Cruzeiro Do Sul, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cruzeiro+Do+Sul&units=imperial
#
# Currently on 133 out of 928 |::| City: Hithadhoo, MV
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hithadhoo&units=imperial
#
# Currently on 134 out of 928 |::| City: Esperance, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Esperance&units=imperial
#
# Currently on 135 out of 928 |::| City: Torbay, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Torbay&units=imperial
#
# Currently on 136 out of 928 |::| City: Burnie, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Burnie&units=imperial
#
# Currently on 137 out of 928 |::| City: Inuvik, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Inuvik&units=imperial
#
# Currently on 138 out of 928 |::| City: Jiddah, SA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jiddah&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 139 out of 928 |::| City: Atuona, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Atuona&units=imperial
#
# Currently on 140 out of 928 |::| City: Jamestown, SH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jamestown&units=imperial
#
# Currently on 141 out of 928 |::| City: Pontianak, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pontianak&units=imperial
#
# Currently on 142 out of 928 |::| City: Lavrentiya, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lavrentiya&units=imperial
#
# Currently on 143 out of 928 |::| City: Dikson, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dikson&units=imperial
#
# Currently on 144 out of 928 |::| City: Arraial Do Cabo, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Arraial+Do+Cabo&units=imperial
#
# Currently on 145 out of 928 |::| City: Belushya Guba, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Belushya+Guba&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
# Currently on 146 out of 928 |::| City: Illoqqortoormiut, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Illoqqortoormiut&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 147 out of 928 |::| City: Hobyo, SO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hobyo&units=imperial
#
# Currently on 148 out of 928 |::| City: Chillicothe, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chillicothe&units=imperial
#
# Currently on 149 out of 928 |::| City: Amderma, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Amderma&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 150 out of 928 |::| City: Chatellerault, FR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chatellerault&units=imperial
#
# Currently on 151 out of 928 |::| City: Evensk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Evensk&units=imperial
#
# Currently on 152 out of 928 |::| City: Vestmannaeyjar, IS
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vestmannaeyjar&units=imperial
#
# Currently on 153 out of 928 |::| City: Cherskiy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cherskiy&units=imperial
#
# Currently on 154 out of 928 |::| City: Georgetown, SH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Georgetown&units=imperial
#
# Currently on 155 out of 928 |::| City: Talnakh, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Talnakh&units=imperial
#
# Currently on 156 out of 928 |::| City: Zhanatas, KZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zhanatas&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 157 out of 928 |::| City: Bathsheba, BB
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bathsheba&units=imperial
#
# Currently on 158 out of 928 |::| City: Chumphon, TH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chumphon&units=imperial
#
# Currently on 159 out of 928 |::| City: Manteca, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Manteca&units=imperial
#
# Currently on 160 out of 928 |::| City: Ponta Do Sol, CV
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ponta+Do+Sol&units=imperial
#
# Currently on 161 out of 928 |::| City: Faanui, PF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Faanui&units=imperial
#
# Currently on 162 out of 928 |::| City: Chagda, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chagda&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 163 out of 928 |::| City: Fort Nelson, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Fort+Nelson&units=imperial
#
# Currently on 164 out of 928 |::| City: Ilulissat, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ilulissat&units=imperial
#
# Currently on 165 out of 928 |::| City: Nizhneyansk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nizhneyansk&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 166 out of 928 |::| City: Sergeyevka, KZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sergeyevka&units=imperial
#
# Currently on 167 out of 928 |::| City: Sukumo, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sukumo&units=imperial
#
# Currently on 168 out of 928 |::| City: Seymchan, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Seymchan&units=imperial
#
# Currently on 169 out of 928 |::| City: Grand Baie, MU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Grand+Baie&units=imperial
#
# Currently on 170 out of 928 |::| City: Arlit, NE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Arlit&units=imperial
#
# Currently on 171 out of 928 |::| City: Nola, CF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nola&units=imperial
#
# Currently on 172 out of 928 |::| City: Zhigansk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zhigansk&units=imperial
#
# Currently on 173 out of 928 |::| City: Mandera, KE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mandera&units=imperial
#
# Currently on 174 out of 928 |::| City: Ulladulla, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ulladulla&units=imperial
#
# Currently on 175 out of 928 |::| City: Guerrero Negro, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Guerrero+Negro&units=imperial
#
# Currently on 176 out of 928 |::| City: Tarko-Sale, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tarko-Sale&units=imperial
#
# Currently on 177 out of 928 |::| City: Mar Del Plata, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mar+Del+Plata&units=imperial
#
# Currently on 178 out of 928 |::| City: Piacabucu, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Piacabucu&units=imperial
#
# Currently on 179 out of 928 |::| City: Naberera, TZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Naberera&units=imperial
#
# Currently on 180 out of 928 |::| City: Santa Fe, CU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Santa+Fe&units=imperial
#
# Currently on 181 out of 928 |::| City: Colon, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Colon&units=imperial
#
# Currently on 182 out of 928 |::| City: Southbridge, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Southbridge&units=imperial
#
# Currently on 183 out of 928 |::| City: Abu Samrah, QA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Abu+Samrah&units=imperial
#
# Currently on 184 out of 928 |::| City: Saint George, BM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint+George&units=imperial
#
# Currently on 185 out of 928 |::| City: Ovalle, CL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ovalle&units=imperial
#
# Currently on 186 out of 928 |::| City: Saint Pete Beach, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint+Pete+Beach&units=imperial
#
# Currently on 187 out of 928 |::| City: Kangaatsiaq, GL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kangaatsiaq&units=imperial
#
# Currently on 188 out of 928 |::| City: Srednekolymsk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Srednekolymsk&units=imperial
#
# Currently on 189 out of 928 |::| City: Lewistown, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lewistown&units=imperial
#
# Currently on 190 out of 928 |::| City: Dakar, SN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dakar&units=imperial
#
# Currently on 191 out of 928 |::| City: Palabuhanratu, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Palabuhanratu&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
# Currently on 192 out of 928 |::| City: Vardo, NO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vardo&units=imperial
#
# Currently on 193 out of 928 |::| City: Severomuysk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Severomuysk&units=imperial
#
# Currently on 194 out of 928 |::| City: Haibowan, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Haibowan&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 195 out of 928 |::| City: Grindavik, IS
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Grindavik&units=imperial
#
# Currently on 196 out of 928 |::| City: Saint-Georges, GF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint-Georges&units=imperial
#
# Currently on 197 out of 928 |::| City: Kavaratti, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kavaratti&units=imperial
#
# Currently on 198 out of 928 |::| City: Porto Novo, CV
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Porto+Novo&units=imperial
#
# Currently on 199 out of 928 |::| City: Korla, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Korla&units=imperial
#
# Currently on 200 out of 928 |::| City: Bredasdorp, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bredasdorp&units=imperial
#
# Currently on 201 out of 928 |::| City: Swiecie, PL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Swiecie&units=imperial
#
# Currently on 202 out of 928 |::| City: Necochea, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Necochea&units=imperial
#
# Currently on 203 out of 928 |::| City: Whitehorse, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Whitehorse&units=imperial
#
# Currently on 204 out of 928 |::| City: Meyungs, PW
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Meyungs&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 205 out of 928 |::| City: Ekhabi, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ekhabi&units=imperial
#
# Currently on 206 out of 928 |::| City: Chuy, UY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chuy&units=imperial
#
# Currently on 207 out of 928 |::| City: Nhulunbuy, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nhulunbuy&units=imperial
#
# Currently on 208 out of 928 |::| City: Aquidauana, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aquidauana&units=imperial
#
# Currently on 209 out of 928 |::| City: Sao Filipe, CV
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sao+Filipe&units=imperial
#
# Currently on 210 out of 928 |::| City: Tumut, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tumut&units=imperial
#
# Currently on 211 out of 928 |::| City: Olinda, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Olinda&units=imperial
#
# Currently on 212 out of 928 |::| City: Tuktoyaktuk, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tuktoyaktuk&units=imperial
#
# Currently on 213 out of 928 |::| City: Udachnyy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Udachnyy&units=imperial
#
# Currently on 214 out of 928 |::| City: Santa Cruz, CR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Santa+Cruz&units=imperial
#
# Currently on 215 out of 928 |::| City: Almaznyy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Almaznyy&units=imperial
#
# Currently on 216 out of 928 |::| City: Kruisfontein, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kruisfontein&units=imperial
#
# Currently on 217 out of 928 |::| City: Palmares Do Sul, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Palmares+Do+Sul&units=imperial
#
# Currently on 218 out of 928 |::| City: Severo-Kurilsk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Severo-Kurilsk&units=imperial
#
# Currently on 219 out of 928 |::| City: Lubao, CD
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lubao&units=imperial
#
# Currently on 220 out of 928 |::| City: Sorong, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sorong&units=imperial
#
# Currently on 221 out of 928 |::| City: Sitangkai, PH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sitangkai&units=imperial
#
# Currently on 222 out of 928 |::| City: Meulaboh, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Meulaboh&units=imperial
#
# Currently on 223 out of 928 |::| City: Sambava, MG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sambava&units=imperial
#
# Currently on 224 out of 928 |::| City: Palmerston, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Palmerston&units=imperial
#
# Currently on 225 out of 928 |::| City: Pisco, PE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pisco&units=imperial
#
# Currently on 226 out of 928 |::| City: Turka, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Turka&units=imperial
#
# Currently on 227 out of 928 |::| City: Pangnirtung, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pangnirtung&units=imperial
#
# Currently on 228 out of 928 |::| City: Coquimbo, CL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Coquimbo&units=imperial
#
# Currently on 229 out of 928 |::| City: Keflavik, IS
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Keflavik&units=imperial
#
# Currently on 230 out of 928 |::| City: Saint-Joseph, RE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint-Joseph&units=imperial
#
# Currently on 231 out of 928 |::| City: Barentsburg, SJ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Barentsburg&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 232 out of 928 |::| City: Umm Lajj, SA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Umm+Lajj&units=imperial
#
# Currently on 233 out of 928 |::| City: Eskisehir, TR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Eskisehir&units=imperial
#
# Currently on 234 out of 928 |::| City: Victoria, SC
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Victoria&units=imperial
#
# Currently on 235 out of 928 |::| City: Chabahar, IR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Chabahar&units=imperial
#
# Currently on 236 out of 928 |::| City: Caluquembe, AO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Caluquembe&units=imperial
#
# Currently on 237 out of 928 |::| City: Klaksvik, FO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Klaksvik&units=imperial
#
# Currently on 238 out of 928 |::| City: Christchurch, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Christchurch&units=imperial
#
# Currently on 239 out of 928 |::| City: Katsuura, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Katsuura&units=imperial
# Currently on 240 out of 928 |::| City: Maumere, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maumere&units=imperial
#
# Currently on 241 out of 928 |::| City: Suba, PH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Suba&units=imperial
#
# Currently on 242 out of 928 |::| City: Magalia, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Magalia&units=imperial
#
# Currently on 243 out of 928 |::| City: Manado, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Manado&units=imperial
#
# Currently on 244 out of 928 |::| City: Golden, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Golden&units=imperial
#
# Currently on 245 out of 928 |::| City: Ijaki, KI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ijaki&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 246 out of 928 |::| City: Geraldton, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Geraldton&units=imperial
#
# Currently on 247 out of 928 |::| City: Labis, MY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Labis&units=imperial
#
# Currently on 248 out of 928 |::| City: Vao, NC
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vao&units=imperial
#
# Currently on 249 out of 928 |::| City: Ribeira Brava, PT
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ribeira+Brava&units=imperial
#
# Currently on 250 out of 928 |::| City: San Carlos De Bariloche, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=San+Carlos+De+Bariloche&units=imperial
#
# Currently on 251 out of 928 |::| City: Pimentel, PE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pimentel&units=imperial
#
# Currently on 252 out of 928 |::| City: Tumpat, MY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Tumpat&units=imperial
#
# Currently on 253 out of 928 |::| City: Camacha, PT
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Camacha&units=imperial
#
# Currently on 254 out of 928 |::| City: Seoul, KR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Seoul&units=imperial
#
# Currently on 255 out of 928 |::| City: Nizhniy Baskunchak, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nizhniy+Baskunchak&units=imperial
#
# Currently on 256 out of 928 |::| City: Cagliari, IT
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cagliari&units=imperial
#
# Currently on 257 out of 928 |::| City: Buraydah, SA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Buraydah&units=imperial
#
# Currently on 258 out of 928 |::| City: Taksimo, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Taksimo&units=imperial
#
# Currently on 259 out of 928 |::| City: Lypova Dolyna, UA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lypova+Dolyna&units=imperial
#
# Currently on 260 out of 928 |::| City: Kargopol, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kargopol&units=imperial
#
# Currently on 261 out of 928 |::| City: Nizwa, OM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nizwa&units=imperial
#
# Currently on 262 out of 928 |::| City: Xiongyue, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Xiongyue&units=imperial
#
# Currently on 263 out of 928 |::| City: Addi Ugri, ER
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Addi+Ugri&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 264 out of 928 |::| City: Taft, IR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Taft&units=imperial
#
# Currently on 265 out of 928 |::| City: Aripuana, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aripuana&units=imperial
#
# Currently on 266 out of 928 |::| City: Amapa, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Amapa&units=imperial
#
# Currently on 267 out of 928 |::| City: Saint-Augustin, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Saint-Augustin&units=imperial
#
# Currently on 268 out of 928 |::| City: Savalou, BJ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Savalou&units=imperial
#
# Currently on 269 out of 928 |::| City: Waipawa, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Waipawa&units=imperial
#
# Currently on 270 out of 928 |::| City: Worcester, ZA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Worcester&units=imperial
#
# Currently on 271 out of 928 |::| City: Castro, CL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Castro&units=imperial
#
# Currently on 272 out of 928 |::| City: Grand River South East, MU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Grand+River+South+East&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 273 out of 928 |::| City: At-Bashi, KG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=At-Bashi&units=imperial
#
# Currently on 274 out of 928 |::| City: Progreso, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Progreso&units=imperial
#
# Currently on 275 out of 928 |::| City: Peleduy, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Peleduy&units=imperial
#
# Currently on 276 out of 928 |::| City: Suzun, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Suzun&units=imperial
#
# Currently on 277 out of 928 |::| City: Sur, OM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sur&units=imperial
#
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pemba&units=imperial
#
# Currently on 836 out of 928 |::| City: Ciras, AF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ciras&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 837 out of 928 |::| City: Pinawa, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Pinawa&units=imperial
#
# Currently on 838 out of 928 |::| City: Somotillo, NI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Somotillo&units=imperial
#
# Currently on 839 out of 928 |::| City: Jahrom, IR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jahrom&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 840 out of 928 |::| City: Anchovy, JM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Anchovy&units=imperial
#
# Currently on 841 out of 928 |::| City: Ngunguru, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ngunguru&units=imperial
#
# Currently on 842 out of 928 |::| City: Beisfjord, NO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Beisfjord&units=imperial
#
# Currently on 843 out of 928 |::| City: Kirakira, SB
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kirakira&units=imperial
#
# Currently on 844 out of 928 |::| City: Serov, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Serov&units=imperial
#
# Currently on 845 out of 928 |::| City: Jumla, NP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Jumla&units=imperial
#
# Currently on 846 out of 928 |::| City: Varberg, SE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Varberg&units=imperial
#
# Currently on 847 out of 928 |::| City: Dali, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dali&units=imperial
#
# Currently on 848 out of 928 |::| City: Gazanjyk, TM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gazanjyk&units=imperial
#
# Currently on 849 out of 928 |::| City: Cartagena, CO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cartagena&units=imperial
#
# Currently on 850 out of 928 |::| City: Igarka, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Igarka&units=imperial
#
# Currently on 851 out of 928 |::| City: Morant Bay, JM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Morant+Bay&units=imperial
#
# Currently on 852 out of 928 |::| City: Vanino, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Vanino&units=imperial
#
# Currently on 853 out of 928 |::| City: Soloneshnoye, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Soloneshnoye&units=imperial
#
# Currently on 854 out of 928 |::| City: Andenes, NO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Andenes&units=imperial
#
# Currently on 855 out of 928 |::| City: Quang Ngai, VN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Quang+Ngai&units=imperial
#
# Currently on 856 out of 928 |::| City: Sayyan, YE
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sayyan&units=imperial
#
# Currently on 857 out of 928 |::| City: Leshukonskoye, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Leshukonskoye&units=imperial
#
# Currently on 858 out of 928 |::| City: Newport, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Newport&units=imperial
#
# Currently on 859 out of 928 |::| City: Grootfontein, NA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Grootfontein&units=imperial
#
# Currently on 860 out of 928 |::| City: Mackay, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mackay&units=imperial
#
# Currently on 861 out of 928 |::| City: Bemidji, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bemidji&units=imperial
# Currently on 862 out of 928 |::| City: Honiara, SB
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Honiara&units=imperial
#
# Currently on 863 out of 928 |::| City: Patacamaya, BO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Patacamaya&units=imperial
#
# Currently on 864 out of 928 |::| City: Ust-Kuyga, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ust-Kuyga&units=imperial
#
# Currently on 865 out of 928 |::| City: Coos Bay, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Coos+Bay&units=imperial
#
# Currently on 866 out of 928 |::| City: Kupang, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kupang&units=imperial
#
# Currently on 867 out of 928 |::| City: Utica, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Utica&units=imperial
#
# Currently on 868 out of 928 |::| City: Aleksandrovka, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aleksandrovka&units=imperial
#
# Currently on 869 out of 928 |::| City: Opelousas, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Opelousas&units=imperial
#
# Currently on 870 out of 928 |::| City: Ardabil, IR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ardabil&units=imperial
#
# Currently on 871 out of 928 |::| City: Anloga, GH
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Anloga&units=imperial
#
# Currently on 872 out of 928 |::| City: Acapulco, MX
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Acapulco&units=imperial
#
# Currently on 873 out of 928 |::| City: Zaozerne, UA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zaozerne&units=imperial
#
# Currently on 874 out of 928 |::| City: Shiyan, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Shiyan&units=imperial
#
# Currently on 875 out of 928 |::| City: Irbil, IQ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Irbil&units=imperial
#
# Currently on 876 out of 928 |::| City: Dinghai, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dinghai&units=imperial
#
# Currently on 877 out of 928 |::| City: Bairiki, KI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Bairiki&units=imperial
#
# Currently on 878 out of 928 |::| City: Syava, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Syava&units=imperial
#
# Currently on 879 out of 928 |::| City: Geneva, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Geneva&units=imperial
#
# Currently on 880 out of 928 |::| City: Batavia, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Batavia&units=imperial
#
# Currently on 881 out of 928 |::| City: Orlik, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Orlik&units=imperial
#
# Currently on 882 out of 928 |::| City: Edmundston, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Edmundston&units=imperial
#
# Currently on 883 out of 928 |::| City: Presidencia Roque Saenz Pena, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Presidencia+Roque+Saenz+Pena&units=imperial
#
# Currently on 884 out of 928 |::| City: Nurota, UZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nurota&units=imperial
#
# Currently on 885 out of 928 |::| City: Genhe, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Genhe&units=imperial
#
# Currently on 886 out of 928 |::| City: Murighiol, RO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Murighiol&units=imperial
#
# Currently on 887 out of 928 |::| City: Yablonovo, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yablonovo&units=imperial
#
# Currently on 888 out of 928 |::| City: Ternate, ID
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ternate&units=imperial
#
# Currently on 889 out of 928 |::| City: Port Hedland, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Hedland&units=imperial
#
# Currently on 890 out of 928 |::| City: Abaete, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Abaete&units=imperial
#
# Currently on 891 out of 928 |::| City: Ulyanovo, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Ulyanovo&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 892 out of 928 |::| City: Port Hawkesbury, CA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Port+Hawkesbury&units=imperial
#
# Currently on 893 out of 928 |::| City: Duki, PK
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Duki&units=imperial
#
# Currently on 894 out of 928 |::| City: Aginskoye, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Aginskoye&units=imperial
#
# Currently on 895 out of 928 |::| City: Kahului, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kahului&units=imperial
#
# Currently on 896 out of 928 |::| City: Waddan, LY
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Waddan&units=imperial
#
# Currently on 897 out of 928 |::| City: Gejiu, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Gejiu&units=imperial
#
# Currently on 898 out of 928 |::| City: Lukiv, UA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Lukiv&units=imperial
#
# Currently on 899 out of 928 |::| City: Verkhoyansk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Verkhoyansk&units=imperial
#
# Currently on 900 out of 928 |::| City: Turkmenabat, TM
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Turkmenabat&units=imperial
#
# Currently on 901 out of 928 |::| City: Mordovo, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mordovo&units=imperial
#
# Currently on 902 out of 928 |::| City: Fukue, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Fukue&units=imperial
#
# Currently on 903 out of 928 |::| City: Cockburn Town, BS
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Cockburn+Town&units=imperial
#
# Currently on 904 out of 928 |::| City: Kieta, PG
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kieta&units=imperial
#
# Currently on 905 out of 928 |::| City: Erie, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Erie&units=imperial
#
# Currently on 906 out of 928 |::| City: Nam Tha, LA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nam+Tha&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 907 out of 928 |::| City: Kawana Waters, AU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kawana+Waters&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 908 out of 928 |::| City: Yerbogachen, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Yerbogachen&units=imperial
#
# Currently on 909 out of 928 |::| City: Brzeg Dolny, PL
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Brzeg+Dolny&units=imperial
# Currently on 910 out of 928 |::| City: Freeport, US
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Freeport&units=imperial
#
# Currently on 911 out of 928 |::| City: Mana, GF
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Mana&units=imperial
#
# Currently on 912 out of 928 |::| City: Caxito, AO
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Caxito&units=imperial
#
# Currently on 913 out of 928 |::| City: Dotnuva, LT
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Dotnuva&units=imperial
#
# Currently on 914 out of 928 |::| City: Kodinar, IN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kodinar&units=imperial
#
# Currently on 915 out of 928 |::| City: Am Timan, TD
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Am+Timan&units=imperial
#
# Currently on 916 out of 928 |::| City: Nevelsk, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Nevelsk&units=imperial
#
# Currently on 917 out of 928 |::| City: Leme, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Leme&units=imperial
#
# Currently on 918 out of 928 |::| City: Hue, VN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Hue&units=imperial
#
# Currently on 919 out of 928 |::| City: Maltahohe, NA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maltahohe&units=imperial
#
# Currently on 920 out of 928 |::| City: Karkaralinsk, KZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Karkaralinsk&units=imperial
# I'm afraid I can't do that Dave. There seems to have been an error. Let's try the next city.
#
# Currently on 921 out of 928 |::| City: Altay, CN
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Altay&units=imperial
#
# Currently on 922 out of 928 |::| City: Sao Sebastiao, BR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Sao+Sebastiao&units=imperial
#
# Currently on 923 out of 928 |::| City: Maarianhamina, FI
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Maarianhamina&units=imperial
#
# Currently on 924 out of 928 |::| City: Zatoka, UA
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Zatoka&units=imperial
#
# Currently on 925 out of 928 |::| City: Russell, NZ
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Russell&units=imperial
#
# Currently on 926 out of 928 |::| City: Kushiro, JP
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Kushiro&units=imperial
#
# Currently on 927 out of 928 |::| City: Salym, RU
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Salym&units=imperial
#
# Currently on 928 out of 928 |::| City: Concordia, AR
# http://api.openweathermap.org/data/2.5/weather?appid=b25308977725b83101693dd059c4f501&q=Concordia&units=imperial

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Add collected weather data to Weather DF
weather_df["Temperature (F)"] = temperature_list
weather_df["Humidity (%)"] = humidity_list
weather_df["Cloud Cover (%)"] = cloudiness_list
weather_df["Wind Speed (MPH)"] = wind_speed_list
weather_df["Date (UTC)"] = date_list

# Drop rows where we assigned Error too, because there was no data to pull
weather_df_v2 = weather_df[weather_df["Temperature (F)"] != "Error"]

# Reset Index after removing errors
weather_df_v2 = weather_df_v2.reset_index(drop=True)



# Save DF as .csv
weather_df_v2.to_csv("weather_data.csv")

print("Total number of unique cities in weather dataframe is: " + str(len(weather_df_v2.index)))
weather_df_v2.head(5)
# Out:
# Total number of unique cities in weather dataframe is: 851
#    Latitude  Longitude        City Country Temperature (F) Humidity (%)  \
# 0    -49.34      71.83    Souillac      MU            78.8           65
# 1    -63.69     -12.97   Cape Town      ZA           66.11           72
# 2     26.90     -45.04  Codrington      AG           56.26           71
# 3    -50.16    -121.36     Rikitea      PF           75.06           84
# 4     46.39     -62.78    Montague      CA           41.47           79
#
#   Cloud Cover (%) Wind Speed (MPH)  Date (UTC)
# 0              75            19.46  1603694057
# 1               0              4.7  1603694058
# 2               0            21.97  1603694059
# 3             100            19.33  1603694060
# 4             100             2.21  1603694061

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get list of the indices of cities that have humidity over 100%.

over_100 = weather_df_v2.index[weather_df_v2["Humidity (%)"] > 100].tolist()
print(over_100)
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df_v2.drop(over_100)


clean_city_data = clean_city_data.reset_index(drop=True)
print("Total number of unique cities in weather dataframe is: " + str(len(weather_df_v2.index)))
clean_city_data.head(100)
# Out:
# Total number of unique cities in weather dataframe is: 851
#     Latitude  Longitude           City Country Temperature (F) Humidity (%)  \
# 0     -49.34      71.83       Souillac      MU            78.8           65
# 1     -63.69     -12.97      Cape Town      ZA           66.11           72
# 2      26.90     -45.04     Codrington      AG           56.26           71
# 3     -50.16    -121.36        Rikitea      PF           75.06           84
# 4      46.39     -62.78       Montague      CA           41.47           79
# ..       ...        ...            ...     ...             ...          ...
# 95     69.86     -80.09    Clyde River      CA            12.2           78
# 96    -63.80     175.99     Kaitangata      NZ           51.01           63
# 97     22.68      84.36        Simdega      IN           86.16           35
# 98     10.20    -163.16  Makakilo City      US           77.38           78
# 99     50.26     -78.40       Matagami      CA            26.6          100
#
#    Cloud Cover (%) Wind Speed (MPH)  Date (UTC)
# 0               75            19.46  1603694057
# 1                0              4.7  1603694058
# 2                0            21.97  1603694059
# 3              100            19.33  1603694060
# 4              100             2.21  1603694061
# ..             ...              ...         ...
# 95              90            17.22  1603694400
# 96              48             1.99  1603694401
# 97               0             5.73  1603694402
# 98               1             2.01  1603694122
# 99              90             3.36  1603694405
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Temperature (F)"]

# Create Scatter Plot
fig_1 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Temperature - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

fig_1.figure.savefig('lat_v_temp.png')

print("This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.")

plt.show
# Out:
# This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Humidity (%)"]

# Create Scatter Plot
fig_2 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Humidity - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

fig_2.figure.savefig('lat_v_humid.png')

print("This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Cloud Cover (%)"]

# Create Scatter Plot
fig_3 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Cloudiness - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

fig_3.figure.savefig('lat_v_cloud.png')


print("This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Set Axises
x_axis = clean_city_data["Latitude"]
y_axis = clean_city_data["Wind Speed (MPH)"]

# Create Scatter Plot
fig_4 = plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Wind Speed - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

fig_4.figure.savefig('lat_v_wind.png')


print("This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.")




plt.show
# Out:
# This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Linear Regression

# %%
# Set Clean City DF to North and South Hemispheres
north_hem = clean_city_data[clean_city_data["Latitude"] > 0]
south_hem = clean_city_data[clean_city_data["Latitude"] < 0]
print("Total number of unique cities in Northern Hemisphere is: " + str(len(north_hem.index)))
print("Total number of unique cities in Southern Hemisphere is: " + str(len(south_hem.index)))
# Out:
# Total number of unique cities in Northern Hemisphere is: 598
# Total number of unique cities in Southern Hemisphere is: 253

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set Axises

x_axis = north_hem["Latitude"]
y_axis = north_hem["Temperature (F)"]

# Create Scatter Plot
fig_5 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Northern Hemisphere - Latitude vs. Temperature - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")


# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")




fig_5.figure.savefig('n_hem_lat_v_temp.png')

print("This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.")

plt.show
# Out:
# The correlation between both factors is -0.85
# This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set Axises

x_axis = south_hem["Latitude"]
y_axis = south_hem["Temperature (F)"]

# Create Scatter Plot
fig_6 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("southern Hemisphere - Latitude vs. Temperature - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")


# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-90, 90),fontsize=15,color="red")




fig_6.figure.savefig('s_hem_lat_v_temp.png')

print("This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.")

plt.show
# Out:
# The correlation between both factors is 0.51
# This plot is comparing the latitude and temperature of each city in the data frame. We can see that as latitude is closer to zero, the equator, the higher the temperature is.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = north_hem["Latitude"]
y_axis = north_hem["Humidity (%)"]

# Create Scatter Plot
fig_7 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Humidity - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=15,color="red")



fig_7.figure.savefig('n_hem_lat_v_humid.png')

print("This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.28
# This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = south_hem["Latitude"]
y_axis = south_hem["Humidity (%)"]

# Create Scatter Plot
fig_8 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Humidity - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")


# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-80,20),fontsize=15,color="red")


fig_8.figure.savefig('s_hem_lat_v_humid.png')

print("This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.06
# This plot is comparing the latitude and humidity of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = north_hem["Latitude"]
y_axis = north_hem["Cloud Cover (%)"]

# Create Scatter Plot
fig_9 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Cloudiness - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(50,30),fontsize=15,color="red")



fig_9.figure.savefig('n_hem_lat_v_cloud.png')


print("This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.22
# This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = south_hem["Latitude"]
y_axis = south_hem["Cloud Cover (%)"]

# Create Scatter Plot
fig_10 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Cloudiness - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-90,20),fontsize=15,color="red")




fig_10.figure.savefig('s_hem_lat_v_cloud.png')


print("This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.")



plt.show
# Out:
# The correlation between both factors is 0.07
# This plot is comparing the latitude and cloudiness of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = north_hem["Latitude"]
y_axis = north_hem["Wind Speed (MPH)"]

# Create Scatter Plot
fig_11 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Wind Speed - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")


fig_11.figure.savefig('n_hem_lat_v_wind.png')


print("This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.")




plt.show
# Out:
# The correlation between both factors is 0.16
# This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set Axises
x_axis = south_hem["Latitude"]
y_axis = south_hem["Wind Speed (MPH)"]

# Create Scatter Plot
fig_12 = plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Set Lables and other
plt.title("Latitude vs. Wind Speed - 10.25.20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# calculate correlation coefficient
correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# calculates the linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis.astype(float) ,y_axis.astype(float))
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-90,18),fontsize=15,color="red")


fig_12.figure.savefig('s_hem_lat_v_wind.png')


print("This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.")




plt.show
# Out:
# The correlation between both factors is -0.22
# This plot is comparing the latitude and wind speed of each city in the data frame. There does not seem to be much of a relationship.
# <function matplotlib.pyplot.show(*args, **kw)>
